# %%
# # Unit 6 | Assignment - What's the Weather Like?

# ## WeatherPy

# In this example, you'll be creating a Python script 
# to visualize the weather of 500+ cities across the world of
# varying distance from the equator.To accomplish this, 
# you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), 
# the [OpenWeatherMap API](https://openweathermap.org/api), 
# and a little common sense to create a representative model of weather across world cities.

# Your objective is to build a series of scatter plots to showcase the following relationships:

# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# Your final notebook must:

# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.

# As final considerations:

# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.

# ## Hints and Considerations

# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).

# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.

# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy). Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!

# * Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?

# * In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).

# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
cities=[]
rand_lat_lngs=[]

rand_lat= np.linspace(-90,90,num=5000)
rand_lng= np.linspace(-180,180,num=5000)

latt=np.random.uniform(rand_lat)
lngg=np.random.uniform(rand_lng)

rand_lat_lngs=zip(latt,lngg)

for rand_lat_lng in rand_lat_lngs:
    city = citipy.nearest_city(rand_lat_lng[0], rand_lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
pprint(cities)
# Out:
# ['puerto ayora',
#  'rikitea',
#  'coquimbo',
#  'punta arenas',
#  'georgetown',
#  'campestre',
#  'barras',
#  'faanui',
#  'hermanus',
#  'mataura',
#  'cape town',
#  'castro',
#  'lebu',
#  'atuona',
#  'ushuaia',
#  'vallenar',
#  'necochea',
#  'mar del plata',
#  'vaini',
#  'avera',
#  'jamestown',
#  'laguna',
#  'omboue',
#  'san ramon',
#  'caravelas',
#  'belmonte',
#  'samusu',
#  'macau',
#  'paita',
#  'chuy',
#  'bom jesus',
#  'avarua',
#  'jacareacanga',
#  'arraial do cabo',
#  'chilca',
#  'teahupoo',
#  'pangoa',
#  'tapes',
#  'cidreira',
#  'goianesia',
#  'tonantins',
#  'barra do corda',
#  'maragogi',
#  'solano',
#  'rocha',
#  'valparaiso',
#  'ancud',
#  'japura',
#  'talcahuano',
#  'rio grande',
#  'vila velha',
#  'santa rosa',
#  'hualmay',
#  'xique-xique',
#  'pisco',
#  'marcona',
#  'olinda',
#  'alofi',
#  'diego de almagro',
#  'jaicos',
#  'viedma',
#  'ilhabela',
#  'cabedelo',
#  'moyobamba',
#  'rolim de moura',
#  'archidona',
#  'soledade',
#  'puerto leguizamo',
#  'san lorenzo',
#  'parana',
#  'porto nacional',
#  'calama',
#  'iquitos',
#  'comodoro rivadavia',
#  'salinas',
#  'sao felix do xingu',
#  'rawson',
#  'manta',
#  'parnamirim',
#  'sao raimundo nonato',
#  'luderitz',
#  'araguaina',
#  'maceio',
#  'axim',
#  'acari',
#  'mulchen',
#  'purranque',
#  'touros',
#  'ascension',
#  'alto araguaia',
#  'concordia',
#  'santo anastacio',
#  'copiapo',
#  'dolores',
#  'loanda',
#  'neuquen',
#  'san cristobal',
#  'filadelfia',
#  'araguari',
#  'saldanha',
#  'porto walter',
#  'puerto quijarro',
#  'paso de los toros',
#  'sao joao de pirabas',
#  'barra do garcas',
#  'camapua',
#  'amarante do maranhao',
#  'sume',
#  'san rafael',
#  'bom jesus da lapa',
#  'santa elena',
#  'lincoln',
#  'sao francisco',
#  'aripuana',
#  'linhares',
#  'chicama',
#  'sao luiz gonzaga',
#  'borba',
#  'bom jardim',
#  'ipixuna',
#  'conde',
#  'fonte boa',
#  'lagunas',
#  'constitucion',
#  'piacabucu',
#  'chimbote',
#  'santa vitoria do palmar',
#  'santa isabel do rio negro',
#  'sao joao da barra',
#  'gualeguay',
#  'pimentel',
#  'harper',
#  'concepcion',
#  'santa maria do para',
#  'coihaique',
#  'sechura',
#  'mercedes',
#  'mancio lima',
#  'tabou',
#  'carauari',
#  'pillaro',
#  'imbituba',
#  'requena',
#  'san jose',
#  'natal',
#  'santa cecilia',
#  'araruama',
#  'tamandare',
#  'huarmey',
#  'rio gallegos',
#  'aracati',
#  'villamontes',
#  'alta floresta',
#  'pauini',
#  'fortuna',
#  'coahuayana',
#  'cerrito',
#  'bataipora',
#  'vilhena',
#  'rio cuarto',
#  'mazagao',
#  'prainha',
#  'catamarca',
#  'padre bernardo',
#  'barcelos',
#  'bahia blanca',
#  'cunha',
#  'linares',
#  'mutum',
#  'teno',
#  'brasilia de minas',
#  'sena madureira',
#  'taltal',
#  'envira',
#  'itapirapua',
#  'barra',
#  'urucara',
#  'molina',
#  'aquiraz',
#  'mariana',
#  'canto do buriti',
#  'puerto madryn',
#  'cruzilia',
#  'jardim',
#  'takoradi',
#  'mayor pablo lagerenza',
#  'inhumas',
#  'sao jose da coroa grande',
#  'reconquista',
#  'casa nova',
#  'caiaponia',
#  'guajara',
#  'coracora',
#  'talara',
#  'carinhanha',
#  'niteroi',
#  'huaraz',
#  'picota',
#  'pitimbu',
#  'saquarema',
#  'moji das cruzes',
#  'mendoza',
#  'bahia de caraquez',
#  'salvador',
#  'itarema',
#  'samaipata',
#  'gualaquiza',
#  'camana',
#  'maraa',
#  'manicore',
#  'ituporanga',
#  'assare',
#  'petrolandia',
#  'coxim',
#  'colquechaca',
#  'presidente olegario',
#  'san borja',
#  'santiago del estero',
#  'maravilha',
#  'joao pinheiro',
#  'curuguaty',
#  'manacapuru',
#  'general roca',
#  'oriximina',
#  'contamana',
#  'itaueira',
#  'benjamin constant',
#  'sao raimundo das mangabeiras',
#  'cacapava do sul',
#  'jutai',
#  'grajau',
#  'serra',
#  'sitio novo do tocantins',
#  'nioaque',
#  'las lomas',
#  'huancavelica',
#  'humaita',
#  'sao gabriel da cachoeira',
#  'pinhao',
#  'ararangua',
#  'lima',
#  'sucre',
#  'contagem',
#  'sao pedro do sul',
#  'olavarria',
#  'calbuco',
#  'ariquemes',
#  'labrea',
#  'uyuni',
#  'sao borja',
#  'carolina',
#  'sao miguel do araguaia',
#  'pontes e lacerda',
#  'guapiacu',
#  'urucui',
#  'itarare',
#  'cruz alta',
#  'buchanan',
#  'rio branco',
#  'formoso do araguaia',
#  'tocopilla',
#  'camacari',
#  'san carlos de bariloche',
#  'ribeiropolis',
#  'arinos',
#  'manaus',
#  'iberia',
#  'vacaria',
#  'chimore',
#  'iquique',
#  'macaubas',
#  'la rioja',
#  'chincha alta',
#  'riachao das neves',
#  'capitan bado',
#  'luis correia',
#  'riachao',
#  'rosa zarate',
#  'pozo colorado',
#  'barretos',
#  'costa rica',
#  'carahue',
#  'eirunepe',
#  'san joaquin',
#  'minas',
#  'frutal',
#  'oxapampa',
#  'nova olinda do norte',
#  'porto de moz',
#  'abaete',
#  'caucaia',
#  'salinopolis',
#  'salamanca',
#  'sao desiderio',
#  'paranapanema',
#  'tarauaca',
#  'almeirim',
#  'alta gracia',
#  'betanzos',
#  'uchiza',
#  'corinto',
#  'nova olimpia',
#  'sao bento',
#  'boyuibe',
#  'porangatu',
#  'tres lagoas',
#  'rafaela',
#  'tucuman',
#  'san pedro',
#  'fuerte olimpo',
#  'altamira',
#  'pires do rio',
#  'presidencia roque saenz pena',
#  'canutama',
#  'turiacu',
#  'porto velho',
#  'picos',
#  'iacu',
#  'porto murtinho',
#  'san luis',
#  'itaituba',
#  'jujuy',
#  'registro',
#  'bom despacho',
#  'treinta y tres',
#  'villa carlos paz',
#  'navirai',
#  'boa esperanca',
#  'esperantina',
#  'diamantino',
#  'pilar',
#  'brumadinho',
#  'naranjal',
#  'doctor pedro p. pena',
#  'candido mendes',
#  'salta',
#  'melo',
#  'torres',
#  'maraba',
#  'resistencia',
#  'ouricuri',
#  'rio verde de mato grosso',
#  'araguacu',
#  'acara',
#  'aparecida do taboado',
#  'conceicao da barra',
#  'formosa do rio preto',
#  'morros',
#  'itupiranga',
#  'tucurui',
#  'diamantina',
#  'port-gentil',
#  'sao joao dos patos',
#  'niquelandia',
#  'foz do iguacu',
#  'cururupu',
#  'chapada dos guimaraes',
#  'acajutiba',
#  'palmas',
#  'laranjeiras do sul',
#  'jequie',
#  'cacador',
#  'caxias',
#  'livramento',
#  'riachao do jacuipe',
#  'santo antonio',
#  'eldorado',
#  'salgueiro',
#  'irece',
#  'limoeiro do ajuru',
#  'corrente',
#  'esmeraldas',
#  'nisia floresta',
#  'coruripe',
#  'nilopolis',
#  'carutapera',
#  'rio novo',
#  'itamaraca',
#  'buriti alegre',
#  'mattru',
#  'bocaiuva',
#  'ibia',
#  'armacao dos buzios',
#  'dianopolis',
#  'araripina',
#  'parati',
#  'sao joao evangelista',
#  'oeiras',
#  'mar de espanha',
#  'correntina',
#  'pimenteiras',
#  'barreirinhas',
#  'itinga',
#  'america dourada',
#  'monrovia',
#  'joaima',
#  'acarau',
#  'campo formoso',
#  'prado',
#  'caraubas',
#  'caico',
#  'porto seguro',
#  'puxinana',
#  'san-pedro',
#  'grand-lahou',
#  'cape coast',
#  'sassandra',
#  'mumford',
#  'winneba',
#  'anloga',
#  'yenagoa',
#  'cotonou',
#  'abonnema',
#  'libreville',
#  'luba',
#  'mbini',
#  'opobo',
#  'warri',
#  'kribi',
#  'cocobeach',
#  'malabo',
#  'bata',
#  'evinayong',
#  'aneho',
#  'lagos',
#  'oron',
#  'foumbot',
#  'bafia',
#  'owerri',
#  'akonolinga',
#  'ouidah',
#  'calabar',
#  'onitsha',
#  'sangmelima',
#  'eseka',
#  'abong mbang',
#  'akom',
#  'doume',
#  'amaigbo',
#  'sembe',
#  'riaba',
#  'kumba',
#  'mbalmayo',
#  'nanga eboko',
#  'ambam',
#  'banyo',
#  'garoua boulai',
#  'batouri',
#  'lolodorf',
#  'ngaoundere',
#  'oyem',
#  'tsevie',
#  'poli',
#  'monatele',
#  'asaba',
#  'yokadouma',
#  'carnot',
#  'wukari',
#  'ouesso',
#  'gboko',
#  'tibati',
#  'aba',
#  'nsukka',
#  'notse',
#  'betare oya',
#  'bossembele',
#  'bitam',
#  'sapele',
#  'bouca',
#  'bertoua',
#  'lafia',
#  'parakou',
#  'acurenam',
#  'impfondo',
#  'agbor',
#  'bocaranga',
#  'aconibe',
#  'meiganga',
#  'kagoro',
#  'sarh',
#  'kishi',
#  'numan',
#  'jimeta',
#  'atakpame',
#  'mbouda',
#  'yagoua',
#  'kouango',
#  'limbe',
#  'jalingo',
#  'obala',
#  'otukpo',
#  'jos',
#  'ode',
#  'tignere',
#  'lafiagi',
#  'ndele',
#  'guelengdeng',
#  'goundi',
#  'moissala',
#  'lere',
#  'am timan',
#  'bosobolo',
#  'kembe',
#  'boda',
#  'nola',
#  'bouar',
#  'bimbo',
#  'mobaye',
#  'dekoa',
#  'basoko',
#  'awka',
#  'bossangoa',
#  'bambari',
#  'azare',
#  'hadejia',
#  'ouadda',
#  'kabo',
#  'gemena',
#  'raga',
#  'beboto',
#  'savalou',
#  'bauchi',
#  'yangambi',
#  'minna',
#  'birao',
#  'oka',
#  'bongandanga',
#  'guider',
#  'mbaiki',
#  'bol',
#  'mubi',
#  'buta',
#  'babanusah',
#  'zaria',
#  'dosso',
#  'ketou',
#  'mfou',
#  'bitkine',
#  'obo',
#  'rafai',
#  'isiro',
#  'yabassi',
#  'kaduna',
#  'adre',
#  'moussoro',
#  'lisala',
#  'baboua',
#  'diffa',
#  'businga',
#  'epe',
#  'sotouboua',
#  'ife',
#  'bondo',
#  'kontagora',
#  'bumba',
#  'duku',
#  'gogrial',
#  'akure',
#  'bousso',
#  'gashua',
#  'loum',
#  'bara',
#  'pala',
#  'bentiu',
#  'tessaoua',
#  'umm kaddadah',
#  'wum',
#  'uwayl',
#  'biltine',
#  'yambio',
#  'mao',
#  'oum hadjer',
#  'kisangani',
#  'bangassou',
#  'gaya',
#  'kutum',
#  'paoua',
#  'nkoteng',
#  'gulu',
#  'wamba',
#  'tchollire',
#  'grimari',
#  'tahoua',
#  'ouango',
#  'ati',
#  'gao',
#  'damara',
#  'mongo',
#  'gambela',
#  'dakoro',
#  'filingue',
#  'arua',
#  'gusau',
#  'maridi',
#  'marabba',
#  'gbadolite',
#  'zemio',
#  'diapaga',
#  'illela',
#  'bongor',
#  'kano',
#  'abu jubayhah',
#  'malanville',
#  'tanout',
#  'umm durman',
#  'ekpoma',
#  'arlit',
#  'faya',
#  'gondar',
#  'shambu',
#  'binga',
#  'marawi',
#  'himora',
#  'dutse',
#  'tawkar',
#  'masindi',
#  'kaduqli',
#  'nikki',
#  'wad rawah',
#  'beni',
#  'gambo',
#  'bouza',
#  'suleja',
#  'rabak',
#  'ikole',
#  'mizan teferi',
#  'abalak',
#  'ginda',
#  'maine-soroa',
#  'nguru',
#  'kitgum',
#  'kousseri',
#  'bafilo',
#  'kidal',
#  'bilma',
#  'goure',
#  'natitingou',
#  'agadez',
#  'nazret',
#  'moyale',
#  'wajir',
#  'bassila',
#  'gelemso',
#  'jijiga',
#  'juba',
#  'biu',
#  'boali',
#  'aswan',
#  'sinkat',
#  'baoro',
#  'jizan',
#  'owo',
#  'wajid',
#  'ginir',
#  'addi ugri',
#  'bajil',
#  'mandera',
#  'marsabit',
#  'gat',
#  'abeche',
#  'kollo',
#  'najran',
#  'bedesa',
#  'teseney',
#  'tessalit',
#  'wagar',
#  'abiy adi',
#  'kotido',
#  'dourbali',
#  'sayyan',
#  'asyut',
#  'marzuq',
#  'mecca',
#  'bako',
#  'bembereke',
#  'apomu',
#  'makokou',
#  'pindiga',
#  'sabya',
#  'jiddah',
#  'sawakin',
#  'barbar',
#  'riyadh',
#  'tahta',
#  'wanlaweyn',
#  'barawe',
#  'djougou',
#  'lagdo',
#  'mogadishu',
#  'kapoeta',
#  'abu samrah',
#  'bahir dar',
#  'bosaso',
#  'salalah',
#  'sohag',
#  'dogondoutchi',
#  'jawhar',
#  'bure',
#  'hobyo',
#  'umm lajj',
#  'awjilah',
#  'eyl',
#  'deder',
#  'bandarbeyla',
#  'lodwar',
#  'watsa',
#  'khor',
#  'buqayq',
#  'doha',
#  'tabuk',
#  'berbera',
#  'hargeysa',
#  'edea',
#  'buraydah',
#  'ondo',
#  'ayorou',
#  'robe',
#  'matay',
#  'sabha',
#  'awbari',
#  'korem',
#  'odweyne',
#  'xuddur',
#  'edd',
#  'adrar',
#  'bargal',
#  'hurghada',
#  'mizdah',
#  'bereda',
#  'nedjo',
#  'massakory',
#  'lar',
#  'safwah',
#  'torit',
#  'jalu',
#  'dembi dolo',
#  'waddan',
#  'doka',
#  'bayan',
#  'bam',
#  'abu dhabi',
#  'benin',
#  'kyabe',
#  'akhmim',
#  'bayir',
#  'hun',
#  'yarim',
#  'warqla',
#  'malakal',
#  'hit',
#  'kavaratti',
#  'sur',
#  'victoria',
#  'sakakah',
#  'marsa matruh',
#  'ashqelon',
#  'garowe',
#  'asosa',
#  'bardiyah',
#  'boditi',
#  'ormara',
#  'bokoro',
#  'farah',
#  'jiblah',
#  'minab',
#  'fereydunshahr',
#  'surt',
#  'cove',
#  'porbandar',
#  'kulhudhuffushi',
#  'rudbar',
#  'afgoye',
#  'turbat',
#  'mahibadhoo',
#  'kudahuvadhoo',
#  'keffi',
#  'beirut',
#  'dabat',
#  'lar gerd',
#  'thinadhoo',
#  'nalut',
#  'benghazi',
#  'mirabad',
#  'kalat',
#  'elat',
#  'kashan',
#  'ajdabiya',
#  'darnah',
#  'tazmalt',
#  'gewane',
#  'mandali',
#  'dipkarpaz',
#  'abha',
#  'lalpur',
#  'adana',
#  'kibre mengist',
#  'dawlatabad',
#  'dwarka',
#  'tuggurt',
#  'umm bab',
#  'manavgat',
#  'eydhafushi',
#  'chabahar',
#  'dubti',
#  'candolim',
#  'ugoofaaru',
#  'shahrud',
#  'ayia galini',
#  'aflu',
#  'kifri',
#  'ergani',
#  'yithion',
#  'dire dawa',
#  'zabol',
#  'koutsouras',
#  'nahariyya',
#  'tabas',
#  'tukrah',
#  'borama',
#  'bhikangaon',
#  'bandar-e torkaman',
#  'gardan diwal',
#  'shache',
#  'birnin kebbi',
#  'ardakan',
#  'radhanpur',
#  'castrovillari',
#  'netivot',
#  'matara',
#  'iglesias',
#  'jimma',
#  'haifa',
#  'yafran',
#  'dhidhdhoo',
#  'bergama',
#  'alaca',
#  'guru har sahai',
#  'hoshangabad',
#  'emirdag',
#  'sharan',
#  'novaci',
#  'potiskum',
#  'leh',
#  'barentu',
#  'loni',
#  'suez',
#  'muyuka',
#  'maku',
#  'constantine',
#  'trapani',
#  'bria',
#  'tokat',
#  'poros',
#  'tando adam',
#  'sabirabad',
#  'misratah',
#  'panjakent',
#  'tarhunah',
#  'rath',
#  'qena',
#  'aksu',
#  'faridpur',
#  'agropoli',
#  'pokhara',
#  'korla',
#  'verkhneye kazanishche',
#  'baihar',
#  'lasa',
#  'murwara',
#  'kasauli',
#  'malwan',
#  'pullampadi',
#  'diu',
#  'vedi',
#  'haskovo',
#  'paradwip',
#  'hambantota',
#  'balkanabat',
#  'kazalinsk',
#  'hazorasp',
#  'berga',
#  'kuliyapitiya',
#  'yanam',
#  'zhob',
#  'ponnani',
#  'allapalli',
#  'mondovi',
#  'gangotri',
#  'rostaq',
#  'ludhiana',
#  'mathbaria',
#  'karauzyak',
#  'shihezi',
#  'tasbuget',
#  'zabid',
#  'esfahan',
#  'astipalaia',
#  'stefan cel mare',
#  'methoni',
#  'mincivan',
#  'zhezkazgan',
#  'kuche',
#  'torbat-e jam',
#  'kerman',
#  'montemarciano',
#  'alizai',
#  'mileai',
#  'saryozek',
#  'sarab',
#  'bandarban',
#  'pobe',
#  'malko tarnovo',
#  'murgab',
#  'batticaloa',
#  'atyrau',
#  'visegrad',
#  'sabla',
#  'aleppo',
#  'sokoto',
#  'marsaxlokk',
#  'nurota',
#  'shahdadkot',
#  'phuntsholing',
#  'gopalpur',
#  'mortara',
#  'mangrol',
#  'mongoumba',
#  'qandahar',
#  'tubruq',
#  'ngama',
#  'mokokchung',
#  'mendi',
#  'adamas',
#  'san lawrenz',
#  'potenza',
#  'beyneu',
#  'raniganj',
#  'pop',
#  'umm ruwabah',
#  'van',
#  'fushe-arrez',
#  'senovo',
#  'hovd',
#  'mugur-aksy',
#  'sinjar',
#  'jumla',
#  'dindori',
#  'tastur',
#  'yazman',
#  'urdzhar',
#  'changji',
#  'zonguldak',
#  'kharsawan',
#  'dalbandin',
#  'kungurtug',
#  'sfantu gheorghe',
#  'kalmunai',
#  'ibra',
#  'manavalakurichi',
#  'buzmeyin',
#  'kattivakkam',
#  'turkistan',
#  'neyshabur',
#  'zaysan',
#  'sabang',
#  'balrampur',
#  'pathein',
#  'hami',
#  'abyek',
#  'orlik',
#  'rijeka',
#  'galle',
#  'golkoy',
#  'ciresu',
#  'bijapur',
#  'keti bandar',
#  'biaora',
#  'trincomalee',
#  'muli',
#  'verdikoussa',
#  'berezhany',
#  'pervoye maya',
#  'ye',
#  'panjab',
#  'alexandria',
#  'viytivka',
#  'yasnyy',
#  'mordovo',
#  'meulaboh',
#  'balgazyn',
#  'cairo',
#  'along',
#  'lancut',
#  'hirson',
#  'kyzyl-suu',
#  'algiers',
#  'alghero',
#  'yinchuan',
#  'derzhavinsk',
#  'mykhaylivka',
#  'moratuwa',
#  'phrai bung',
#  'tatvan',
#  'kharabali',
#  'jhinjhak',
#  'aleksandrov gay',
#  'kijang',
#  'pavullo nel frignano',
#  'asarganj',
#  'binzhou',
#  'manadhoo',
#  'kavarna',
#  'beni suef',
#  'pula',
#  'iranshahr',
#  'joshimath',
#  'merke',
#  'aginskoye',
#  'limoges',
#  'kavant',
#  'xam nua',
#  'abu zabad',
#  'khagrachari',
#  'beli potok',
#  'contai',
#  'balti',
#  'veraval',
#  'locri',
#  'karsiyang',
#  'port blair',
#  'esna',
#  'puri',
#  'kazachinskoye',
#  'of',
#  'dubenskiy',
#  'maykain',
#  'marang',
#  'pasni',
#  'basqal',
#  'asopos',
#  'garmsar',
#  'venta',
#  'khormuj',
#  'wladyslawowo',
#  'uyskoye',
#  'selaphum',
#  'wadi musa',
#  'tezu',
#  'yumen',
#  'wattegama',
#  'sarakhs',
#  'svetlyy',
#  'mut',
#  'dongsheng',
#  'baijiantan',
#  'jaisalmer',
#  'hatvan',
#  'sainte-savine',
#  'yichang',
#  'pousat',
#  'jibuti',
#  'sibenik',
#  'karachi',
#  'sahbuz',
#  'manzil salim',
#  'banda aceh',
#  'yanchukan',
#  'bacuit',
#  'kashi',
#  'yurino',
#  'micomeseng',
#  'shubarshi',
#  'kurush',
#  'oboyan',
#  'malumfashi',
#  'kyra',
#  'koltsovo',
#  'urumqi',
#  'aborlan',
#  'xingcheng',
#  'dera bugti',
#  'erzin',
#  'gallipoli',
#  'xichang',
#  'ushtobe',
#  'manzhouli',
#  'kilemary',
#  'paka',
#  'erenhot',
#  'tartus',
#  'weinan',
#  'manali',
#  'ninghai',
#  'lhokseumawe',
#  'great yarmouth',
#  'phuket',
#  'saraza',
#  'panzhihua',
#  'champasak',
#  'kohlu',
#  'mata',
#  'balagansk',
#  'at-bashi',
#  'oytal',
#  'bhalwal',
#  'emba',
#  'biograd na moru',
#  'mikhaylovskoye',
#  'nikolsk',
#  'sibu',
#  'moron',
#  'tori fatehpur',
#  'do gonbadan',
#  'jiayuguan',
#  'dien bien',
#  'kizema',
#  'darhan',
#  'nokha',
#  'lat yao',
#  'carbonia',
#  'madinat sittah uktubar',
#  'soligalich',
#  'mullaitivu',
#  'starokozache',
#  'mahon',
#  'tananger',
#  'nong chik',
#  'shamkhal',
#  'ancona',
#  'mariinsk',
#  'aksehir',
#  'jiazi',
#  'yongan',
#  'jieshi',
#  'zlobin',
#  'narva-joesuu',
#  'bolshegrivskoye',
#  'alibag',
#  'darab',
#  'ilorin',
#  'butwal',
#  'voznesenye',
#  'buon me thuot',
#  'privolnyy',
#  'jining',
#  'srivardhan',
#  'basco',
#  'staritsa',
#  'carpentras',
#  'wachtersbach',
#  'ghauspur',
#  'virtsu',
#  'xianshuigu',
#  'tanta',
#  'mach',
#  'dologon',
#  'zeya',
#  'kinanah',
#  'ulaanbaatar',
#  'narasannapeta',
#  'xiangdong',
#  'kyzyl',
#  'kabanjahe',
#  'ranong',
#  'navahrudak',
#  'koraput',
#  'terbuny',
#  'xinzhou',
#  'kauhajoki',
#  'lichuan',
#  'kondratovo',
#  'huinan',
#  'ludvika',
#  'upleta',
#  'jiujiang',
#  'den helder',
#  'yomitan',
#  'kodinsk',
#  'bojnurd',
#  'krasnoselkup',
#  'makat',
#  'nanzhang',
#  'guilin',
#  'chenghai',
#  'beya',
#  'turtkul',
#  'ustye',
#  'mawlaik',
#  'adwa',
#  'georgiyevka',
#  'gurlan',
#  'lyubar',
#  'ningxiang',
#  'paullo',
#  'eregli',
#  'nizhniy odes',
#  'tommot',
#  'gayny',
#  'rey bouba',
#  'vestbygda',
#  'krasnousolskiy',
#  'krasnogvardeyskoye',
#  'bridlington',
#  'strezhevoy',
#  'babu',
#  'balykshi',
#  'ravar',
#  'tura',
#  'weihe',
#  'mezhdurechensk',
#  'pavlovsk',
#  'gomel',
#  'amga',
#  'lazurne',
#  'susaki',
#  'pangody',
#  'baykit',
#  'xining',
#  'genhe',
#  'uddevalla',
#  'dalinghe',
#  'severomuysk',
#  'linqiong',
#  'batagay-alyta',
#  'lulea',
#  'zyryanovsk',
#  'kandri',
#  'namtsy',
#  'ust-koksa',
#  'lukow',
#  'yar-sale',
#  'yuli',
#  'kuusamo',
#  'oktyabrskiy',
#  'cabra',
#  'nong bua',
#  'tanabe',
#  'pingliang',
#  'nishihara',
#  'yugo-kamskiy',
#  'vilani',
#  'kushima',
#  'mangaldai',
#  'popovo',
#  'jishu',
#  'zhigansk',
#  'wajima',
#  'mirnyy',
#  'sabzevar',
#  'yei',
#  'luchegorsk',
#  'akyab',
#  'sitangkai',
#  'makinsk',
#  'shingu',
#  'seoul',
#  'pantai remis',
#  'kaseda',
#  'bijar',
#  'kollumerland',
#  'chulym',
#  'gorno-chuyskiy',
#  'fevralsk',
#  'baglan',
#  'amurzet',
#  'fuldatal',
#  'tsagan aman',
#  'stryn',
#  'bolshoy kamen',
#  'nykobing',
#  'zunyi',
#  'tuy hoa',
#  'manvi',
#  'severo-yeniseyskiy',
#  'rafsanjan',
#  'rawah',
#  'catuday',
#  'tigzirt',
#  'khandyga',
#  'kampot',
#  'karmana',
#  'damaturu',
#  'jiaonan',
#  'yarada',
#  'listvyanskiy',
#  'davila',
#  'lugovskiy',
#  'uvarovka',
#  'svetlogorsk',
#  'gorkovskoye',
#  'el badari',
#  'ornskoldsvik',
#  'syracuse',
#  'aykhal',
#  'kologriv',
#  'hutang',
#  'kirensk',
#  'bolshaya murta',
#  'nyurba',
#  'larap',
#  'volkhovskiy',
#  'rayachoti',
#  'pemangkat',
#  'tak',
#  'rayadrug',
#  'airai',
#  'kuah',
#  'zhanatas',
#  'nizhniy lomov',
#  'tortoli',
#  'lensk',
#  'ukwa',
#  'buluang',
#  'magdagachi',
#  'tiruppur',
#  'mergui',
#  'qabis',
#  'dehloran',
#  'kuytun',
#  'kota bahru',
#  'molde',
#  'zatoka',
#  'marand',
#  'karakendzha',
#  'cabadiangan',
#  'porto empedocle',
#  'khonuu',
#  'balabac',
#  'kamenka',
#  'yulin',
#  'aktash',
#  'gremyachinsk',
#  'artvin',
#  'tynda',
#  'katsuura',
#  'zaltan',
#  'sembakung',
#  'olga',
#  'kytlym',
#  'belushya guba',
#  'lanas',
#  'vershino-shakhtaminskiy',
#  'satuk',
#  'chumikan',
#  'sodertalje',
#  'umba',
#  'nenjiang',
#  'dandong',
#  'shenjiamen',
#  'tolga',
#  'xuanhua',
#  'cheremukhovo',
#  'myitkyina',
#  'nogliki',
#  'skjervoy',
#  'biak',
#  'svetlaya',
#  'takhtamygda',
#  'hirara',
#  'verkhnyaya inta',
#  'kumluca',
#  'agirish',
#  'naze',
#  'khatanga',
#  'arman',
#  'labutta',
#  'meiningen',
#  'preobrazheniye',
#  'sanchazi',
#  'kuala krai',
#  'nizhneyansk',
#  'berlevag',
#  'kelamangalam',
#  'amderma',
#  'cao bang',
#  'ondorhaan',
#  'namuac',
#  'aci castello',
#  'ostrovnoy',
#  'hailar',
#  'ha tinh',
#  'hendijan',
#  'ayni',
#  'kilmez',
#  'cantavir',
#  'kemijarvi',
#  'galgani',
#  'ksenyevka',
#  'shieli',
#  'sorland',
#  'bolshaya irba',
#  'ono',
#  'havoysund',
#  'kloulklubed',
#  'yining',
#  'langarud',
#  'gospic',
#  'petropavlovka',
#  'kudchi',
#  'zanjan',
#  'serebryanyy bor',
#  'ebebiyin',
#  'nha trang',
#  'minsk',
#  'karaul',
#  'pyapon',
#  'zmiyiv',
#  'dikson',
#  'hasaki',
#  'tha chang',
#  'ternate',
#  'kamaishi',
#  'salym',
#  'tiruvottiyur',
#  'ussel',
#  'lerwick',
#  'ciolpani',
#  'verkhnevilyuysk',
#  'da nang',
#  'yarensk',
#  'cam ranh',
#  'darlawn',
#  'wenling',
#  'novosergiyevka',
#  'gilazi',
#  'sentyabrskiy',
#  'bud',
#  'muscat',
#  'gazanjyk',
#  'remicourt',
#  'khuzhir',
#  'tet',
#  'simbahan',
#  'alingsas',
#  'vardo',
#  'khabary',
#  'wunsiedel',
#  'vershino-darasunskiy',
#  'terney',
#  'mangile',
#  'stege',
#  'dicabisagan',
#  'bushehr',
#  'severobaykalsk',
#  'tiksi',
#  'honningsvag',
#  'ozgon',
#  'longyearbyen',
#  'kargil',
#  'chokurdakh',
#  'zhanakorgan',
#  'barentsburg',
#  'payo',
#  'qui nhon',
#  'zdvinsk',
#  'linxia',
#  'jagatsinghapur',
#  'bosansko grahovo',
#  'lipari',
#  'tatarsk',
#  'shalakusha',
#  'gravdal',
#  'sirnak',
#  'urengoy',
#  'namatanai',
#  'shubarkuduk',
#  'kavieng',
#  'dagda',
#  'tumannyy',
#  'ust-ilimsk',
#  'chulman',
#  'komyshnya',
#  'kumla',
#  'razole',
#  'wuxi',
#  'severo-kurilsk',
#  'mama',
#  'lieksa',
#  'ainazi',
#  'sita buzaului',
#  'kota belud',
#  'dukat',
#  'bulaevo',
#  'ortakoy',
#  'yaan',
#  'qandala',
#  'yunjinghong',
#  'bagdarin',
#  'okha',
#  'pont-saint-esprit',
#  'ust-kuyga',
#  'andenes',
#  'romilly-sur-seine',
#  'kautokeino',
#  'pravda',
#  'mehamn',
#  'kargasok',
#  'kadykchan',
#  'sevsk',
#  'san isidro',
#  'ca mau',
#  'kuandian',
#  'makung',
#  'mersing',
#  'nikolskoye',
#  'nalgonda',
#  'pevek',
#  'srednekolymsk',
#  'pizhanka',
#  'butaritari',
#  'imeni babushkina',
#  'magistralnyy',
#  'aden',
#  'herzberg',
#  'cherskiy',
#  'naliya',
#  'san policarpo',
#  'tokur',
#  'atsiki',
#  'deputatskiy',
#  'bilibino',
#  'temryuk',
#  'ust-kamchatsk',
#  'kemin',
#  'altay',
#  'talnakh',
#  'mormugao',
#  'dongying',
#  'vanimo',
#  'vuktyl',
#  'muhos',
#  'phun phin',
#  'cirpan',
#  'loukhi',
#  'yerbogachen',
#  'komsomolskiy',
#  'saskylakh',
#  'marfino',
#  'kedrovyy',
#  'dahegam',
#  'aguada',
#  'phan rang',
#  'kwidzyn',
#  'bressanone',
#  'pavilosta',
#  'rognan',
#  'trud',
#  'tashtagol',
#  'zapolyarnyy',
#  'lorengau',
#  'shiyan',
#  'gorontalo',
#  'mutsu',
#  'wanning',
#  'ekhabi',
#  'mizpe ramon',
#  'shitanjing',
#  'tahe',
#  'sarkand',
#  'lao cai',
#  'dudinka',
#  'shimoda',
#  'petropavlovsk-kamchatskiy',
#  'taburao',
#  'sayanogorsk',
#  'roald',
#  'surab',
#  'ust-nera',
#  'langsa',
#  'rungata',
#  'dehra dun',
#  'khani',
#  'kobelyaky']

# %%
# OpenWeatherMap API Key
api_key = api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Loop through the list of cities and perform a request for data on each

latss = []
longss = []
humidity = []
tempature=[]
cloud = []
wind = []
cities_list = []
country_list = []
id_list = []
cloud_percent = []

for city in cities:
    response = requests.get(query_url + city).json()
    pprint(response)
    if response["cod"] != "404":
        latss.append(response['coord']['lat'])
        longss.append(response['coord']['lon'])
        humidity.append(response["main"]["humidity"])
        tempature.append(response["main"]["temp"])
        cloud.append(response['weather'][0]['description'])
        wind.append(response["wind"]["speed"])
        cities_list.append(response["name"])
        country_list.append(response["sys"]["country"])
        id_list.append(response["id"])
        cloud_percent.append(response["clouds"]["all"])
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -43.3, 'lon': -65.11},
#  'dt': 1535427939,
#  'id': 3839307,
#  'main': {'grnd_level': 1009.63,
#           'humidity': 37,
#           'pressure': 1009.63,
#           'sea_level': 1020.8,
#           'temp': 54.4,
#           'temp_max': 54.4,
#           'temp_min': 54.4},
#  'name': 'Rawson',
#  'sys': {'country': 'AR',
#          'message': 0.0036,
#          'sunrise': 1535453615,
#          'sunset': 1535493013},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 261.5, 'speed': 11.88}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1535425200,
#  'id': 3874787,
#  'main': {'humidity': 80,
#           'pressure': 983,
#           'temp': 35.6,
#           'temp_max': 35.6,
#           'temp_min': 35.6},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 4642,
#          'message': 0.0034,
#          'sunrise': 1535455868,
#          'sunset': 1535493557,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1535427940,
#  'id': 4030556,
#  'main': {'grnd_level': 1030.38,
#           'humidity': 100,
#           'pressure': 1030.38,
#           'sea_level': 1030.44,
#           'temp': 72.85,
#           'temp_max': 72.85,
#           'temp_min': 72.85},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0039,
#          'sunrise': 1535469227,
#          'sunset': 1535510907},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 7.50031, 'speed': 8.97}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.69, 'lon': -53.46},
#  'dt': 1535427940,
#  'id': 3443061,
#  'main': {'grnd_level': 1033.87,
#           'humidity': 87,
#           'pressure': 1033.87,
#           'sea_level': 1035.47,
#           'temp': 49.09,
#           'temp_max': 49.09,
#           'temp_min': 49.09},
#  'name': 'Chuy',
#  'sys': {'country': 'UY',
#          'message': 0.003,
#          'sunrise': 1535450213,
#          'sunset': 1535490814},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 13.5003, 'speed': 12.44}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1535427940,
#  'id': 1273574,
#  'main': {'grnd_level': 955.81,
#           'humidity': 99,
#           'pressure': 955.81,
#           'sea_level': 1020.68,
#           'temp': 69.25,
#           'temp_max': 69.25,
#           'temp_min': 69.25},
#  'name': 'Vaini',
#  'rain': {'3h': 1.945},
#  'sys': {'country': 'IN',
#          'message': 0.0029,
#          'sunrise': 1535417345,
#          'sunset': 1535462239},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 231.5, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1535425200,
#  'id': 4035715,
#  'main': {'humidity': 64,
#           'pressure': 1014,
#           'temp': 71.6,
#           'temp_max': 71.6,
#           'temp_min': 71.6},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 8340,
#          'message': 0.0037,
#          'sunrise': 1535475091,
#          'sunset': 1535516948,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -3.71, 'lon': -38.6},
#  'dt': 1535425200,
#  'id': 6320062,
#  'main': {'humidity': 83,
#           'pressure': 1015,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Vila Velha',
#  'sys': {'country': 'BR',
#          'id': 4498,
#          'message': 0.003,
#          'sunrise': 1535445286,
#          'sunset': 1535488584,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -21.84, 'lon': -44.81},
#  'dt': 1535427941,
#  'id': 3465071,
#  'main': {'grnd_level': 923.87,
#           'humidity': 91,
#           'pressure': 923.87,
#           'sea_level': 1037.98,
#           'temp': 54.4,
#           'temp_max': 54.4,
#           'temp_min': 54.4},
#  'name': 'Cruzilia',
#  'sys': {'country': 'BR',
#          'message': 0.0033,
#          'sunrise': 1535447543,
#          'sunset': 1535489322},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 106.5, 'speed': 6.4}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.46, 'lon': -66.82},
#  'dt': 1535427941,
#  'id': 3901903,
#  'main': {'grnd_level': 650.29,
#           'humidity': 42,
#           'pressure': 650.29,
#           'sea_level': 1029.72,
#           'temp': 21.82,
#           'temp_max': 21.82,
#           'temp_min': 21.82},
#  'name': 'Uyuni',
#  'sys': {'country': 'BO',
#          'message': 0.0031,
#          'sunrise': 1535452760,
#          'sunset': 1535494666},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 284.5, 'speed': 4.72}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1535425200,
#  'id': 3833367,
#  'main': {'humidity': 44,
#           'pressure': 978,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 4754,
#          'message': 0.0041,
#          'sunrise': 1535455429,
#          'sunset': 1535492752,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 17.22}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1535427942,
#  'id': 3652764,
#  'main': {'grnd_level': 1019.28,
#           'humidity': 99,
#           'pressure': 1019.28,
#           'sea_level': 1026.39,
#           'temp': 71.68,
#           'temp_max': 71.68,
#           'temp_min': 71.68},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'message': 0.0077,
#          'sunrise': 1535457583,
#          'sunset': 1535501120},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 171.5, 'speed': 12.77}}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1535427942,
#  'id': 6201424,
#  'main': {'grnd_level': 1018.39,
#           'humidity': 80,
#           'pressure': 1018.39,
#           'sea_level': 1033.93,
#           'temp': 47.92,
#           'temp_max': 47.92,
#           'temp_min': 47.92},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'message': 0.0036,
#          'sunrise': 1535397754,
#          'sunset': 1535436595},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 85.0003, 'speed': 19.6}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1535427942,
#  'id': 344979,
#  'main': {'grnd_level': 776.5,
#           'humidity': 95,
#           'pressure': 776.5,
#           'sea_level': 1025.01,
#           'temp': 51.07,
#           'temp_max': 51.07,
#           'temp_min': 51.07},
#  'name': 'Lebu',
#  'rain': {'3h': 2.48},
#  'sys': {'country': 'ET',
#          'message': 0.0032,
#          'sunrise': 1535426207,
#          'sunset': 1535470543},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 301, 'speed': 2.04}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -8.28, 'lon': -70.75},
#  'dt': 1535427942,
#  'id': 3661980,
#  'main': {'grnd_level': 1004.93,
#           'humidity': 88,
#           'pressure': 1004.93,
#           'sea_level': 1028.01,
#           'temp': 68.71,
#           'temp_max': 68.71,
#           'temp_min': 68.71},
#  'name': 'Tamandare',
#  'sys': {'country': 'BR',
#          'message': 0.0029,
#          'sunrise': 1535453186,
#          'sunset': 1535496117},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 139.5, 'speed': 2.48}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1535427942,
#  'id': 3471451,
#  'main': {'grnd_level': 1039.38,
#           'humidity': 97,
#           'pressure': 1039.38,
#           'sea_level': 1040.42,
#           'temp': 67.99,
#           'temp_max': 67.99,
#           'temp_min': 67.99},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'message': 0.0036,
#          'sunrise': 1535446926,
#          'sunset': 1535488601},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 122.5, 'speed': 9.19}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -16.7, 'lon': -151.02},
#  'dt': 1535427943,
#  'id': 4034496,
#  'main': {'grnd_level': 1024.3,
#           'humidity': 99,
#           'pressure': 1024.3,
#           'sea_level': 1025.5,
#           'temp': 79.51,
#           'temp_max': 79.51,
#           'temp_min': 79.51},
#  'name': 'Fare',
#  'sys': {'country': 'PF',
#          'message': 0.0033,
#          'sunrise': 1535472793,
#          'sunset': 1535515038},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 41.0003, 'speed': 11.99}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 41.42, 'lon': -6.55},
#  'dt': 1535427943,
#  'id': 2737599,
#  'main': {'grnd_level': 954.27,
#           'humidity': 94,
#           'pressure': 954.27,
#           'sea_level': 1027.49,
#           'temp': 57.1,
#           'temp_max': 57.1,
#           'temp_min': 57.1},
#  'name': 'Saldanha',
#  'rain': {'3h': 0.135},
#  'sys': {'country': 'PT',
#          'message': 0.0033,
#          'sunrise': 1535435302,
#          'sunset': 1535483142},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 63.0003, 'speed': 2.15}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -17.73, 'lon': -149.15},
#  'dt': 1535427000,
#  'id': 4033557,
#  'main': {'humidity': 65,
#           'pressure': 1012,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Tautira',
#  'sys': {'country': 'PF',
#          'id': 8343,
#          'message': 0.003,
#          'sunrise': 1535472389,
#          'sunset': 1535514546,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -21.64, 'lon': -41.05},
#  'dt': 1535427944,
#  'id': 3448903,
#  'main': {'grnd_level': 1039.14,
#           'humidity': 100,
#           'pressure': 1039.14,
#           'sea_level': 1039.2,
#           'temp': 71.41,
#           'temp_max': 71.41,
#           'temp_min': 71.41},
#  'name': 'Sao Joao da Barra',
#  'sys': {'country': 'BR',
#          'message': 0.0034,
#          'sunrise': 1535446632,
#          'sunset': 1535488428},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 147, 'speed': 18.25}}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -41.87, 'lon': -73.83},
#  'dt': 1535427944,
#  'id': 3899695,
#  'main': {'grnd_level': 1020.82,
#           'humidity': 94,
#           'pressure': 1020.82,
#           'sea_level': 1028.3,
#           'temp': 46.39,
#           'temp_max': 46.39,
#           'temp_min': 46.39},
#  'name': 'Ancud',
#  'sys': {'country': 'CL',
#          'message': 0.0059,
#          'sunrise': 1535455604,
#          'sunset': 1535495207},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 308.5, 'speed': 8.08}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.24, 'lon': -48.67},
#  'dt': 1535425200,
#  'id': 3461370,
#  'main': {'humidity': 87,
#           'pressure': 1027,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Imbituba',
#  'sys': {'country': 'BR',
#          'id': 4493,
#          'message': 0.0033,
#          'sunrise': 1535448775,
#          'sunset': 1535489948,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 330, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1535427944,
#  'id': 2069194,
#  'main': {'grnd_level': 973.64,
#           'humidity': 49,
#           'pressure': 973.64,
#           'sea_level': 1032.8,
#           'temp': 61.33,
#           'temp_max': 61.33,
#           'temp_min': 61.33},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0034,
#          'sunrise': 1535404131,
#          'sunset': 1535444725},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40.5003, 'speed': 13.78}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -9.01, 'lon': -35.22},
#  'dt': 1535427945,
#  'id': 3395458,
#  'main': {'grnd_level': 1021.95,
#           'humidity': 100,
#           'pressure': 1021.95,
#           'sea_level': 1030.57,
#           'temp': 72.22,
#           'temp_max': 72.22,
#           'temp_min': 72.22},
#  'name': 'Maragogi',
#  'rain': {'3h': 2.775},
#  'sys': {'country': 'BR',
#          'message': 0.0036,
#          'sunrise': 1535444692,
#          'sunset': 1535487561},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 133, 'speed': 9.64}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1535425200,
#  'id': 3369157,
#  'main': {'humidity': 93,
#           'pressure': 1028,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 6529,
#          'message': 0.0037,
#          'sunrise': 1535432990,
#          'sunset': 1535473541,
#          'type': 1},
#  'visibility': 8000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 40, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -31.63, 'lon': -71.17},
#  'dt': 1535427945,
#  'id': 3887344,
#  'main': {'grnd_level': 982.15,
#           'humidity': 100,
#           'pressure': 982.15,
#           'sea_level': 1031.05,
#           'temp': 48.73,
#           'temp_max': 48.73,
#           'temp_min': 48.73},
#  'name': 'Illapel',
#  'sys': {'country': 'CL',
#          'message': 0.0116,
#          'sunrise': 1535454347,
#          'sunset': 1535495177},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 186, 'speed': 2.37}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -27.23, 'lon': -56.22},
#  'dt': 1535425200,
#  'id': 3439156,
#  'main': {'humidity': 58,
#           'pressure': 1018,
#           'temp': 59,
#           'temp_max': 59,
#           'temp_min': 59},
#  'name': 'Carmen del Parana',
#  'sys': {'country': 'PY',
#          'id': 4727,
#          'message': 0.0034,
#          'sunrise': 1535450536,
#          'sunset': 1535491810,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -3.2, 'lon': -52.21},
#  'dt': 1535427946,
#  'id': 3407882,
#  'main': {'grnd_level': 1017.66,
#           'humidity': 85,
#           'pressure': 1017.66,
#           'sea_level': 1026.43,
#           'temp': 78.07,
#           'temp_max': 78.07,
#           'temp_min': 78.07},
#  'name': 'Altamira',
#  'sys': {'country': 'BR',
#          'message': 0.0031,
#          'sunrise': 1535448531,
#          'sunset': 1535491870},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 31.0003, 'speed': 3.27}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.17, 'lon': -50.22},
#  'dt': 1535427946,
#  'id': 3466165,
#  'main': {'grnd_level': 1026.9,
#           'humidity': 93,
#           'pressure': 1026.9,
#           'sea_level': 1037.38,
#           'temp': 50.44,
#           'temp_max': 50.44,
#           'temp_min': 50.44},
#  'name': 'Cidreira',
#  'sys': {'country': 'BR',
#          'message': 0.0029,
#          'sunrise': 1535449246,
#          'sunset': 1535490223},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 49.0003, 'speed': 11.1}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 30.3, 'lon': -99.24},
#  'dt': 1535426100,
#  'id': 4696310,
#  'main': {'humidity': 42,
#           'pressure': 1014,
#           'temp': 85.42,
#           'temp_max': 87.08,
#           'temp_min': 84.38},
#  'name': 'Harper',
#  'sys': {'country': 'US',
#          'id': 2613,
#          'message': 0.0047,
#          'sunrise': 1535458297,
#          'sunset': 1535504645,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 159.5, 'speed': 12.44}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -26.65, 'lon': 15.16},
#  'dt': 1535427947,
#  'id': 3355672,
#  'main': {'grnd_level': 1019.68,
#           'humidity': 64,
#           'pressure': 1019.68,
#           'sea_level': 1034.42,
#           'temp': 50.89,
#           'temp_max': 50.89,
#           'temp_min': 50.89},
#  'name': 'Luderitz',
#  'sys': {'country': 'NA',
#          'message': 0.0043,
#          'sunrise': 1535433388,
#          'sunset': 1535474701},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 148.5, 'speed': 12.77}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -42.48, 'lon': -73.76},
#  'dt': 1535427947,
#  'id': 3896218,
#  'main': {'grnd_level': 1012.14,
#           'humidity': 93,
#           'pressure': 1012.14,
#           'sea_level': 1027.04,
#           'temp': 46.39,
#           'temp_max': 46.39,
#           'temp_min': 46.39},
#  'name': 'Castro',
#  'sys': {'country': 'CL',
#          'message': 0.0032,
#          'sunrise': 1535455630,
#          'sunset': 1535495148},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 317.5, 'speed': 8.52}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -12.06, 'lon': -77.04},
#  'dt': 1535427784,
#  'id': 3936456,
#  'main': {'grnd_level': 878.39,
#           'humidity': 81,
#           'pressure': 878.39,
#           'sea_level': 1027.65,
#           'temp': 55.84,
#           'temp_max': 55.84,
#           'temp_min': 55.84},
#  'name': 'Lima',
#  'sys': {'country': 'PE',
#          'message': 0.0035,
#          'sunrise': 1535454851,
#          'sunset': 1535497474},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 133, 'speed': 2.26}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1535427947,
#  'id': 4020109,
#  'main': {'grnd_level': 1025.2,
#           'humidity': 99,
#           'pressure': 1025.2,
#           'sea_level': 1025.3,
#           'temp': 79.69,
#           'temp_max': 79.69,
#           'temp_min': 79.69},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0036,
#          'sunrise': 1535469629,
#          'sunset': 1535512442},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 85.0003, 'speed': 15.01}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1535427759,
#  'id': 3863379,
#  'main': {'grnd_level': 992.93,
#           'humidity': 50,
#           'pressure': 992.93,
#           'sea_level': 1014.39,
#           'temp': 50.26,
#           'temp_max': 50.26,
#           'temp_min': 50.26},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.0031,
#          'sunrise': 1535454432,
#          'sunset': 1535493356},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 287.5, 'speed': 22.39}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -13.71, 'lon': -76.2},
#  'dt': 1535425200,
#  'id': 3932145,
#  'main': {'humidity': 82,
#           'pressure': 1015,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Pisco',
#  'sys': {'country': 'PE',
#          'id': 4405,
#          'message': 0.0053,
#          'sunrise': 1535454718,
#          'sunset': 1535497204,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 6.93}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -41.32, 'lon': -72.98},
#  'dt': 1535425200,
#  'id': 3874930,
#  'main': {'humidity': 100,
#           'pressure': 1016,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Puerto Varas',
#  'sys': {'country': 'CL',
#          'id': 4672,
#          'message': 0.003,
#          'sunrise': 1535455363,
#          'sunset': 1535495040,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -21.48, 'lon': -56.15},
#  'dt': 1535427949,
#  'id': 3460087,
#  'main': {'grnd_level': 992.77,
#           'humidity': 70,
#           'pressure': 992.77,
#           'sea_level': 1030.81,
#           'temp': 64.84,
#           'temp_max': 64.84,
#           'temp_min': 64.84},
#  'name': 'Jardim',
#  'sys': {'country': 'BR',
#          'message': 0.0035,
#          'sunrise': 1535450247,
#          'sunset': 1535492060},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 84.5003, 'speed': 11.54}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1535425200,
#  'id': 3378644,
#  'main': {'humidity': 94,
#           'pressure': 1014,
#           'temp': 75.2,
#           'temp_max': 75.2,
#           'temp_min': 75.2},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'id': 4343,
#          'message': 0.0033,
#          'sunrise': 1535449550,
#          'sunset': 1535493699,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -17.73, 'lon': -39.27},
#  'dt': 1535427950,
#  'id': 3466980,
#  'main': {'grnd_level': 1035.73,
#           'humidity': 100,
#           'pressure': 1035.73,
#           'sea_level': 1035.71,
#           'temp': 73.66,
#           'temp_max': 73.66,
#           'temp_min': 73.66},
#  'name': 'Caravelas',
#  'rain': {'3h': 0.255},
#  'sys': {'country': 'BR',
#          'message': 0.0037,
#          'sunrise': 1535446031,
#          'sunset': 1535488172},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 134, 'speed': 16.24}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1535427950,
#  'id': 3366880,
#  'main': {'grnd_level': 1000.79,
#           'humidity': 100,
#           'pressure': 1000.79,
#           'sea_level': 1041.79,
#           'temp': 46.3,
#           'temp_max': 46.3,
#           'temp_min': 46.3},
#  'name': 'Hermanus',
#  'rain': {'3h': 0.56},
#  'sys': {'country': 'ZA',
#          'message': 0.0037,
#          'sunrise': 1535432821,
#          'sunset': 1535473317},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 312, 'speed': 3.83}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 4.87, 'lon': -2.24},
#  'dt': 1535427950,
#  'id': 2303611,
#  'main': {'grnd_level': 1023.98,
#           'humidity': 100,
#           'pressure': 1023.98,
#           'sea_level': 1026.31,
#           'temp': 75.37,
#           'temp_max': 75.37,
#           'temp_min': 75.37},
#  'name': 'Axim',
#  'sys': {'country': 'GH',
#          'message': 0.0033,
#          'sunrise': 1535436211,
#          'sunset': 1535480204},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 232.5, 'speed': 6.4}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24, 'lon': -51.32},
#  'dt': 1535427950,
#  'id': 3463573,
#  'main': {'grnd_level': 970.4,
#           'humidity': 81,
#           'pressure': 970.4,
#           'sea_level': 1035.88,
#           'temp': 52.33,
#           'temp_max': 52.33,
#           'temp_min': 52.33},
#  'name': 'Faxinal',
#  'sys': {'country': 'BR',
#          'message': 0.0037,
#          'sunrise': 1535449205,
#          'sunset': 1535490786},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 87.0003, 'speed': 9.19}}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -0.91, 'lon': -77.81},
#  'dt': 1535427951,
#  'id': 3660573,
#  'main': {'grnd_level': 854.48,
#           'humidity': 94,
#           'pressure': 854.48,
#           'sea_level': 1029.27,
#           'temp': 55.93,
#           'temp_max': 55.93,
#           'temp_min': 55.93},
#  'name': 'Archidona',
#  'sys': {'country': 'EC',
#          'message': 0.0033,
#          'sunrise': 1535454581,
#          'sunset': 1535498104},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 262.5, 'speed': 1.25}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -1.77, 'lon': -55.87},
#  'dt': 1535427951,
#  'id': 3393471,
#  'main': {'grnd_level': 1020.66,
#           'humidity': 96,
#           'pressure': 1020.66,
#           'sea_level': 1026.07,
#           'temp': 75.73,
#           'temp_max': 75.73,
#           'temp_min': 75.73},
#  'name': 'Oriximina',
#  'sys': {'country': 'BR',
#          'message': 0.0026,
#          'sunrise': 1535449351,
#          'sunset': 1535492806},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 36.5003, 'speed': 2.37}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -9.67, 'lon': -35.74},
#  'dt': 1535425200,
#  'id': 3395981,
#  'main': {'humidity': 94,
#           'pressure': 1018,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Maceio',
#  'sys': {'country': 'BR',
#          'id': 4538,
#          'message': 0.0038,
#          'sunrise': 1535444844,
#          'sunset': 1535487659,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 2.24}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -16.78, 'lon': -151.5},
#  'dt': 1535427951,
#  'id': 4033375,
#  'main': {'grnd_level': 1024.3,
#           'humidity': 99,
#           'pressure': 1024.3,
#           'sea_level': 1025.5,
#           'temp': 79.51,
#           'temp_max': 79.51,
#           'temp_min': 79.51},
#  'name': 'Tevaitoa',
#  'sys': {'country': 'PF',
#          'message': 0.0064,
#          'sunrise': 1535472911,
#          'sunset': 1535515150},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 41.0003, 'speed': 11.99}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -22.73, 'lon': -64.34},
#  'dt': 1535427951,
#  'id': 3923154,
#  'main': {'grnd_level': 964.8,
#           'humidity': 48,
#           'pressure': 964.8,
#           'sea_level': 1025.74,
#           'temp': 63.04,
#           'temp_max': 63.04,
#           'temp_min': 63.04},
#  'name': 'Bermejo',
#  'sys': {'country': 'AR',
#          'message': 0.0036,
#          'sunrise': 1535452269,
#          'sunset': 1535493970},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 34.5003, 'speed': 4.16}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -4.58, 'lon': -81.27},
#  'dt': 1535427952,
#  'id': 3691582,
#  'main': {'grnd_level': 1012.06,
#           'humidity': 91,
#           'pressure': 1012.06,
#           'sea_level': 1027.24,
#           'temp': 64.57,
#           'temp_max': 64.57,
#           'temp_min': 64.57},
#  'name': 'Talara',
#  'sys': {'country': 'PE',
#          'message': 0.0031,
#          'sunrise': 1535455560,
#          'sunset': 1535498789},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 202.5, 'speed': 5.73}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.47, 'lon': -87.06},
#  'dt': 1535424960,
#  'id': 4927537,
#  'main': {'humidity': 67,
#           'pressure': 1013,
#           'temp': 81.25,
#           'temp_max': 84.92,
#           'temp_min': 78.8},
#  'name': 'Valparaiso',
#  'sys': {'country': 'US',
#          'id': 1053,
#          'message': 0.0043,
#          'sunrise': 1535454634,
#          'sunset': 1535502447,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'gust': 8.2, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -26.24, 'lon': -48.64},
#  'dt': 1535427952,
#  'id': 3449112,
#  'main': {'grnd_level': 1037.6,
#           'humidity': 100,
#           'pressure': 1037.6,
#           'sea_level': 1041.35,
#           'temp': 57.19,
#           'temp_max': 57.19,
#           'temp_min': 57.19},
#  'name': 'Sao Francisco do Sul',
#  'sys': {'country': 'BR',
#          'message': 0.0044,
#          'sunrise': 1535448669,
#          'sunset': 1535490038},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 15.0003, 'speed': 6.62}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -16.19, 'lon': -67.73},
#  'dt': 1535425200,
#  'id': 3919085,
#  'main': {'humidity': 92,
#           'pressure': 1039,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Coroico',
#  'sys': {'country': 'BO',
#          'id': 4426,
#          'message': 0.0029,
#          'sunrise': 1535452792,
#          'sunset': 1535495068,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -0.42, 'lon': 102.29},
#  'dt': 1535427952,
#  'id': 1642773,
#  'main': {'grnd_level': 1013.85,
#           'humidity': 79,
#           'pressure': 1013.85,
#           'sea_level': 1025.46,
#           'temp': 80.14,
#           'temp_max': 80.14,
#           'temp_min': 80.14},
#  'name': 'Japura',
#  'sys': {'country': 'ID',
#          'message': 0.0033,
#          'sunrise': 1535411346,
#          'sunset': 1535454909},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180.5, 'speed': 2.93}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -12.24, 'lon': -41.62},
#  'dt': 1535427953,
#  'id': 3461023,
#  'main': {'grnd_level': 936.92,
#           'humidity': 89,
#           'pressure': 936.92,
#           'sea_level': 1032.19,
#           'temp': 62.05,
#           'temp_max': 62.05,
#           'temp_min': 62.05},
#  'name': 'Iraquara',
#  'rain': {'3h': 0.38},
#  'sys': {'country': 'BR',
#          'message': 0.0034,
#          'sunrise': 1535446361,
#          'sunset': 1535488966},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 123.5, 'speed': 7.74}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -45.58, 'lon': -72.07},
#  'dt': 1535425200,
#  'id': 3894426,
#  'main': {'humidity': 81,
#           'pressure': 1002,
#           'temp': 40.78,
#           'temp_max': 42.8,
#           'temp_min': 39.2},
#  'name': 'Coihaique',
#  'sys': {'country': 'CL',
#          'id': 4643,
#          'message': 0.0036,
#          'sunrise': 1535455455,
#          'sunset': 1535494515,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 30, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -38.55, 'lon': -58.74},
#  'dt': 1535427953,
#  'id': 3430443,
#  'main': {'grnd_level': 1020.25,
#           'humidity': 43,
#           'pressure': 1020.25,
#           'sea_level': 1025.95,
#           'temp': 62.86,
#           'temp_max': 62.86,
#           'temp_min': 62.86},
#  'name': 'Necochea',
#  'sys': {'country': 'AR',
#          'message': 0.0051,
#          'sunrise': 1535451767,
#          'sunset': 1535491798},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 317, 'speed': 18.25}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -33.25, 'lon': -58.03},
#  'dt': 1535427953,
#  'id': 3441684,
#  'main': {'grnd_level': 1029.41,
#           'humidity': 61,
#           'pressure': 1029.41,
#           'sea_level': 1032.19,
#           'temp': 53.59,
#           'temp_max': 53.59,
#           'temp_min': 53.59},
#  'name': 'Mercedes',
#  'sys': {'country': 'UY',
#          'message': 0.0032,
#          'sunrise': 1535451284,
#          'sunset': 1535491935},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 9.50031, 'speed': 11.77}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -3.14, 'lon': -58.44},
#  'dt': 1535427954,
#  'id': 3397893,
#  'main': {'grnd_level': 1022.2,
#           'humidity': 79,
#           'pressure': 1022.2,
#           'sea_level': 1025.78,
#           'temp': 79.69,
#           'temp_max': 79.69,
#           'temp_min': 79.69},
#  'name': 'Itacoatiara',
#  'sys': {'country': 'BR',
#          'message': 0.0029,
#          'sunrise': 1535450024,
#          'sunset': 1535493368},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 271.5, 'speed': 0.69}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -6.64, 'lon': -51.99},
#  'dt': 1535427954,
#  'id': 3388847,
#  'main': {'grnd_level': 993.66,
#           'humidity': 86,
#           'pressure': 993.66,
#           'sea_level': 1025.78,
#           'temp': 73.48,
#           'temp_max': 73.48,
#           'temp_min': 73.48},
#  'name': 'Sao Felix do Xingu',
#  'sys': {'country': 'BR',
#          'message': 0.0044,
#          'sunrise': 1535448618,
#          'sunset': 1535491681},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336.5, 'speed': 2.15}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 7.53, 'lon': -12.5},
#  'dt': 1535427954,
#  'id': 2409914,
#  'main': {'grnd_level': 1023.41,
#           'humidity': 99,
#           'pressure': 1023.41,
#           'sea_level': 1026.19,
#           'temp': 75.37,
#           'temp_max': 75.37,
#           'temp_min': 75.37},
#  'name': 'Bonthe',
#  'rain': {'3h': 0.19},
#  'sys': {'country': 'SL',
#          'message': 0.0053,
#          'sunrise': 1535438562,
#          'sunset': 1535482774},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 175, 'speed': 5.73}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 4.42, 'lon': -7.36},
#  'dt': 1535427955,
#  'id': 2281120,
#  'main': {'grnd_level': 1025.36,
#           'humidity': 100,
#           'pressure': 1025.36,
#           'sea_level': 1026.55,
#           'temp': 77.35,
#           'temp_max': 77.35,
#           'temp_min': 77.35},
#  'name': 'Tabou',
#  'rain': {'3h': 0.14},
#  'sys': {'country': 'CI',
#          'message': 0.0054,
#          'sunrise': 1535437458,
#          'sunset': 1535481414},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 181, 'speed': 7.18}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 4.89, 'lon': -1.75},
#  'dt': 1535427955,
#  'id': 2294915,
#  'main': {'grnd_level': 1023.17,
#           'humidity': 100,
#           'pressure': 1023.17,
#           'sea_level': 1026.31,
#           'temp': 73.39,
#           'temp_max': 73.39,
#           'temp_min': 73.39},
#  'name': 'Takoradi',
#  'sys': {'country': 'GH',
#          'message': 0.009,
#          'sunrise': 1535436093,
#          'sunset': 1535480087},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 238.5, 'speed': 5.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -16.5, 'lon': -68.19},
#  'dt': 1535425200,
#  'id': 3911925,
#  'main': {'humidity': 78,
#           'pressure': 1039,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'El Alto',
#  'sys': {'country': 'BO',
#          'id': 4426,
#          'message': 0.0035,
#          'sunrise': 1535452915,
#          'sunset': 1535495166,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -14.92, 'lon': -70.66},
#  'dt': 1535427955,
#  'id': 3946985,
#  'main': {'grnd_level': 617.38,
#           'humidity': 94,
#           'pressure': 617.38,
#           'sea_level': 1028.9,
#           'temp': 33.52,
#           'temp_max': 33.52,
#           'temp_min': 33.52},
#  'name': 'Caracollo',
#  'rain': {'3h': 0.195},
#  'sys': {'country': 'PE',
#          'message': 0.0033,
#          'sunrise': 1535453440,
#          'sunset': 1535495825},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 126, 'speed': 3.38}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -8.9, 'lon': -35.15},
#  'dt': 1535427956,
#  'id': 3388456,
#  'main': {'grnd_level': 1021.95,
#           'humidity': 100,
#           'pressure': 1021.95,
#           'sea_level': 1030.57,
#           'temp': 72.22,
#           'temp_max': 72.22,
#           'temp_min': 72.22},
#  'name': 'Sao Jose da Coroa Grande',
#  'rain': {'3h': 2.775},
#  'sys': {'country': 'BR',
#          'message': 0.0035,
#          'sunrise': 1535444670,
#          'sunset': 1535487549},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 133, 'speed': 9.64}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -3.38, 'lon': -57.72},
#  'dt': 1535427956,
#  'id': 3395062,
#  'main': {'grnd_level': 1019.93,
#           'humidity': 90,
#           'pressure': 1019.93,
#           'sea_level': 1025.62,
#           'temp': 76.54,
#           'temp_max': 76.54,
#           'temp_min': 76.54},
#  'name': 'Maues',
#  'sys': {'country': 'BR',
#          'message': 0.0038,
#          'sunrise': 1535449861,
#          'sunset': 1535493186},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 25.5003, 'speed': 1.25}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -2.9, 'lon': -40.84},
#  'dt': 1535427956,
#  'id': 3403687,
#  'main': {'grnd_level': 1018.87,
#           'humidity': 77,
#           'pressure': 1018.87,
#           'sea_level': 1027.2,
#           'temp': 77.44,
#           'temp_max': 77.44,
#           'temp_min': 77.44},
#  'name': 'Camocim',
#  'sys': {'country': 'BR',
#          'message': 0.0033,
#          'sunrise': 1535445791,
#          'sunset': 1535489154},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 75.5003, 'speed': 16.13}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -16.28, 'lon': -39.02},
#  'dt': 1535425200,
#  'id': 3450288,
#  'main': {'humidity': 88,
#           'pressure': 1022,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Santa Cruz Cabralia',
#  'sys': {'country': 'BR',
#          'id': 4559,
#          'message': 0.0034,
#          'sunrise': 1535445908,
#          'sunset': 1535488173,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -16.48, 'lon': -151.75},
#  'dt': 1535427956,
#  'id': 4034551,
#  'main': {'grnd_level': 1025.36,
#           'humidity': 100,
#           'pressure': 1025.36,
#           'sea_level': 1025.38,
#           'temp': 79.6,
#           'temp_max': 79.6,
#           'temp_min': 79.6},
#  'name': 'Faanui',
#  'sys': {'country': 'PF',
#          'message': 0.0097,
#          'sunrise': 1535472959,
#          'sunset': 1535515223},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 47.0003, 'speed': 11.77}}
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -17.72, 'lon': -48.16},
#  'dt': 1535427957,
#  'id': 3461151,
#  'main': {'grnd_level': 945.67,
#           'humidity': 54,
#           'pressure': 945.67,
#           'sea_level': 1031.3,
#           'temp': 72.76,
#           'temp_max': 72.76,
#           'temp_min': 72.76},
#  'name': 'Ipameri',
#  'sys': {'country': 'BR',
#          'message': 0.0033,
#          'sunrise': 1535448163,
#          'sunset': 1535490306},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80.5003, 'speed': 9.75}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -13.28, 'lon': -50.16},
#  'dt': 1535427957,
#  'id': 3448455,
#  'main': {'grnd_level': 992.77,
#           'humidity': 65,
#           'pressure': 992.77,
#           'sea_level': 1026.59,
#           'temp': 76.63,
#           'temp_max': 76.63,
#           'temp_min': 76.63},
#  'name': 'Sao Miguel do Araguaia',
#  'sys': {'country': 'BR',
#          'message': 0.0027,
#          'sunrise': 1535448453,
#          'sunset': 1535490972},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 4.38}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -5.2, 'lon': -35.46},
#  'dt': 1535427957,
#  'id': 3386213,
#  'main': {'grnd_level': 1024.63,
#           'humidity': 88,
#           'pressure': 1024.63,
#           'sea_level': 1028.9,
#           'temp': 76.45,
#           'temp_max': 76.45,
#           'temp_min': 76.45},
#  'name': 'Touros',
#  'sys': {'country': 'BR',
#          'message': 0.0032,
#          'sunrise': 1535444594,
#          'sunset': 1535487771},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 137, 'speed': 12.77}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.49, 'lon': -58.8},
#  'dt': 1535427957,
#  'id': 3437443,
#  'main': {'grnd_level': 1019.68,
#           'humidity': 61,
#           'pressure': 1019.68,
#           'sea_level': 1029.8,
#           'temp': 58.45,
#           'temp_max': 58.45,
#           'temp_min': 58.45},
#  'name': 'Pozo Colorado',
#  'sys': {'country': 'PY',
#          'message': 0.0029,
#          'sunrise': 1535450975,
#          'sunset': 1535492605},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 75.0003, 'speed': 8.97}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -17.53, 'lon': -149.33},
#  'dt': 1535427000,
#  'id': 4033356,
#  'main': {'humidity': 65,
#           'pressure': 1012,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Tiarei',
#  'sys': {'country': 'PF',
#          'id': 8343,
#          'message': 0.0033,
#          'sunrise': 1535472423,
#          'sunset': 1535514598,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 12.75}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -41.13, 'lon': -71.31},
#  'dt': 1535425200,
#  'id': 7647007,
#  'main': {'humidity': 75,
#           'pressure': 1012,
#           'temp': 44.6,
#           'temp_max': 44.6,
# ...
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 356, 'speed': 2.71}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -3.66, 'lon': 152.44},
#  'dt': 1535428301,
#  'id': 2090021,
#  'main': {'grnd_level': 1017.09,
#           'humidity': 100,
#           'pressure': 1017.09,
#           'sea_level': 1023.07,
#           'temp': 81.76,
#           'temp_max': 81.76,
#           'temp_min': 81.76},
#  'name': 'Namatanai',
#  'sys': {'country': 'PG',
#          'message': 0.003,
#          'sunrise': 1535399447,
#          'sunset': 1535442743},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 224.5, 'speed': 3.71}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 24.03, 'lon': 84.07},
#  'dt': 1535428301,
#  'id': 1273626,
#  'main': {'grnd_level': 978.5,
#           'humidity': 96,
#           'pressure': 978.5,
#           'sea_level': 1012.86,
#           'temp': 80.23,
#           'temp_max': 80.23,
#           'temp_min': 80.23},
#  'name': 'Daltenganj',
#  'sys': {'country': 'IN',
#          'message': 0.003,
#          'sunrise': 1535414627,
#          'sunset': 1535460350},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 91.0003, 'speed': 7.07}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 39.13, 'lon': 16.07},
#  'dt': 1535424600,
#  'id': 2525727,
#  'main': {'humidity': 93,
#           'pressure': 1013,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Amantea',
#  'sys': {'country': 'IT',
#          'id': 5758,
#          'message': 0.0033,
#          'sunrise': 1535430042,
#          'sunset': 1535477550,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 50.6, 'lon': 97.53},
#  'dt': 1535428302,
#  'id': 1501377,
#  'main': {'grnd_level': 813.06,
#           'humidity': 54,
#           'pressure': 813.06,
#           'sea_level': 1022.78,
#           'temp': 66.01,
#           'temp_max': 66.01,
#           'temp_min': 66.01},
#  'name': 'Kungurtug',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1535409444,
#          'sunset': 1535459032},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 163.5, 'speed': 4.16}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 57.26, 'lon': 16.44},
#  'dt': 1535426400,
#  'id': 2686162,
#  'main': {'humidity': 100,
#           'pressure': 1010,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Oskarshamn',
#  'sys': {'country': 'SE',
#          'id': 5396,
#          'message': 0.0036,
#          'sunrise': 1535428046,
#          'sunset': 1535479323,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 240, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 52.42, 'lon': 136.49},
#  'dt': 1535428302,
#  'id': 2023584,
#  'main': {'grnd_level': 1015.63,
#           'humidity': 92,
#           'pressure': 1015.63,
#           'sea_level': 1030.57,
#           'temp': 62.59,
#           'temp_max': 62.59,
#           'temp_min': 62.59},
#  'name': 'Imeni Poliny Osipenko',
#  'rain': {'3h': 0.215},
#  'sys': {'country': 'RU',
#          'message': 0.004,
#          'sunrise': 1535399869,
#          'sunset': 1535449905},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 35.0003, 'speed': 3.71}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.33, 'lon': -91.2},
#  'dt': 1535427300,
#  'id': 4863349,
#  'main': {'humidity': 62,
#           'pressure': 1009,
#           'temp': 83.25,
#           'temp_max': 84.2,
#           'temp_min': 79.7},
#  'name': 'Basco',
#  'sys': {'country': 'US',
#          'id': 878,
#          'message': 0.0035,
#          'sunrise': 1535455715,
#          'sunset': 1535503354,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'gust': 10.8, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 47.51, 'lon': 122.88},
#  'dt': 1535428302,
#  'id': 2035593,
#  'main': {'grnd_level': 999.01,
#           'humidity': 96,
#           'pressure': 999.01,
#           'sea_level': 1026.76,
#           'temp': 72.31,
#           'temp_max': 72.31,
#           'temp_min': 72.31},
#  'name': 'Nianzishan',
#  'sys': {'country': 'CN',
#          'message': 0.0032,
#          'sunrise': 1535403680,
#          'sunset': 1535452638},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 196, 'speed': 6.29}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 10.35, 'lon': 107.08},
#  'dt': 1535427000,
#  'id': 1562414,
#  'main': {'humidity': 70,
#           'pressure': 1010,
#           'temp': 87.8,
#           'temp_max': 87.8,
#           'temp_min': 87.8},
#  'name': 'Vung Tau',
#  'sys': {'country': 'VN',
#          'id': 7985,
#          'message': 0.0032,
#          'sunrise': 1535409744,
#          'sunset': 1535454204,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 65.8, 'lon': 87.96},
#  'dt': 1535428303,
#  'id': 1488903,
#  'main': {'grnd_level': 1011.17,
#           'humidity': 100,
#           'pressure': 1011.17,
#           'sea_level': 1025.14,
#           'temp': 59.26,
#           'temp_max': 59.26,
#           'temp_min': 59.26},
#  'name': 'Turukhansk',
#  'sys': {'country': 'RU',
#          'message': 0.0037,
#          'sunrise': 1535409026,
#          'sunset': 1535463969},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 87.5003, 'speed': 7.07}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 27.5, 'lon': 88.54},
#  'dt': 1535428303,
#  'id': 1263776,
#  'main': {'grnd_level': 653.37,
#           'humidity': 89,
#           'pressure': 653.37,
#           'sea_level': 1017.27,
#           'temp': 51.97,
#           'temp_max': 51.97,
#           'temp_min': 51.97},
#  'name': 'Mangan',
#  'sys': {'country': 'IN',
#          'message': 0.0036,
#          'sunrise': 1535413370,
#          'sunset': 1535459459},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219, 'speed': 1.92}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 59.83, 'lon': 12.54},
#  'dt': 1535426400,
#  'id': 2725123,
#  'main': {'humidity': 100,
#           'pressure': 1009,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Tobol',
#  'sys': {'country': 'SE',
#          'id': 5412,
#          'message': 0.0046,
#          'sunrise': 1535428546,
#          'sunset': 1535480684,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 24.58, 'lon': 121.1},
#  'dt': 1535425200,
#  'id': 1675107,
#  'main': {'humidity': 74,
#           'pressure': 1007,
#           'temp': 86.04,
#           'temp_max': 89.6,
#           'temp_min': 80.6},
#  'name': 'Qingquan',
#  'sys': {'country': 'TW',
#          'id': 7477,
#          'message': 0.0036,
#          'sunrise': 1535405709,
#          'sunset': 1535451497,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 64.73, 'lon': 177.51},
#  'dt': 1535425200,
#  'id': 2127202,
#  'main': {'humidity': 87,
#           'pressure': 1014,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Anadyr',
#  'sys': {'country': 'RU',
#          'id': 7238,
#          'message': 0.0032,
#          'sunrise': 1535387787,
#          'sunset': 1535442241,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09d',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 100, 'gust': 11, 'speed': 17.9}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 69.58, 'lon': 20.21},
#  'dt': 1535422800,
#  'id': 778829,
#  'main': {'humidity': 87,
#           'pressure': 1013,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Lyngseidet',
#  'sys': {'country': 'NO',
#          'id': 5339,
#          'message': 0.0098,
#          'sunrise': 1535424002,
#          'sunset': 1535481463,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 50.9, 'lon': 142.16},
#  'dt': 1535428304,
#  'id': 2127282,
#  'main': {'grnd_level': 1017.01,
#           'humidity': 88,
#           'pressure': 1017.01,
#           'sea_level': 1031.34,
#           'temp': 63.22,
#           'temp_max': 63.22,
#           'temp_min': 63.22},
#  'name': 'Aleksandrovsk-Sakhalinskiy',
#  'sys': {'country': 'RU',
#          'message': 0.0042,
#          'sunrise': 1535398687,
#          'sunset': 1535448370},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 314.5, 'speed': 3.38}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 62.71, 'lon': 56.19},
#  'dt': 1535428305,
#  'id': 481548,
#  'main': {'grnd_level': 1012.3,
#           'humidity': 85,
#           'pressure': 1012.3,
#           'sea_level': 1029.63,
#           'temp': 57.1,
#           'temp_max': 57.1,
#           'temp_min': 57.1},
#  'name': 'Troitsko-Pechorsk',
#  'sys': {'country': 'RU',
#          'message': 0.0046,
#          'sunrise': 1535417462,
#          'sunset': 1535470803},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 203, 'speed': 4.72}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 53.6, 'lon': 91.39},
#  'dt': 1535425200,
#  'id': 1510377,
#  'main': {'humidity': 77,
#           'pressure': 1014,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Belyy Yar',
#  'sys': {'country': 'RU',
#          'id': 7276,
#          'message': 0.0038,
#          'sunrise': 1535410557,
#          'sunset': 1535460857,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210, 'speed': 4.47}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 35.94, 'lon': 101.38},
#  'dt': 1535428305,
#  'id': 1808204,
#  'main': {'grnd_level': 712.87,
#           'humidity': 87,
#           'pressure': 712.87,
#           'sea_level': 1017.92,
#           'temp': 57.19,
#           'temp_max': 57.19,
#           'temp_min': 57.19},
#  'name': 'Mugan',
#  'sys': {'country': 'CN',
#          'message': 0.0043,
#          'sunrise': 1535409778,
#          'sunset': 1535456878},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 66.0003, 'speed': 2.71}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 26.22, 'lon': 117.49},
#  'dt': 1535428306,
#  'id': 1796663,
#  'main': {'grnd_level': 960.99,
#           'humidity': 85,
#           'pressure': 960.99,
#           'sea_level': 1016.95,
#           'temp': 80.05,
#           'temp_max': 80.05,
#           'temp_min': 80.05},
#  'name': 'Bantou',
#  'sys': {'country': 'CN',
#          'message': 0.0036,
#          'sunrise': 1535406489,
#          'sunset': 1535452448},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 87.0003, 'speed': 2.71}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 40.67, 'lon': 33.6},
#  'dt': 1535428306,
#  'id': 749747,
#  'main': {'grnd_level': 878.72,
#           'humidity': 79,
#           'pressure': 878.72,
#           'sea_level': 1021.93,
#           'temp': 55.93,
#           'temp_max': 55.93,
#           'temp_min': 55.93},
#  'name': 'Ayan',
#  'sys': {'country': 'TR',
#          'message': 0.0056,
#          'sunrise': 1535425717,
#          'sunset': 1535473460},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 335.5, 'speed': 2.15}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 46.17, 'lon': 45.34},
#  'dt': 1535428306,
#  'id': 468747,
#  'main': {'grnd_level': 1029.01,
#           'humidity': 59,
#           'pressure': 1029.01,
#           'sea_level': 1028.38,
#           'temp': 58.99,
#           'temp_max': 58.99,
#           'temp_min': 58.99},
#  'name': 'Yashkul',
#  'sys': {'country': 'RU',
#          'message': 0.0066,
#          'sunrise': 1535422434,
#          'sunset': 1535471098},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 48.5003, 'speed': 8.97}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 67.47, 'lon': 78.7},
#  'dt': 1535428306,
#  'id': 1489853,
#  'main': {'grnd_level': 1025.2,
#           'humidity': 76,
#           'pressure': 1025.2,
#           'sea_level': 1028.66,
#           'temp': 56.29,
#           'temp_max': 56.29,
#           'temp_min': 56.29},
#  'name': 'Tazovskiy',
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1535410727,
#          'sunset': 1535466696},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 347.5, 'speed': 5.39}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 24.19, 'lon': 102.82},
#  'dt': 1535428307,
#  'id': 1787599,
#  'main': {'grnd_level': 830.16,
#           'humidity': 66,
#           'pressure': 830.16,
#           'sea_level': 1017.52,
#           'temp': 75.46,
#           'temp_max': 75.46,
#           'temp_min': 75.46},
#  'name': 'Xingyi',
#  'sys': {'country': 'CN',
#          'message': 0.0031,
#          'sunrise': 1535410118,
#          'sunset': 1535455861},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 91.0003, 'speed': 2.59}}

# %%
weather_dict = {
    "city": cities_list,
    "country": country_list,
    "id_list": id_list,
    "lat": latss,
    "lngs": longss,
    "temp": tempature,
    "cloud":cloud,
    "cloud percent":cloud_percent,
    "humidity": humidity,
    "wind": wind
}

# %%
weather_data = pd.DataFrame.from_dict(weather_dict)
weather_df = weather_data.rename(columns={"country": "Country",
                                          "city": "City",
                                          "id_list": "ID Number",
                                          "lat": "Latitude",
                                          "lngs": "Longitude",
                                          "cloud": "Cloudiness",
                                          "cloud percent": "Cloud Percentage",
                                          "wind": "Wind Speed (mph)",
                                          "temp": "Temperature (F)", 
                                          "humidity": "Humidity (%)"      
                                         })

weather_drop_dup = weather_df.drop_duplicates()
weather_df=weather_drop_dup.reset_index(drop=True)
weather_df.drop(weather_df[weather_df["Humidity (%)"] > 100].index,inplace=True)
df = weather_df.reset_index(drop=True)
# Out:
#                           City Country  ID Number  Latitude  Longitude  \
# 200                     Tucume      PE    3691161     -6.51     -79.86
# 201                    Camargo      MX    4013724     27.69    -105.17
# 202                  Orcopampa      PE    3933986    -15.27     -72.34
# 203                    Artigas      BR    3443758    -30.40     -56.46
# 204           Puerto Leguizamo      CO    3671437     -0.19     -74.78
# 205          Presidente Medici      BR    3924872    -11.18     -61.90
# 206               Rio Gallegos      AR    3838859    -51.62     -69.22
# 207                    Mazagao      BR    3395042     -0.12     -51.29
# 208                   Jipijapa      EC    3655446     -1.35     -80.58
# 209                    Tucurui      BR    3385935     -3.77     -49.67
# 210                      Llata      PE    3695320     -9.55     -76.82
# 211                   Camacari      BR    3468031    -12.70     -38.32
# 212           Lencois Paulista      BR    3458645    -22.60     -48.80
# 213                  Caiaponia      BR    3468234    -16.96     -51.81
# 214              Nova Londrina      BR    3456146    -22.76     -52.99
# 215             Treinta y Tres      UY    3439781    -33.23     -54.39
# 216                      Arica      CL    3899361    -18.48     -70.32
# 217                San Lorenzo      PY    3437056    -25.34     -57.51
# 218                  Cruz Alta      AR    3859839    -33.01     -61.81
# 219             Nisia Floresta      BR    3393922     -6.09     -35.21
# 220       Governador Valadares      BR    3462315    -18.85     -41.95
# 221            Varzea da Palma      BR    3445459    -17.60     -44.73
# 222                  Salamanca      ES    3111108     40.97      -5.66
# 223                     Urucui      BR    3385658     -7.23     -44.56
# 224                    Niteroi      BR    3452925    -29.95     -51.16
# 225                 Carinhanha      BR    3466950    -14.30     -43.77
# 226                San Nicolas      HN    3601834     14.94     -88.33
# 227                      Salta      AR    3838233    -24.79     -65.41
# 228               Canguaretama      BR    3403362     -6.38     -35.14
# 229                      Muana      BR    3394326     -1.53     -49.22
# 230                      Manta      RO     685981     45.10      24.10
# 231                  Tocopilla      CL    3869716    -22.09     -70.20
# 232                    Itupeva      BR    3460516    -23.15     -47.06
# 233     Sao Francisco de Paula      BR    3449121    -29.45     -50.58
# 234                     Pangoa      PE    3933104    -12.12     -73.00
# 235                     Huaral      PE    3939285    -11.50     -77.21
# 236                     Rivera      UY    3440781    -30.90     -55.54
# 237                 San Javier      ES    2511366     37.81      -0.83
# 238  Sao Benedito do Rio Preto      BR    3389012     -3.33     -43.53
# 239                      Olmos      PE    3694256     -5.99     -79.75
# 240           Campos do Jordao      BR    3467684    -22.74     -45.59
# 241    Marechal Candido Rondon      BR    3457772    -24.56     -54.06
# 242                  San Borja      BO    3905792    -14.86     -66.75
# 243               Jacareacanga      BR    3397763     -6.22     -57.76
# 244            Pocos de Caldas      BR    3453303    -21.79     -46.56
# 245                    Parauna      ID    1974329     -3.82     122.09
# 246                   Coruripe      BR    3465329    -10.12     -36.18
# 247                       Azul      AR    3436199    -36.78     -59.86
# 248                  Pacasmayo      PE    3694178     -7.40     -79.57
# 249            Benjamin Aceval      PY    3439348    -24.97     -57.57
#
#      Temperature (F)        Cloudiness  Cloud Percentage  Humidity (%)  \
# 200            66.20     broken clouds                75            29
# 201            81.40        light rain                68            33
# 202            25.87         clear sky                 8            79
# 203            46.39         clear sky                 0            83
# 204            71.23        light rain                92            98
# 205            68.35         clear sky                 8            83
# 206            35.60         clear sky                 0            69
# 207            80.60        few clouds                20            88
# 208            71.60     broken clouds                75            88
# 209            74.11         clear sky                 0            96
# 210            31.90        few clouds                12            84
# 211            71.23        light rain                 0            93
# 212            54.85         clear sky                 0            86
# 213            74.29  scattered clouds                36            60
# 214            58.09         clear sky                 0            67
# 215            45.49         clear sky                 0            77
# 216            57.87   overcast clouds                90            72
# 217            59.00         clear sky                 0            54
# 218            57.10         clear sky                 8            47
# 219            75.20         clear sky                 0            78
# 220            66.37        light rain                88            88
# 221            70.24        few clouds                24            67
# 222            62.60         clear sky                 0            59
# 223            77.53         clear sky                 0            44
# 224            48.24         clear sky                 0            93
# 225            70.42         clear sky                 0            54
# 226            70.42     broken clouds                56            94
# 227            53.28         clear sky                 0            61
# 228            75.20         clear sky                 0            78
# 229            81.58   overcast clouds               100            87
# 230            59.62        light rain                12            93
# 231            54.13        few clouds                12           100
# 232            57.22   overcast clouds                90            87
# 233            37.93         clear sky                 0            85
# 234            58.63         clear sky                 0            94
# 235            53.05  scattered clouds                32            95
# 236            46.21         clear sky                 0            78
# 237            75.20         clear sky                 8            88
# 238            78.52        few clouds                12            67
# 239            61.24        few clouds                24            97
# 240            60.66   overcast clouds                90            82
# 241            52.51         clear sky                 0            76
# 242            65.47         clear sky                 0            72
# 243            77.62  scattered clouds                44            85
# 244            61.42  scattered clouds                48            76
# 245            81.13     broken clouds                56            63
# 246            77.17   overcast clouds                92            96
# 247            59.17        few clouds                20            42
# 248            62.05         clear sky                 0            99
# 249            59.00         clear sky                 0            54
#
#      Wind Speed (mph)
# 200             10.29
# 201              5.06
# 202              2.37
# 203             11.10
# 204              2.37
# 205              3.38
# 206              9.17
# 207              3.36
# 208              6.93
# 209              2.71
# 210              2.26
# 211              6.85
# 212             14.00
# 213              3.94
# 214             11.32
# 215              7.96
# 216              5.82
# 217              4.70
# 218             13.56
# 219              8.05
# 220             10.31
# 221             11.65
# 222              1.12
# 223             11.54
# 224              2.71
# 225             10.76
# 226              1.92
# 227              4.70
# 228              8.05
# 229             10.42
# 230              2.71
# 231              1.92
# 232              6.93
# 233              3.49
# 234              1.36
# 235              3.38
# 236             10.76
# 237              6.93
# 238             10.20
# 239              2.15
# 240              9.17
# 241              8.97
# 242              1.92
# 243              1.81
# 244              8.08
# 245              2.37
# 246             14.45
# 247             13.22
# 248              7.96
# 249              4.70

# %%
nlag=np.array(df["Longitude"])

nlat=np.array(df["Latitude"])
ntemp=np.array(df["Temperature (F)"])
ncoud=np.array(df["Cloud Percentage"])
nhumid=np.array(df["Humidity (%)"])
nwind=np.array(df["Wind Speed (mph)"])

# %%
plt.scatter(df["Latitude"], df["Temperature (F)"],
            s=30, label="City", color="lightcoral", edgecolors="black", alpha=.75)

plt.suptitle("Temperature Analysis as of 08/25/18",
             horizontalalignment='center', verticalalignment='top', fontsize=16)

plt.xlabel("Latitude")
plt.ylabel("Temperature Per City (F)")
plt.grid(color='black', linewidth=.25)

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(df["Latitude"],df["Humidity (%)"], s=30,
            label = "City", color = "green", edgecolors="black", alpha = 0.5)

plt.suptitle("Humidity Analysis as of 08/25/18",
             horizontalalignment='center', verticalalignment='top', fontsize=16)

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
        
plt.grid(color='black', linewidth=.25)


#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Cloud Percentage"], s=30,
            label = "City", color = "blue", edgecolors="black", alpha = 0.75)

plt.suptitle("Cloud Analysis as of 08/25/18",
             horizontalalignment='center', verticalalignment='top', fontsize=16)

plt.xlabel("Latitude")
plt.ylabel("Cloud (%)")
        
plt.grid(color='black', linewidth=.25)

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed (mph)"], s=30,
            label = "City", color = "purple", edgecolors="black", alpha = 0.5)

plt.suptitle("Wind Analysis as of 08/25/18",
             horizontalalignment='center', verticalalignment='top', fontsize=16)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
        
plt.grid(color='black', linewidth=.25)

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(df["Longitude"],df["Latitude"], s=25,c=ntemp, cmap="RdBu_r",
            vmin=ntemp.max()-ntemp.mean(),vmax=ntemp.max())

plt.suptitle("Cities Temperature",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Temperature in Degrees (F)",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(weather_df["Longitude"],weather_df["Latitude"], s=10,c=ncoud, cmap="viridis_r", vmin=ncoud.min(),vmax=ncoud.max())

plt.suptitle("Cities Cloudiness",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Cloud Percentage",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(df["Longitude"],df["Latitude"], s=10,c=nhumid, cmap="gist_earth_r", vmin=nhumid.min(),vmax=nhumid.max())

plt.suptitle("Cities Humidity",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Humidity Percentage",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)

plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(df["Longitude"],df["Latitude"], s=10,c=nwind, cmap="gist_earth_r", vmin=nwind.min(),vmax=nwind.max())

plt.suptitle("Cities Windiness",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Wind Speed (MPH)",fontstyle ='italic',horizontalalignment='center', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()
