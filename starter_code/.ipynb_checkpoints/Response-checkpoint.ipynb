# %%
# # Unit 6 | Assignment - What's the Weather Like?

# ## Background

# Whether financial, political, or social -- 
# data's true power lies in its ability to answer questions definitively. 
# So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: 
# "What's the weather like as we approach the equator?"

# Now, we know what you may be thinking: _"Duh. It gets hotter..."_

# But, if pressed, how would you **prove** it?

# ![Equator](Images/equatorsign.png)

# ## WeatherPy

# In this example, you'll be creating a Python script 
# to visualize the weather of 500+ cities across the world of
# varying distance from the equator.To accomplish this, 
# you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), 
# the [OpenWeatherMap API](https://openweathermap.org/api), 
# and a little common sense to create a representative model of weather across world cities.

# Your objective is to build a series of scatter plots to showcase the following relationships:

# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude

# Your final notebook must:

# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.

# As final considerations:

# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
# * See [Example Solution](WeatherPy_Example.pdf) for a reference on expected format.

# ## Hints and Considerations

# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).

# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.

# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy). Before you try to incorporate the library into your analysis, start by creating simple test cases outside your main script to confirm that you are using it correctly. Too often, when introduced to a new library, students get bogged down by the most minor of errors -- spending hours investigating their entire code -- when, in fact, a simple and focused test would have shown their basic utilization of the library was wrong from the start. Don't let this be you!

# * Part of our expectation in this challenge is that you will use critical thinking skills to understand how and why we're recommending the tools we are. What is Citipy for? Why would you use it in conjunction with the OpenWeatherMap API? How would you do so?

# * In building your script, pay attention to the cities you are using in your query pool. Are you getting coverage of the full gamut of latitudes and longitudes? Or are you simply choosing 500 cities concentrated in one region of the world? Even if you were a geographic genius, simply rattling 500 cities based on your human selection would create a biased dataset. Be thinking of how you should counter this. (Hint: Consider the full range of latitudes).

# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#np.linspace

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 610

# %%
# OpenWeatherMap API Key
api_key = api_key


# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# response = requests.get(query_url + city).json()
# tempature.append(response["main"]["temp"])

# %%
# Loop through the list of cities and perform a request for data on each

latss = []
longss = []
humidity = []
tempature=[]
cloud = []
wind = []
cities_list = []
country_list = []
id_list = []
cloud_percent = []

for city in cities:
    response = requests.get(query_url + city).json()
    pprint(response)
    if response["cod"] != "404":
        latss.append(response['coord']['lat'])
        longss.append(response['coord']['lon'])
        humidity.append(response["main"]["humidity"])
        tempature.append(response["main"]["temp"])
        cloud.append(response['weather'][0]['description'])
        wind.append(response["wind"]["speed"])
        cities_list.append(response["name"])
        country_list.append(response["sys"]["country"])
        id_list.append(response["id"])
        cloud_percent.append(response["clouds"]["all"])
# Out:
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.93, 'lon': 57.53},
#  'dt': 1535249774,
#  'id': 286987,
#  'main': {'grnd_level': 948.12,
#           'humidity': 51,
#           'pressure': 948.12,
#           'sea_level': 1013.93,
#           'temp': 73.34,
#           'temp_max': 73.34,
#           'temp_min': 73.34},
#  'name': 'Nizwa',
#  'sys': {'country': 'OM',
#          'message': 0.0033,
#          'sunrise': 1535248213,
#          'sunset': 1535293974},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 42.5, 'speed': 2.51}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -35.17, 'lon': 173.16},
#  'dt': 1535249474,
#  'id': 2194098,
#  'main': {'grnd_level': 1021.72,
#           'humidity': 85,
#           'pressure': 1021.72,
#           'sea_level': 1035.21,
#           'temp': 57.23,
#           'temp_max': 57.23,
#           'temp_min': 57.23},
#  'name': 'Ahipara',
#  'sys': {'country': 'NZ',
#          'message': 0.0032,
#          'sunrise': 1535223319,
#          'sunset': 1535263424},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 196.5, 'speed': 10.78}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1535249417,
#  'id': 3833859,
#  'main': {'grnd_level': 1022.13,
#           'humidity': 42,
#           'pressure': 1022.13,
#           'sea_level': 1034.68,
#           'temp': 38.24,
#           'temp_max': 38.24,
#           'temp_min': 38.24},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.003,
#          'sunrise': 1535279487,
#          'sunset': 1535319265},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 331, 'speed': 12.24}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1535249213,
#  'id': 3424607,
#  'main': {'grnd_level': 1018.07,
#           'humidity': 100,
#           'pressure': 1018.07,
#           'sea_level': 1020.66,
#           'temp': 41.57,
#           'temp_max': 41.57,
#           'temp_min': 41.57},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'message': 0.0044,
#          'sunrise': 1535266089,
#          'sunset': 1535321653},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 184, 'speed': 3.18}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 34.02, 'lon': -6.83},
#  'dt': 1535247000,
#  'id': 2538474,
#  'main': {'humidity': 88,
#           'pressure': 1012,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Rabat',
#  'sys': {'country': 'MA',
#          'id': 6143,
#          'message': 0.0041,
#          'sunrise': 1535262999,
#          'sunset': 1535310062,
#          'type': 1},
#  'visibility': 5000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 166, 'speed': 1.61}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1535249409,
#  'id': 2075265,
#  'main': {'grnd_level': 1032.02,
#           'humidity': 100,
#           'pressure': 1032.02,
#           'sea_level': 1033.06,
#           'temp': 57.05,
#           'temp_max': 57.05,
#           'temp_min': 57.05},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'message': 0.0034,
#          'sunrise': 1535237085,
#          'sunset': 1535277400},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92.5, 'speed': 6.42}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 4.42, 'lon': -7.36},
#  'dt': 1535249427,
#  'id': 2281120,
#  'main': {'grnd_level': 1024.31,
#           'humidity': 100,
#           'pressure': 1024.31,
#           'sea_level': 1025.44,
#           'temp': 77.21,
#           'temp_max': 77.21,
#           'temp_min': 77.21},
#  'name': 'Tabou',
#  'sys': {'country': 'CI',
#          'message': 0.0038,
#          'sunrise': 1535264680,
#          'sunset': 1535308664},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 216.5, 'speed': 18.16}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 30.76, 'lon': -86.57},
#  'dt': 1535248680,
#  'id': 4152311,
#  'main': {'humidity': 93,
#           'pressure': 1021,
#           'temp': 80.19,
#           'temp_max': 83.12,
#           'temp_min': 75.02},
#  'name': 'Crestview',
#  'sys': {'country': 'US',
#          'id': 645,
#          'message': 0.0186,
#          'sunrise': 1535282356,
#          'sunset': 1535328976,
#          'type': 1},
#  'visibility': 9656,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 106.5, 'speed': 4.41}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 33.74, 'lon': -80.8},
#  'dt': 1535248560,
#  'id': 4589590,
#  'main': {'humidity': 85,
#           'pressure': 1023,
#           'temp': 74.7,
#           'temp_max': 78.98,
#           'temp_min': 68},
#  'name': 'Totness',
#  'sys': {'country': 'US',
#          'id': 2427,
#          'message': 0.0042,
#          'sunrise': 1535280779,
#          'sunset': 1535327781,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 5.64}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 11.75, 'lon': 11.96},
#  'dt': 1535249775,
#  'id': 2345521,
#  'main': {'grnd_level': 980.22,
#           'humidity': 94,
#           'pressure': 980.22,
#           'sea_level': 1026.17,
#           'temp': 70.01,
#           'temp_max': 70.01,
#           'temp_min': 70.01},
#  'name': 'Damaturu',
#  'sys': {'country': 'NG',
#          'message': 0.0029,
#          'sunrise': 1535259710,
#          'sunset': 1535304357},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 231, 'speed': 6.2}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -16.48, 'lon': -151.75},
#  'dt': 1535249776,
#  'id': 4034551,
#  'main': {'grnd_level': 1026.67,
#           'humidity': 100,
#           'pressure': 1026.67,
#           'sea_level': 1026.78,
#           'temp': 78.29,
#           'temp_max': 78.29,
#           'temp_min': 78.29},
#  'name': 'Faanui',
#  'sys': {'country': 'PF',
#          'message': 0.0033,
#          'sunrise': 1535300247,
#          'sunset': 1535342406},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 95.5, 'speed': 6.2}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -4.26, 'lon': -55.99},
#  'dt': 1535249776,
#  'id': 3397967,
#  'main': {'grnd_level': 1015.88,
#           'humidity': 67,
#           'pressure': 1015.88,
#           'sea_level': 1026.05,
#           'temp': 80.45,
#           'temp_max': 80.45,
#           'temp_min': 80.45},
#  'name': 'Itaituba',
#  'rain': {'3h': 0.305},
#  'sys': {'country': 'BR',
#          'message': 0.0037,
#          'sunrise': 1535276730,
#          'sunset': 1535319959},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 28, 'speed': 2.17}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.97, 'lon': -117.74},
#  'dt': 1535248560,
#  'id': 5710360,
#  'main': {'humidity': 4,
#           'pressure': 1014,
#           'temp': 80.96,
#           'temp_max': 80.96,
#           'temp_min': 80.96},
#  'name': 'Winnemucca',
#  'sys': {'country': 'US',
#          'id': 2078,
#          'message': 0.0048,
#          'sunrise': 1535289118,
#          'sunset': 1535337159,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.01, 'lon': -68.8},
#  'dt': 1535245200,
#  'id': 3844421,
#  'main': {'humidity': 70,
#           'pressure': 1024,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Russell',
#  'sys': {'country': 'AR',
#          'id': 4700,
#          'message': 0.0066,
#          'sunrise': 1535281206,
#          'sunset': 1535321654,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 337.5, 'speed': 2.06}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 18.62, 'lon': -100.35},
#  'dt': 1535249776,
#  'id': 3981460,
#  'main': {'grnd_level': 904.59,
#           'humidity': 92,
#           'pressure': 904.59,
#           'sea_level': 1026.33,
#           'temp': 67.67,
#           'temp_max': 67.67,
#           'temp_min': 67.67},
#  'name': 'Coahuayana',
#  'rain': {'3h': 1.29},
#  'sys': {'country': 'MX',
#          'message': 0.0031,
#          'sunrise': 1535286335,
#          'sunset': 1535331623},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 33, 'speed': 1.72}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1535248260,
#  'id': 5106834,
#  'main': {'humidity': 61,
#           'pressure': 1022,
#           'temp': 68,
#           'temp_max': 71.6,
#           'temp_min': 64.04},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 2088,
#          'message': 0.0048,
#          'sunrise': 1535278411,
#          'sunset': 1535326752,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -8.9, 'lon': -35.15},
#  'dt': 1535249434,
#  'id': 3388456,
#  'main': {'grnd_level': 1022.61,
#           'humidity': 95,
#           'pressure': 1022.61,
#           'sea_level': 1031.36,
#           'temp': 73.43,
#           'temp_max': 73.43,
#           'temp_min': 73.43},
#  'name': 'Sao Jose da Coroa Grande',
#  'rain': {'3h': 0.295},
#  'sys': {'country': 'BR',
#          'message': 0.0038,
#          'sunrise': 1535271934,
#          'sunset': 1535314757},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 143.5, 'speed': 8.66}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1535248380,
#  'id': 4407665,
#  'main': {'humidity': 76,
#           'pressure': 1014,
#           'temp': 82.04,
#           'temp_max': 82.04,
#           'temp_min': 82.04},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 1664,
#          'message': 0.0444,
#          'sunrise': 1535283681,
#          'sunset': 1535331570,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 200, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 66.83, 'lon': 70.83},
#  'dt': 1535249475,
#  'id': 1486321,
#  'main': {'grnd_level': 1031.12,
#           'humidity': 100,
#           'pressure': 1031.12,
#           'sea_level': 1032.25,
#           'temp': 49.76,
#           'temp_max': 49.76,
#           'temp_min': 49.76},
#  'name': 'Yar-Sale',
#  'sys': {'country': 'RU',
#          'message': 0.0044,
#          'sunrise': 1535239595,
#          'sunset': 1535296080},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 3.00003, 'speed': 19.51}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1535245200,
#  'id': 3369157,
#  'main': {'humidity': 66,
#           'pressure': 1016,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 6529,
#          'message': 0.0042,
#          'sunrise': 1535260346,
#          'sunset': 1535300656,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 70.47, 'lon': -68.59},
#  'dt': 1535245200,
#  'id': 5924351,
#  'main': {'humidity': 93,
#           'pressure': 1009,
#           'temp': 35.6,
#           'temp_max': 35.6,
#           'temp_min': 35.6},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA',
#          'id': 3585,
#          'message': 0.0039,
#          'sunrise': 1535271616,
#          'sunset': 1535330915,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 350, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 36.62, 'lon': -121.92},
#  'dt': 1535247300,
#  'id': 5380437,
#  'main': {'humidity': 77,
#           'pressure': 1014,
#           'temp': 61.65,
#           'temp_max': 62.96,
#           'temp_min': 60.08},
#  'name': 'Pacific Grove',
#  'sys': {'country': 'US',
#          'id': 399,
#          'message': 0.0042,
#          'sunrise': 1535290454,
#          'sunset': 1535337836,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'gust': 9.8, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 47.66, 'lon': -52.73},
#  'dt': 1535245200,
#  'id': 6167817,
#  'main': {'humidity': 72,
#           'pressure': 1023,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Torbay',
#  'sys': {'country': 'CA',
#          'id': 3467,
#          'message': 0.0033,
#          'sunrise': 1535272884,
#          'sunset': 1535322182,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'gust': 12.3, 'speed': 18.34}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 36.3, 'lon': 59.61},
#  'dt': 1535247000,
#  'id': 124665,
#  'main': {'humidity': 66,
#           'pressure': 1014,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Mashhad',
#  'sys': {'country': 'IR',
#          'id': 7043,
#          'message': 0.0034,
#          'sunrise': 1535246886,
#          'sunset': 1535294287,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 6.93}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1535249214,
#  'id': 3652764,
#  'main': {'grnd_level': 1019.69,
#           'humidity': 100,
#           'pressure': 1019.69,
#           'sea_level': 1026.98,
#           'temp': 70.37,
#           'temp_max': 70.37,
#           'temp_min': 70.37},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'message': 0.0034,
#          'sunrise': 1535284821,
#          'sunset': 1535328355},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 168.5, 'speed': 12.24}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.31, 'lon': -8.72},
#  'dt': 1535248800,
#  'id': 2739997,
#  'main': {'humidity': 87,
#           'pressure': 1014,
#           'temp': 57.07,
#           'temp_max': 59,
#           'temp_min': 55.4},
#  'name': 'Mindelo',
#  'sys': {'country': 'PT',
#          'id': 5959,
#          'message': 0.003,
#          'sunrise': 1535262906,
#          'sunset': 1535311050,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 349.5, 'speed': 17.72}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 45.6, 'lon': -0.6},
#  'dt': 1535248800,
#  'id': 3026644,
#  'main': {'humidity': 93,
#           'pressure': 1018,
#           'temp': 54.59,
#           'temp_max': 55.4,
#           'temp_min': 53.6},
#  'name': 'Souillac',
#  'sys': {'country': 'FR',
#          'id': 5528,
#          'message': 0.003,
#          'sunrise': 1535260570,
#          'sunset': 1535309483,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 237, 'speed': 2.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.39, 'lon': 42.45},
#  'dt': 1535245200,
#  'id': 110690,
#  'main': {'humidity': 49,
#           'pressure': 1020,
#           'temp': 67.95,
#           'temp_max': 69.8,
#           'temp_min': 66.2},
#  'name': 'Faya',
#  'sys': {'country': 'SA',
#          'id': 6975,
#          'message': 0.0047,
#          'sunrise': 1535252070,
#          'sunset': 1535297358,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 357, 'speed': 4.74}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1535249416,
#  'id': 3372707,
#  'main': {'grnd_level': 1036.55,
#           'humidity': 100,
#           'pressure': 1036.55,
#           'sea_level': 1039.99,
#           'temp': 72.8,
#           'temp_max': 72.8,
#           'temp_min': 72.8},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'message': 0.0028,
#          'sunrise': 1535267927,
#          'sunset': 1535315623},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 48.5, 'speed': 7.54}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1535249216,
#  'id': 4020109,
#  'main': {'grnd_level': 1025.04,
#           'humidity': 100,
#           'pressure': 1025.04,
#           'sea_level': 1025.07,
#           'temp': 77.39,
#           'temp_max': 77.39,
#           'temp_min': 77.39},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0029,
#          'sunrise': 1535296896,
#          'sunset': 1535339648},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 98.5, 'speed': 18.28}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 69.44, 'lon': -133.03},
#  'dt': 1535245200,
#  'id': 6170031,
#  'main': {'humidity': 71,
#           'pressure': 1011,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 3555,
#          'message': 0.0033,
#          'sunrise': 1535287621,
#          'sunset': 1535345853,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1535249208,
#  'id': 4030556,
#  'main': {'grnd_level': 1032.91,
#           'humidity': 100,
#           'pressure': 1032.91,
#           'sea_level': 1033.02,
#           'temp': 72.53,
#           'temp_max': 72.53,
#           'temp_min': 72.53},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0035,
#          'sunrise': 1535296539,
#          'sunset': 1535338067},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 53, 'speed': 13.47}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1535245200,
#  'id': 4035715,
#  'main': {'humidity': 78,
#           'pressure': 1012,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 8340,
#          'message': 0.0039,
#          'sunrise': 1535302396,
#          'sunset': 1535344114,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 46.41, 'lon': 4.91},
#  'dt': 1535248800,
#  'id': 2996881,
#  'main': {'humidity': 100,
#           'pressure': 1018,
#           'temp': 42.8,
#           'temp_max': 42.8,
#           'temp_min': 42.8},
#  'name': 'Boz',
#  'sys': {'country': 'FR',
#          'id': 5569,
#          'message': 0.0037,
#          'sunrise': 1535259166,
#          'sunset': 1535308240,
#          'type': 1},
#  'visibility': 350,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 343, 'speed': 5.08}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1535248800,
#  'id': 3833367,
#  'main': {'humidity': 80,
#           'pressure': 1000,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 4754,
#          'message': 0.0037,
#          'sunrise': 1535282924,
#          'sunset': 1535319727,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -3.66, 'lon': 152.44},
#  'dt': 1535249453,
#  'id': 2090021,
#  'main': {'grnd_level': 1016.21,
#           'humidity': 96,
#           'pressure': 1016.21,
#           'sea_level': 1022.12,
#           'temp': 84.5,
#           'temp_max': 84.5,
#           'temp_min': 84.5},
#  'name': 'Namatanai',
#  'sys': {'country': 'PG',
#          'message': 0.0036,
#          'sunrise': 1535226693,
#          'sunset': 1535269968},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 271.5, 'speed': 3.06}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -30.17, 'lon': -50.22},
#  'dt': 1535249418,
#  'id': 3466165,
#  'main': {'grnd_level': 1028.45,
#           'humidity': 77,
#           'pressure': 1028.45,
#           'sea_level': 1039.02,
#           'temp': 48.23,
#           'temp_max': 48.23,
#           'temp_min': 48.23},
#  'name': 'Cidreira',
#  'sys': {'country': 'BR',
#          'message': 0.0041,
#          'sunrise': 1535276586,
#          'sunset': 1535317355},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 253, 'speed': 14.58}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1535247180,
#  'id': 5855927,
#  'main': {'humidity': 96,
#           'pressure': 1013,
#           'temp': 72.09,
#           'temp_max': 75.02,
#           'temp_min': 69.8},
#  'name': 'Hilo',
#  'rain': {'1h': 11.43},
#  'sys': {'country': 'US',
#          'id': 818,
#          'message': 0.0712,
#          'sunrise': 1535299418,
#          'sunset': 1535344805,
#          'type': 1},
#  'visibility': 3219,
#  'weather': [{'description': 'heavy intensity rain',
#               'icon': '10n',
#               'id': 502,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 77.5, 'speed': 18.16}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -5.56, 'lon': -80.82},
#  'dt': 1535249779,
#  'id': 3691954,
#  'main': {'grnd_level': 1025.04,
#           'humidity': 87,
#           'pressure': 1025.04,
#           'sea_level': 1027.95,
#           'temp': 65.96,
#           'temp_max': 65.96,
#           'temp_min': 65.96},
#  'name': 'Sechura',
#  'sys': {'country': 'PE',
#          'message': 0.004,
#          'sunrise': 1535282744,
#          'sunset': 1535325861},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170.5, 'speed': 9.78}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -29.69, 'lon': 152.93},
#  'dt': 1535249780,
#  'id': 2164771,
#  'main': {'grnd_level': 1013.29,
#           'humidity': 100,
#           'pressure': 1013.29,
#           'sea_level': 1028.88,
#           'temp': 56.51,
#           'temp_max': 56.51,
#           'temp_min': 56.51},
#  'name': 'Grafton',
#  'rain': {'3h': 7.105},
#  'sys': {'country': 'AU',
#          'message': 0.0036,
#          'sunrise': 1535227840,
#          'sunset': 1535268607},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 118.5, 'speed': 3.06}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 42.87, 'lon': -106.31},
#  'dt': 1535248380,
#  'id': 5820705,
#  'main': {'humidity': 32,
#           'pressure': 1014,
#           'temp': 73.94,
#           'temp_max': 73.94,
#           'temp_min': 73.94},
#  'name': 'Casper',
#  'sys': {'country': 'US',
#          'id': 3071,
#          'message': 0.004,
#          'sunrise': 1535286212,
#          'sunset': 1535334576,
#          'type': 1},
#  'visibility': 12874,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -10.68, 'lon': -77.82},
#  'dt': 1535249780,
#  'id': 3933024,
#  'main': {'grnd_level': 1023.67,
#           'humidity': 100,
#           'pressure': 1023.67,
#           'sea_level': 1028.28,
#           'temp': 60.11,
#           'temp_max': 60.11,
#           'temp_min': 60.11},
#  'name': 'Paramonga',
#  'sys': {'country': 'PE',
#          'message': 0.0033,
#          'sunrise': 1535282250,
#          'sunset': 1535324920},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153.5, 'speed': 9.55}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -6.22, 'lon': 155.63},
#  'dt': 1535249532,
#  'id': 2094027,
#  'main': {'grnd_level': 1002.51,
#           'humidity': 93,
#           'pressure': 1002.51,
#           'sea_level': 1022.16,
#           'temp': 83.24,
#           'temp_max': 83.24,
#           'temp_min': 83.24},
#  'name': 'Kieta',
#  'rain': {'3h': 0.615},
#  'sys': {'country': 'PG',
#          'message': 0.0039,
#          'sunrise': 1535226042,
#          'sunset': 1535269090},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 64, 'speed': 3.18}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 5.11, 'lon': 7.36},
#  'dt': 1535249781,
#  'id': 2353151,
#  'main': {'grnd_level': 1006.89,
#           'humidity': 97,
#           'pressure': 1006.89,
#           'sea_level': 1026.61,
#           'temp': 71.27,
#           'temp_max': 71.27,
#           'temp_min': 71.27},
#  'name': 'Aba',
#  'rain': {'3h': 0.12},
#  'sys': {'country': 'NG',
#          'message': 0.0037,
#          'sunrise': 1535261116,
#          'sunset': 1535305163},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 251, 'speed': 3.62}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.02, 'lon': 27.91},
#  'dt': 1535249225,
#  'id': 1006984,
#  'main': {'grnd_level': 1016.7,
#           'humidity': 96,
#           'pressure': 1016.7,
#           'sea_level': 1021.1,
#           'temp': 67.49,
#           'temp_max': 67.49,
#           'temp_min': 67.49},
#  'name': 'East London',
#  'sys': {'country': 'ZA',
#          'message': 0.0043,
#          'sunrise': 1535258015,
#          'sunset': 1535298432},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 256, 'speed': 21.07}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 34.7, 'lon': 138.93},
#  'dt': 1535245200,
#  'id': 1852357,
#  'main': {'humidity': 79,
#           'pressure': 1012,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Shimoda',
#  'sys': {'country': 'JP',
#          'id': 7616,
#          'message': 0.0033,
#          'sunrise': 1535227952,
#          'sunset': 1535275157,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 19.46}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 3.38, 'lon': -59.8},
#  'dt': 1535249781,
#  'id': 3379316,
#  'main': {'grnd_level': 1010.94,
#           'humidity': 58,
#           'pressure': 1010.94,
#           'sea_level': 1025.36,
#           'temp': 83.87,
#           'temp_max': 83.87,
#           'temp_min': 83.87},
#  'name': 'Lethem',
#  'rain': {'3h': 0.565},
#  'sys': {'country': 'GY',
#          'message': 0.0038,
#          'sunrise': 1535277310,
#          'sunset': 1535321201},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 46.5, 'speed': 8.66}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 50.68, 'lon': 156.12},
#  'dt': 1535249424,
#  'id': 2121385,
#  'main': {'grnd_level': 1014.02,
#           'humidity': 89,
#           'pressure': 1014.02,
#           'sea_level': 1027.18,
#           'temp': 54.08,
#           'temp_max': 54.08,
#           'temp_min': 54.08},
#  'name': 'Severo-Kurilsk',
#  'sys': {'country': 'RU',
#          'message': 0.0029,
#          'sunrise': 1535222368,
#          'sunset': 1535272462},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 285, 'speed': 3.96}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 8.41, 'lon': 48.48},
#  'dt': 1535249498,
#  'id': 58933,
#  'main': {'grnd_level': 968.71,
#           'humidity': 44,
#           'pressure': 968.71,
#           'sea_level': 1023.41,
#           'temp': 80.09,
#           'temp_max': 80.09,
#           'temp_min': 80.09},
#  'name': 'Garowe',
#  'sys': {'country': 'SO',
#          'message': 0.003,
#          'sunrise': 1535251099,
#          'sunset': 1535295444},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 19.62}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1535249209,
#  'id': 3863379,
#  'main': {'grnd_level': 998.05,
#           'humidity': 53,
#           'pressure': 998.05,
#           'sea_level': 1019.32,
#           'temp': 55.7,
#           'temp_max': 55.7,
#           'temp_min': 55.7},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.0037,
#          'sunrise': 1535281859,
#          'sunset': 1535320401},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 263.5, 'speed': 22.75}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -21.48, 'lon': -56.15},
#  'dt': 1535249782,
#  'id': 3460087,
#  'main': {'grnd_level': 1000.48,
#           'humidity': 56,
#           'pressure': 1000.48,
#           'sea_level': 1039.58,
#           'temp': 54.08,
#           'temp_max': 54.08,
#           'temp_min': 54.08},
#  'name': 'Jardim',
#  'sys': {'country': 'BR',
#          'message': 0.0035,
#          'sunrise': 1535277553,
#          'sunset': 1535319226},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 188.5, 'speed': 10.67}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.08},
#  'dt': 1535249417,
#  'id': 1282256,
#  'main': {'grnd_level': 1023.99,
#           'humidity': 100,
#           'pressure': 1023.99,
#           'sea_level': 1024.06,
#           'temp': 80.9,
#           'temp_max': 80.9,
#           'temp_min': 80.9},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV',
#          'message': 0.0034,
#          'sunrise': 1535245600,
#          'sunset': 1535289145},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 259, 'speed': 7.76}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1535249410,
#  'id': 6201424,
#  'main': {'grnd_level': 1011.35,
#           'humidity': 70,
#           'pressure': 1011.35,
#           'sea_level': 1026.41,
#           'temp': 56.42,
#           'temp_max': 56.42,
#           'temp_min': 56.42},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'message': 0.0042,
#          'sunrise': 1535225177,
#          'sunset': 1535263642},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 303.5, 'speed': 19.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1535249431,
#  'id': 2208248,
#  'main': {'grnd_level': 1009.48,
#           'humidity': 68,
#           'pressure': 1009.48,
#           'sea_level': 1026.33,
#           'temp': 56.6,
#           'temp_max': 56.6,
#           'temp_min': 56.6},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'message': 0.0048,
#          'sunrise': 1535224948,
#          'sunset': 1535263396},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 287.5, 'speed': 19.73}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -3.9, 'lon': -38.39},
#  'dt': 1535248800,
#  'id': 3407407,
#  'main': {'humidity': 83,
#           'pressure': 1015,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Aquiraz',
#  'sys': {'country': 'BR',
#          'id': 4498,
#          'message': 0.0039,
#          'sunrise': 1535272491,
#          'sunset': 1535315751,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1535247000,
#  'id': 546105,
#  'main': {'humidity': 93,
#           'pressure': 1009,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 7267,
#          'message': 0.0038,
#          'sunrise': 1535251091,
#          'sunset': 1535303852,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 21.39, 'lon': -157.74},
#  'dt': 1535245020,
#  'id': 5847486,
#  'main': {'humidity': 79,
#           'pressure': 1012,
#           'temp': 81.99,
#           'temp_max': 84.92,
#           'temp_min': 77},
#  'name': 'Kailua',
#  'rain': {'1h': 1.52},
#  'sys': {'country': 'US',
#          'id': 828,
#          'message': 0.0038,
#          'sunrise': 1535299970,
#          'sunset': 1535345527,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 60, 'gust': 12.3, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -0.72, 'lon': 8.78},
#  'dt': 1535249529,
#  'id': 2396518,
#  'main': {'grnd_level': 1026.18,
#           'humidity': 100,
#           'pressure': 1026.18,
#           'sea_level': 1026.53,
#           'temp': 73.7,
#           'temp_max': 73.7,
#           'temp_min': 73.7},
#  'name': 'Port-Gentil',
#  'sys': {'country': 'GA',
#          'message': 0.0047,
#          'sunrise': 1535261034,
#          'sunset': 1535304569},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220.5, 'speed': 7.76}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.28, 'lon': 20.71},
#  'dt': 1535249508,
#  'id': 787487,
#  'main': {'grnd_level': 903.29,
#           'humidity': 95,
#           'pressure': 903.29,
#           'sea_level': 1023.29,
#           'temp': 55.7,
#           'temp_max': 55.7,
#           'temp_min': 55.7},
#  'name': 'Poum',
#  'sys': {'country': 'MK',
#          'message': 0.0035,
#          'sunrise': 1535255841,
#          'sunset': 1535303993},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 271, 'speed': 2.39}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 60.75, 'lon': -137.51},
#  'dt': 1535249694,
#  'id': 5969025,
#  'main': {'grnd_level': 901.92,
#           'humidity': 83,
#           'pressure': 901.92,
#           'sea_level': 1027.79,
#           'temp': 48.95,
#           'temp_max': 48.95,
#           'temp_min': 48.95},
#  'name': 'Haines Junction',
#  'rain': {'3h': 1.025},
#  'sys': {'country': 'CA',
#          'message': 0.0041,
#          'sunrise': 1535291338,
#          'sunset': 1535344368},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 57.5, 'speed': 2.06}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1535245200,
#  'id': 6185377,
#  'main': {'humidity': 62,
#           'pressure': 1012,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 3558,
#          'message': 0.0034,
#          'sunrise': 1535285398,
#          'sunset': 1535339197,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.69, 'lon': 12.92},
#  'dt': 1535249405,
#  'id': 2446796,
#  'main': {'grnd_level': 967.41,
#           'humidity': 57,
#           'pressure': 967.41,
#           'sea_level': 1024.02,
#           'temp': 80.63,
#           'temp_max': 80.63,
#           'temp_min': 80.63},
#  'name': 'Bilma',
#  'sys': {'country': 'NE',
#          'message': 0.0141,
#          'sunrise': 1535259143,
#          'sunset': 1535304457},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 223.5, 'speed': 11.12}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1535249206,
#  'id': 964432,
#  'main': {'grnd_level': 1012.64,
#           'humidity': 69,
#           'pressure': 1012.64,
#           'sea_level': 1021.39,
#           'temp': 64.16,
#           'temp_max': 64.16,
#           'temp_min': 64.16},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'message': 0.0033,
#          'sunrise': 1535258295,
#          'sunset': 1535298643},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 276, 'speed': 19.28}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 69.22, 'lon': -51.1},
#  'dt': 1535248200,
#  'id': 3423146,
#  'main': {'humidity': 93,
#           'pressure': 1011,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ilulissat',
#  'sys': {'country': 'GL',
#          'id': 4805,
#          'message': 0.0089,
#          'sunrise': 1535267998,
#          'sunset': 1535326160,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 51.07, 'lon': 132.56},
#  'dt': 1535249784,
#  'id': 2047258,
#  'main': {'grnd_level': 972.76,
#           'humidity': 82,
#           'pressure': 972.76,
#           'sea_level': 1022.36,
#           'temp': 72.26,
#           'temp_max': 72.26,
#           'temp_min': 72.26},
#  'name': 'Novyy Urgal',
#  'sys': {'country': 'RU',
#          'message': 0.0047,
#          'sunrise': 1535227980,
#          'sunset': 1535278154},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 62, 'speed': 3.96}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 37.14, 'lon': -8.45},
#  'dt': 1535247000,
#  'id': 2267254,
#  'main': {'humidity': 31,
#           'pressure': 1011,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Lagoa',
#  'sys': {'country': 'PT',
#          'id': 5948,
#          'message': 0.0042,
#          'sunrise': 1535263168,
#          'sunset': 1535310666,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -45.58, 'lon': -72.07},
#  'dt': 1535245200,
#  'id': 3894426,
#  'main': {'humidity': 87,
#           'pressure': 1011,
#           'temp': 44.31,
#           'temp_max': 46.4,
#           'temp_min': 42.8},
#  'name': 'Coihaique',
#  'sys': {'country': 'CL',
#          'id': 4643,
#          'message': 0.0058,
#          'sunrise': 1535282876,
#          'sunset': 1535321566,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 50, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1535247000,
#  'id': 2163355,
#  'main': {'humidity': 47,
#           'pressure': 1007,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0041,
#          'sunrise': 1535230060,
#          'sunset': 1535269087,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1535249411,
#  'id': 2069194,
#  'main': {'grnd_level': 975.36,
#           'humidity': 50,
#           'pressure': 975.36,
#           'sea_level': 1034.64,
#           'temp': 61.28,
#           'temp_max': 61.28,
#           'temp_min': 61.28},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0037,
#          'sunrise': 1535231484,
#          'sunset': 1535271843},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 236, 'speed': 7.2}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1535245200,
#  'id': 3874787,
#  'main': {'humidity': 86,
#           'pressure': 1001,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 4642,
#          'message': 0.0032,
#          'sunrise': 1535283348,
#          'sunset': 1535320549,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -28.95, 'lon': 153.24},
#  'dt': 1535249684,
#  'id': 2160063,
#  'main': {'grnd_level': 1001.86,
#           'humidity': 100,
#           'pressure': 1001.86,
#           'sea_level': 1028.52,
#           'temp': 56.96,
#           'temp_max': 56.96,
#           'temp_min': 56.96},
#  'name': 'Codrington',
#  'rain': {'3h': 5.455},
#  'sys': {'country': 'AU',
#          'message': 0.0092,
#          'sunrise': 1535227723,
#          'sunset': 1535268574},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 60.5, 'speed': 4.41}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 66.94, 'lon': -53.67},
#  'dt': 1535249523,
#  'id': 3419842,
#  'main': {'grnd_level': 986.38,
#           'humidity': 95,
#           'pressure': 986.38,
#           'sea_level': 1022.56,
#           'temp': 33.92,
#           'temp_max': 33.92,
#           'temp_min': 33.92},
#  'name': 'Sisimiut',
#  'sys': {'country': 'GL',
#          'message': 0.1634,
#          'sunrise': 1535269510,
#          'sunset': 1535325912},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 17.5, 'speed': 2.39}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 65.28, 'lon': -126.83},
#  'dt': 1535245200,
#  'id': 6089245,
#  'main': {'humidity': 93,
#           'pressure': 1009,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA',
#          'id': 3547,
#          'message': 0.0033,
#          'sunrise': 1535287643,
#          'sunset': 1535342906,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 280, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 17.01, 'lon': 54.1},
#  'dt': 1535244600,
#  'id': 286621,
#  'main': {'humidity': 100,
#           'pressure': 1002,
#           'temp': 73.4,
# ...
#  'sys': {'country': 'RU',
#          'id': 7248,
#          'message': 0.0034,
#          'sunrise': 1535221453,
#          'sunset': 1535272155,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 4.47}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 20.78, 'lon': 97.03},
#  'dt': 1535249866,
#  'id': 1293960,
#  'main': {'grnd_level': 887.08,
#           'humidity': 92,
#           'pressure': 887.08,
#           'sea_level': 1017.05,
#           'temp': 72.17,
#           'temp_max': 72.17,
#           'temp_min': 72.17},
#  'name': 'Taunggyi',
#  'sys': {'country': 'MM',
#          'message': 0.0038,
#          'sunrise': 1535238846,
#          'sunset': 1535284387},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 166.5, 'speed': 4.18}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 23.99, 'lon': -104.67},
#  'dt': 1535244180,
#  'id': 4011743,
#  'main': {'humidity': 39,
#           'pressure': 1021,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Constitucion',
#  'sys': {'country': 'MX',
#          'id': 3983,
#          'message': 0.0032,
#          'sunrise': 1535287093,
#          'sunset': 1535332933,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -39.94, 'lon': 176.59},
#  'dt': 1535249867,
#  'id': 2185329,
#  'main': {'grnd_level': 1000.08,
#           'humidity': 61,
#           'pressure': 1000.08,
#           'sea_level': 1031.92,
#           'temp': 59.03,
#           'temp_max': 59.03,
#           'temp_min': 59.03},
#  'name': 'Waipawa',
#  'sys': {'country': 'NZ',
#          'message': 0.0033,
#          'sunrise': 1535222822,
#          'sunset': 1535262280},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 278.5, 'speed': 5.08}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 33.33, 'lon': -105.67},
#  'dt': 1535248500,
#  'id': 5488598,
#  'main': {'humidity': 49,
#           'pressure': 1026,
#           'temp': 81.28,
#           'temp_max': 88.88,
#           'temp_min': 71.6},
#  'name': 'Ruidoso',
#  'rain': {'3h': 0.28},
#  'sys': {'country': 'US',
#          'id': 2027,
#          'message': 0.0044,
#          'sunrise': 1535286778,
#          'sunset': 1535333718,
#          'type': 1},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 250, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 55.07, 'lon': -117.28},
#  'dt': 1535249868,
#  'id': 6173220,
#  'main': {'grnd_level': 940.82,
#           'humidity': 82,
#           'pressure': 940.82,
#           'sea_level': 1021.71,
#           'temp': 55.79,
#           'temp_max': 55.79,
#           'temp_min': 55.79},
#  'name': 'Valleyview',
#  'rain': {'3h': 0.14},
#  'sys': {'country': 'CA',
#          'message': 0.0031,
#          'sunrise': 1535287472,
#          'sunset': 1535338550},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 221.5, 'speed': 5.64}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.88, 'lon': 10.89},
#  'dt': 1535248500,
#  'id': 3172402,
#  'main': {'humidity': 94,
#           'pressure': 1011,
#           'temp': 49.42,
#           'temp_max': 64.4,
#           'temp_min': 32},
#  'name': 'Nago',
#  'sys': {'country': 'IT',
#          'id': 5875,
#          'message': 0.0043,
#          'sunrise': 1535257783,
#          'sunset': 1535306755,
#          'type': 1},
#  'visibility': 50,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 20, 'speed': 32.21}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 43.06, 'lon': 47.33},
#  'dt': 1535247000,
#  'id': 495893,
#  'main': {'humidity': 82,
#           'pressure': 1011,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Shamkhal',
#  'sys': {'country': 'RU',
#          'id': 7297,
#          'message': 0.0033,
#          'sunrise': 1535249294,
#          'sunset': 1535297761,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 6.71}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.51, 'lon': 47.65},
#  'dt': 1535249868,
#  'id': 587116,
#  'main': {'grnd_level': 991.08,
#           'humidity': 78,
#           'pressure': 991.08,
#           'sea_level': 1024.63,
#           'temp': 62.63,
#           'temp_max': 62.63,
#           'temp_min': 62.63},
#  'name': 'Ucar',
#  'sys': {'country': 'AZ',
#          'message': 0.0056,
#          'sunrise': 1535249435,
#          'sunset': 1535297471},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 43, 'speed': 0.94}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 11.74, 'lon': 41.09},
#  'dt': 1535249868,
#  'id': 338554,
#  'main': {'grnd_level': 960.04,
#           'humidity': 60,
#           'pressure': 960.04,
#           'sea_level': 1021.59,
#           'temp': 77.39,
#           'temp_max': 77.39,
#           'temp_min': 77.39},
#  'name': 'Dubti',
#  'sys': {'country': 'ET',
#          'message': 0.0083,
#          'sunrise': 1535252719,
#          'sunset': 1535297368},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 207.5, 'speed': 3.74}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 41.48, 'lon': 24.85},
#  'dt': 1535248200,
#  'id': 727552,
#  'main': {'humidity': 73,
#           'pressure': 1007,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Rudozem',
#  'sys': {'country': 'BG',
#          'id': 5684,
#          'message': 0.0034,
#          'sunrise': 1535254830,
#          'sunset': 1535303016,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -42.45, 'lon': 171.21},
#  'dt': 1535249869,
#  'id': 2206895,
#  'main': {'grnd_level': 1022.37,
#           'humidity': 100,
#           'pressure': 1022.37,
#           'sea_level': 1033.71,
#           'temp': 51.11,
#           'temp_max': 51.11,
#           'temp_min': 51.11},
#  'name': 'Greymouth',
#  'sys': {'country': 'NZ',
#          'message': 0.0032,
#          'sunrise': 1535224301,
#          'sunset': 1535263386},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 244, 'speed': 4.52}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 46.19, 'lon': 26.84},
#  'dt': 1535248800,
#  'id': 667917,
#  'main': {'humidity': 93,
#           'pressure': 1010,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Bogdana',
#  'sys': {'country': 'RO',
#          'id': 5984,
#          'message': 0.0061,
#          'sunrise': 1535253920,
#          'sunset': 1535302962,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 42.18, 'lon': 127.48},
#  'dt': 1535249869,
#  'id': 2034691,
#  'main': {'grnd_level': 935.96,
#           'humidity': 85,
#           'pressure': 935.96,
#           'sea_level': 1025.03,
#           'temp': 64.34,
#           'temp_max': 64.34,
#           'temp_min': 64.34},
#  'name': 'Songjianghe',
#  'sys': {'country': 'CN',
#          'message': 0.0037,
#          'sunrise': 1535230121,
#          'sunset': 1535278471},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 259.5, 'speed': 6.08}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 63.73, 'lon': 8.83},
#  'dt': 1535248200,
#  'id': 3139597,
#  'main': {'humidity': 93,
#           'pressure': 1004,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Sistranda',
#  'sys': {'country': 'NO',
#          'id': 5316,
#          'message': 0.0033,
#          'sunrise': 1535255450,
#          'sunset': 1535310006,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 240, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 6.19, 'lon': -67.49},
#  'dt': 1535249498,
#  'id': 3671519,
#  'main': {'grnd_level': 955.25,
#           'humidity': 92,
#           'pressure': 955.25,
#           'sea_level': 1026.33,
#           'temp': 70.1,
#           'temp_max': 70.1,
#           'temp_min': 70.1},
#  'name': 'Puerto Carreno',
#  'sys': {'country': 'CO',
#          'message': 0.0036,
#          'sunrise': 1535279031,
#          'sunset': 1535323169},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 152, 'speed': 2.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23, 'lon': 27.67},
#  'dt': 1535249870,
#  'id': 933313,
#  'main': {'grnd_level': 926.88,
#           'humidity': 76,
#           'pressure': 926.88,
#           'sea_level': 1030.51,
#           'temp': 54.89,
#           'temp_max': 54.89,
#           'temp_min': 54.89},
#  'name': 'Mokobeng',
#  'sys': {'country': 'BW',
#          'message': 0.0073,
#          'sunrise': 1535257524,
#          'sunset': 1535299030},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 51, 'speed': 5.97}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 37.17, 'lon': -99.65},
#  'dt': 1535249457,
#  'id': 4267710,
#  'main': {'grnd_level': 953.47,
#           'humidity': 49,
#           'pressure': 953.47,
#           'sea_level': 1024.43,
#           'temp': 82.52,
#           'temp_max': 82.52,
#           'temp_min': 82.52},
#  'name': 'Sitka',
#  'rain': {'3h': 0.984},
#  'sys': {'country': 'US',
#          'message': 0.003,
#          'sunrise': 1535285066,
#          'sunset': 1535332535},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 220.5, 'speed': 8.43}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 32.86, 'lon': 59.22},
#  'dt': 1535245200,
#  'id': 140463,
#  'main': {'humidity': 25,
#           'pressure': 1013,
#           'temp': 62.6,
#           'temp_max': 62.6,
#           'temp_min': 62.6},
#  'name': 'Birjand',
#  'sys': {'country': 'IR',
#          'id': 7041,
#          'message': 0.0034,
#          'sunrise': 1535247217,
#          'sunset': 1535294148,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 9.17}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 50.39, 'lon': 30.37},
#  'dt': 1535248800,
#  'id': 689487,
#  'main': {'humidity': 71,
#           'pressure': 1012,
#           'temp': 59.7,
#           'temp_max': 62.6,
#           'temp_min': 55.4},
#  'name': 'Vyshneve',
#  'sys': {'country': 'UA',
#          'id': 7348,
#          'message': 0.0039,
#          'sunrise': 1535252615,
#          'sunset': 1535302563,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 68.05, 'lon': 39.51},
#  'dt': 1535249654,
#  'id': 556268,
#  'main': {'grnd_level': 994.4,
#           'humidity': 77,
#           'pressure': 994.4,
#           'sea_level': 1019.36,
#           'temp': 61.28,
#           'temp_max': 61.28,
#           'temp_min': 61.28},
#  'name': 'Ostrovnoy',
#  'rain': {'3h': 0.13},
#  'sys': {'country': 'RU',
#          'message': 0.0033,
#          'sunrise': 1535246679,
#          'sunset': 1535304011},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 201.5, 'speed': 16.6}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 25.65, 'lon': 87.89},
#  'dt': 1535249871,
#  'id': 1259047,
#  'main': {'grnd_level': 1009.08,
#           'humidity': 91,
#           'pressure': 1009.08,
#           'sea_level': 1012.8,
#           'temp': 82.88,
#           'temp_max': 82.88,
#           'temp_min': 82.88},
#  'name': 'Jian',
#  'sys': {'country': 'IN',
#          'message': 0.0036,
#          'sunrise': 1535240774,
#          'sunset': 1535286840},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 81, 'speed': 7.2}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -7.47, 'lon': -34.81},
#  'dt': 1535245200,
#  'id': 3391889,
#  'main': {'humidity': 94,
#           'pressure': 1018,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Pitimbu',
#  'sys': {'country': 'BR',
#          'id': 4516,
#          'message': 0.0034,
#          'sunrise': 1535271789,
#          'sunset': 1535314738,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.12, 'lon': -5.53},
#  'dt': 1535244600,
#  'id': 2640377,
#  'main': {'humidity': 76,
#           'pressure': 1015,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Penzance',
#  'rain': {'3h': 4.04},
#  'sys': {'country': 'GB',
#          'id': 5070,
#          'message': 0.0037,
#          'sunrise': 1535261272,
#          'sunset': 1535311136,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 170, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -8.45, 'lon': 120.42},
#  'dt': 1535249872,
#  'id': 1629380,
#  'main': {'grnd_level': 976.41,
#           'humidity': 78,
#           'pressure': 976.41,
#           'sea_level': 1026.13,
#           'temp': 79.82,
#           'temp_max': 79.82,
#           'temp_min': 79.82},
#  'name': 'Latung',
#  'sys': {'country': 'ID',
#          'message': 0.0058,
#          'sunrise': 1535234590,
#          'sunset': 1535277442},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 2.95}}

# %%
weather_dict = {
    "city": cities_list,
    "country": country_list,
    "id_list": id_list,
    "lat": latss,
    "lngs": longss,
    "temp": tempature,
    "cloud":cloud,
    "cloud percent":cloud_percent,
    "humidity": humidity,
    "wind": wind
}

# %%
weather_data = pd.DataFrame.from_dict(weather_dict)
weather_df = weather_data.rename(columns={"country": "Country",
                                          "city": "City",
                                          "id_list": "ID Number",
                                          "lat": "Latitude",
                                          "lngs": "Longitude",
                                          "cloud": "Cloudiness",
                                          "cloud percent": "Cloud Percentage",
                                          "wind": "Wind Speed (mph)",
                                          "temp": "Temperature (F)", 
                                          "humidity": "Humidity (%)"      
                                         })
weather_df
# Out:
#                           City Country  ID Number  Latitude  Longitude  \
# 0                        Nizwa      OM     286987     22.93      57.53
# 1                      Ahipara      NZ    2194098    -35.17     173.16
# 2                       Barrow      AR    3833859    -38.31     -60.23
# 3                     Tasiilaq      GL    3424607     65.61     -37.64
# 4                        Rabat      MA    2538474     34.02      -6.83
# 5                    Busselton      AU    2075265    -33.64     115.35
# 6                        Tabou      CI    2281120      4.42      -7.36
# 7                    Crestview      US    4152311     30.76     -86.57
# 8                      Totness      US    4589590     33.74     -80.80
# 9                     Damaturu      NG    2345521     11.75      11.96
# 10                      Faanui      PF    4034551    -16.48    -151.75
# 11                    Itaituba      BR    3397967     -4.26     -55.99
# 12                  Winnemucca      US    5710360     40.97    -117.74
# 13                     Russell      AR    3844421    -33.01     -68.80
# 14                  Coahuayana      MX    3981460     18.62    -100.35
# 15                      Albany      US    5106834     42.65     -73.75
# 16    Sao Jose da Coroa Grande      BR    3388456     -8.90     -35.15
# 17                      Kodiak      US    4407665     39.95     -94.76
# 18                    Yar-Sale      RU    1486321     66.83      70.83
# 19                   Cape Town      ZA    3369157    -33.93      18.42
# 20                 Clyde River      CA    5924351     70.47     -68.59
# 21               Pacific Grove      US    5380437     36.62    -121.92
# 22                      Torbay      CA    6167817     47.66     -52.73
# 23                     Mashhad      IR     124665     36.30      59.61
# 24                Puerto Ayora      EC    3652764     -0.74     -90.35
# 25                     Mindelo      PT    2739997     41.31      -8.72
# 26                    Souillac      FR    3026644     45.60      -0.60
# 27                        Faya      SA     110690     18.39      42.45
# 28              Ribeira Grande      PT    3372707     38.52     -28.70
# 29                      Atuona      PF    4020109     -9.80    -139.03
# ..                         ...     ...        ...       ...        ...
# 523                Bandarbeyla      SO      64814      9.49      50.81
# 524                   Armidale      AU    2177671    -30.51     151.67
# 525                  Piacabucu      BR    3454005    -10.41     -36.43
# 526           Valenca do Piaui      BR    3385592     -6.41     -41.75
# 527                Santa Lucia      IT    2522890     39.93       9.66
# 528  Petropavlovsk-Kamchatskiy      RU    2122104     53.05     158.65
# 529                   Taunggyi      MM    1293960     20.78      97.03
# 530               Constitucion      MX    4011743     23.99    -104.67
# 531                    Waipawa      NZ    2185329    -39.94     176.59
# 532                    Ruidoso      US    5488598     33.33    -105.67
# 533                 Valleyview      CA    6173220     55.07    -117.28
# 534                       Nago      IT    3172402     45.88      10.89
# 535                   Shamkhal      RU     495893     43.06      47.33
# 536                       Ucar      AZ     587116     40.51      47.65
# 537                      Dubti      ET     338554     11.74      41.09
# 538                    Rudozem      BG     727552     41.48      24.85
# 539                  Greymouth      NZ    2206895    -42.45     171.21
# 540                    Bogdana      RO     667917     46.19      26.84
# 541                Songjianghe      CN    2034691     42.18     127.48
# 542                  Sistranda      NO    3139597     63.73       8.83
# 543             Puerto Carreno      CO    3671519      6.19     -67.49
# 544                   Mokobeng      BW     933313    -23.00      27.67
# 545                      Sitka      US    4267710     37.17     -99.65
# 546                    Birjand      IR     140463     32.86      59.22
# 547                   Vyshneve      UA     689487     50.39      30.37
# 548                  Ostrovnoy      RU     556268     68.05      39.51
# 549                       Jian      IN    1259047     25.65      87.89
# 550                    Pitimbu      BR    3391889     -7.47     -34.81
# 551                   Penzance      GB    2640377     50.12      -5.53
# 552                     Latung      ID    1629380     -8.45     120.42
#
#      Temperature (F)        Cloudiness  Cloud Percentage  Humidity (%)  \
# 0              73.34         clear sky                 0            51
# 1              57.23     broken clouds                64            85
# 2              38.24         clear sky                 0            42
# 3              41.57   overcast clouds                92           100
# 4              64.40  scattered clouds                40            88
# 5              57.05  scattered clouds                44           100
# 6              77.21   overcast clouds                92           100
# 7              80.19              mist                 1            93
# 8              74.70         clear sky                 1            85
# 9              70.01         clear sky                 0            94
# 10             78.29         clear sky                 0           100
# 11             80.45        light rain                44            67
# 12             80.96         clear sky                 1             4
# 13             51.80         clear sky                 0            70
# 14             67.67        light rain                44            92
# 15             68.00     broken clouds                75            61
# 16             73.43        light rain                92            95
# 17             82.04         clear sky                 1            76
# 18             49.76        few clouds                20           100
# 19             48.20     broken clouds                75            66
# 20             35.60         clear sky                 1            93
# 21             61.65         clear sky                 1            77
# 22             64.40         clear sky                 5            72
# 23             68.00         clear sky                 0            66
# 24             70.37        few clouds                12           100
# 25             57.07         clear sky                 0            87
# 26             54.59              mist                20            93
# 27             67.95         clear sky                 0            49
# 28             72.80         clear sky                 8           100
# 29             77.39     broken clouds                68           100
# ..               ...               ...               ...           ...
# 523            76.76        few clouds                20            88
# 524            51.92        light rain                48            94
# 525            74.24   overcast clouds                88            79
# 526            80.45         clear sky                 0            32
# 527            73.40  scattered clouds                40            38
# 528            64.40        few clouds                20            63
# 529            72.17     broken clouds                64            92
# 530            78.80   overcast clouds                90            39
# 531            59.03         clear sky                 0            61
# 532            81.28        light rain                12            49
# 533            55.79        light rain                68            82
# 534            49.42               fog                90            94
# 535            68.00  scattered clouds                40            82
# 536            62.63         clear sky                 0            78
# 537            77.39   overcast clouds                88            60
# 538            69.80        few clouds                20            73
# 539            51.11   overcast clouds                88           100
# 540            60.80         clear sky                 0            93
# 541            64.34        few clouds                24            85
# 542            46.40       shower rain                75            93
# 543            70.10     broken clouds                56            92
# 544            54.89         clear sky                 0            76
# 545            82.52        light rain                64            49
# 546            62.60         clear sky                 0            25
# 547            59.70         clear sky                 0            71
# 548            61.28        light rain                88            77
# 549            82.88     broken clouds                64            91
# 550            73.40  scattered clouds                40            94
# 551            57.20     moderate rain               100            76
# 552            79.82         clear sky                 8            78
#
#      Wind Speed (mph)
# 0                2.51
# 1               10.78
# 2               12.24
# 3                3.18
# 4                1.61
# 5                6.42
# 6               18.16
# 7                4.41
# 8                5.64
# 9                6.20
# 10               6.20
# 11               2.17
# 12               9.17
# 13               2.06
# 14               1.72
# 15               8.05
# 16               8.66
# 17               9.17
# 18              19.51
# 19              11.41
# 20               6.93
# 21              16.11
# 22              18.34
# 23               6.93
# 24              12.24
# 25              17.72
# 26               2.73
# 27               4.74
# 28               7.54
# 29              18.28
# ..                ...
# 523             29.68
# 524              5.53
# 525              7.99
# 526             11.56
# 527              6.93
# 528              4.47
# 529              4.18
# 530              9.17
# 531              5.08
# 532              8.05
# 533              5.64
# 534             32.21
# 535              6.71
# 536              0.94
# 537              3.74
# 538              6.93
# 539              4.52
# 540              3.36
# 541              6.08
# 542             10.29
# 543              2.73
# 544              5.97
# 545              8.43
# 546              9.17
# 547              2.24
# 548             16.60
# 549              7.20
# 550              6.93
# 551             10.29
# 552              2.95
#
# [553 rows x 10 columns]

# %%
# wn_carrier = data[data['unique_carrier'] == 'WN']
# wn_carrier['arr_delay'].hist

# %% [raw]
# bin_values

# %%
# INPUT

# bin_values = np.arange(start=-50, stop=200, step=10)
# us_mq_airlines_index = data['unique_carrier'].isin(['US','MQ']) # create index of flights from those airlines
# us_mq_airlines = data[us_mq_airlines_index] # select rows
# group_carriers = us_mq_airlines.groupby('unique_carrier')['arr_delay'] # group values by carrier, select minutes delayed
# group_carriers.plot(kind='hist', bins=bin_values, figsize=[12,6], alpha=.4, legend=True) # alpha for transparency

# %%
plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], s=50,

# %%
plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], s=50,
            label = "City", color = "lightcoral", edgecolors="black", alpha = .7)



plt.xlabel("Latitude")
plt.ylabel("Temperature Per City (F)")

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], s=50,
            label = "City", color = "gold", edgecolors="black", alpha = 0.7)


plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %%
plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], s=50,
            label = "City", color = "green", edgecolors="black", alpha = 0.5)

# %%
plt.scatter(weather_df["Wind Speed (mph)"], weather_df["Latitude"], s=50,
            label = "City", color = "purple", edgecolors="black", alpha = 0.60)

plt.show()

# %%
plt.suptitle("weather analysis as of 08/25/18", verticalalignment='bottom', fontsize=16)

plt.title("Note: Circle size correlates with driver count per city.", 
          fontstyle = 'italic', fontsize=12)


        
plt.grid(color='black', linewidth=.25)



lgnd = plt.legend(frameon = True, edgecolor = "black")

# %%
grouped = weather_df.groupby("city")
avg_fare = grouped["fare"].mean()
total_rides = grouped["ride_id"].count()
driver_count = grouped["driver_count"].sum()

total_drivers = (driver_count // total_rides)

city_types = city_df.groupby("type")
city_type = city_df.set_index("city")["type"]

ride_sharing_df = pd.DataFrame({
    "Average Fare per City": avg_fare,
    "Number of Rides": total_rides,
    "Number of Drivers": total_drivers,
    "City Type": city_type})

ride_sharing_df.head()
