# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time
from pprint import pprint
from citipy import citipy
import keys
import random
import seaborn as sns

# %%
cities_name = []

#generate random latitude and longitude points
random_lat_long = []
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


#find nearest city with location points
for location in lat_lngs:
    city = citipy.nearest_city(location[0],location[1]).city_name
#append cities to list  
    if city not in cities_name:
        cities_name.append(city)

# %%
print(cities_name)
# Out:
# ['busselton', 'cape town', 'ventspils', 'nouadhibou', 'saint george', 'kieta', 'kruisfontein', 'baruun-urt', 'avarua', 'ushuaia', 'barrow', 'qui nhon', 'rikitea', 'guangshui', 'mataura', 'thiruvananthapuram', 'trinidad', 'grand river south east', 'upernavik', 'tumannyy', 'naze', 'ancud', 'luderitz', 'hermanus', 'tarauaca', 'hobart', 'orlik', 'hilo', 'attawapiskat', 'tecoanapa', 'tasiilaq', 'jamestown', 'lompoc', 'cabo san lucas', 'namtsy', 'illoqqortoormiut', 'pisco', 'ilhabela', 'bluff', 'georgetown', 'jinxiang', 'thompson', 'punta arenas', 'pavlovka', 'kapaa', 'amderma', 'taolanaro', 'katsuura', 'barentsburg', 'richards bay', 'aksarka', 'khatanga', 'alofi', 'ribeira grande', 'isiro', 'longyearbyen', 'butaritari', 'samusu', 'port alfred', 'atuona', 'kamenskoye', 'berlevag', 'mekhe', 'darhan', 'yellowknife', 'ust-kuyga', 'sentyabrskiy', 'road town', 'halalo', 'labuhan', 'savonlinna', 'lakes entrance', 'clyde river', 'albany', 'havoysund', 'lagoa', 'kaitangata', 'bengkulu', 'buala', 'grand-santi', 'flinders', 'victoria', 'olafsvik', 'karauzyak', 'pangnirtung', 'tuatapere', 'musoma', 'riyadh', 'nanortalik', 'narsaq', 'ornskoldsvik', 'vaini', 'alekseyevka', 'saleaula', 'rungata', 'vista hermosa', 'nichinan', 'zhigansk', 'saint-leu', 'bredasdorp', 'rocha', 'malegaon', 'torbay', 'arraial do cabo', 'castro', 'felidhoo', 'la ronge', 'hasaki', 'cidreira', 'san andres', 'orocue', 'coahuayana', 'yomitan', 'banda aceh', 'talara', 'saint-georges', 'tuktoyaktuk', 'nata', 'port elizabeth', 'belushya guba', 'zhanakorgan', 'deputatskiy', 'nisia floresta', 'salinas', 'meadow lake', 'mys shmidta', 'necochea', 'ilulissat', 'tiznit', 'oktyabrskoye', 'conceicao do araguaia', 'soubre', 'maniitsoq', 'xinyu', 'bethel', 'hami', 'port blair', 'cherskiy', 'caravelas', 'hambantota', 'codrington', 'hithadhoo', 'chapais', 'darapidap', 'sision', 'moose jaw', 'smithers', 'bad berleburg', 'new norfolk', 'san policarpo', 'mar del plata', 'raduzhnyy', 'bubaque', 'flin flon', 'sept-iles', 'ginir', 'mutoko', 'qaanaaq', 'nouakchott', 'chase', 'verkhoyansk', 'chokurdakh', 'jardim', 'sao filipe', 'lebu', 'tabou', 'husavik', 'palmer', 'ossora', 'manzhouli', 'rjukan', 'lahij', 'raga', 'mopipi', 'turka', 'tiksi', 'bermejo', 'petrolina', 'jambi', 'kumluca', 'puerto ayora', 'saldanha', 'rehoboth', 'barbar', 'amapa', 'henties bay', 'chokwe', 'stettler', 'charters towers', 'hendijan', 'qaqortoq', 'lata', 'yeniseysk', 'chuy', 'bathsheba', 'asahikawa', 'japura', 'dingle', 'khani', 'carnarvon', 'smithville', 'sawakin', 'jacarau', 'mayo', 'male', 'zhuhai', 'lorengau', 'dakar', 'north bend', 'sivas', 'nikolskoye', 'krasnoborsk', 'spornoye', 'quepos', 'half moon bay', 'zabol', 'mao', 'ystad', 'east london', 'lumeje', 'tsihombe', 'kahului', 'kedrovyy', 'pimentel', 'faanui', 'santa marta', 'fairlie', 'leh', 'hvolsvollur', 'sinnamary', 'gamba', 'salalah', 'yantal', 'charleville', 'erenhot', 'puerto colombia', 'khorixas', 'fortuna', 'lavrentiya', 'saskylakh', 'kodiak', 'khersonisos', 'guerrero negro', 'geraldton', 'alta floresta', 'chulman', 'luanda', 'magaria', 'strezhevoy', 'mahebourg', 'ponta do sol', 'korem', 'natal', 'byron bay', 'vao', 'don benito', 'patnos', 'minot', 'lakatoro', 'yulara', 'nukus', 'envira', 'kavieng', 'teacapan', 'bundaberg', 'careiro da varzea', 'san quintin', 'miles city', 'tupik', 'roald', 'yenagoa', 'provideniya', 'fairbanks', 'dubbo', 'hirara', 'neuquen', 'vestmannaeyjar', 'sidi qasim', 'margate', 'muroran', 'touros', 'srednekolymsk', 'vaitupu', 'nkongsamba', 'palabuhanratu', 'aitape', 'souillac', 'saint-joseph', 'belyy yar', 'asau', 'tessalit', 'payo', 'karratha', 'bocana de paiwas', 'canton', 'sorong', 'quelimane', 'dikson', 'ustye', 'bay roberts', 'isangel', 'bur gabo', 'mogadishu', 'bukama', 'guacimo', 'huarmey', 'college', 'svetlogorsk', 'umm kaddadah', 'dhidhdhoo', 'mehamn', 'leningradskiy', 'campeche', 'steinbach', 'la plata', 'ye', 'bambous virieux', 'ponta delgada', 'yatou', 'coquimbo', 'itarema', 'tual', 'avera', 'miramar', 'desaguadero', 'nort ...

# %%
# Import API key
api_key = keys.api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
city_data = []

for city in cities_name:
    response = requests.get(query_url + city).json()
    pprint(response)
    
    if response["cod"] != "404":
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_temp = response["main"]["temp"]
        city_max_temp = response["main"]["temp_max"]
        city_min_temp = response["main"]["temp_min"]
        city_pressure = response["main"]["pressure"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_weather_description = response["weather"][0]["description"]
        city_date = response["dt"]

        # Append the City information into city_data list
        city_data.append({
            "City": city, 
            "Lat": city_lat, 
            "Lng": city_lng,
            "Temp": city_temp,
            "Max Temp": city_max_temp,
            "Min Temp": city_min_temp,
            "Pressure": city_pressure,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Description": city_weather_description,
            "Date": city_date})
# Out:
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1560555227,
#  'id': 2075265,
#  'main': {'humidity': 80,
#           'pressure': 1016,
#           'temp': 44.94,
#           'temp_max': 46,
#           'temp_min': 44.01},
#  'name': 'Busselton',
#  'rain': {'3h': 0.062},
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'message': 0.0062,
#          'sunrise': 1560554462,
#          'sunset': 1560590218,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 215.301, 'speed': 11.5}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1560555018,
#  'id': 3369157,
#  'main': {'humidity': 100,
#           'pressure': 1022,
#           'temp': 47.95,
#           'temp_max': 52,
#           'temp_min': 41},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'message': 0.0053,
#          'sunrise': 1560577775,
#          'sunset': 1560613437,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 100,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 70, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 57.39, 'lon': 21.56},
#  'dt': 1560555228,
#  'id': 454310,
#  'main': {'humidity': 100,
#           'pressure': 1021,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Ventspils',
#  'sys': {'country': 'LV',
#          'id': 1877,
#          'message': 0.0055,
#          'sunrise': 1560562546,
#          'sunset': 1560627158,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 350,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'speed': 1.12}}
# {'base': 'stations',
#  'clouds': {'all': 21},
#  'cod': 200,
#  'coord': {'lat': 20.93, 'lon': -17.03},
#  'dt': 1560555228,
#  'id': 2377457,
#  'main': {'humidity': 72,
#           'pressure': 1017,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Nouadhibou',
#  'sys': {'country': 'MR',
#          'id': 2444,
#          'message': 0.0068,
#          'sunrise': 1560493597,
#          'sunset': 1560541809,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 39.45, 'lon': 22.34},
#  'dt': 1560555228,
#  'id': 262462,
#  'main': {'humidity': 50,
#           'pressure': 1014,
#           'temp': 74.12,
#           'temp_max': 77,
#           'temp_min': 71.6},
#  'name': 'Saint George',
#  'sys': {'country': 'GR',
#          'id': 6629,
#          'message': 0.0048,
#          'sunrise': 1560567783,
#          'sunset': 1560621547,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': -6.22, 'lon': 155.63},
#  'dt': 1560555228,
#  'id': 2094027,
#  'main': {'grnd_level': 1006.69,
#           'humidity': 71,
#           'pressure': 1009.98,
#           'sea_level': 1009.98,
#           'temp': 82.73,
#           'temp_max': 82.73,
#           'temp_min': 82.73},
#  'name': 'Kieta',
#  'sys': {'country': 'PG',
#          'message': 0.0051,
#          'sunrise': 1560541498,
#          'sunset': 1560583844},
#  'timezone': 39600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130.706, 'speed': 2.39}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34, 'lon': 24.73},
#  'dt': 1560555229,
#  'id': 986717,
#  'main': {'grnd_level': 989.77,
#           'humidity': 30,
#           'pressure': 1022.12,
#           'sea_level': 1022.12,
#           'temp': 49.43,
#           'temp_max': 49.43,
#           'temp_min': 49.43},
#  'name': 'Kruisfontein',
#  'sys': {'country': 'ZA',
#          'message': 0.0054,
#          'sunrise': 1560576270,
#          'sunset': 1560611912},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 4.184, 'speed': 6.71}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 46.68, 'lon': 113.28},
#  'dt': 1560555229,
#  'id': 2032614,
#  'main': {'grnd_level': 885.77,
#           'humidity': 41,
#           'pressure': 1009.2,
#           'sea_level': 1009.2,
#           'temp': 62.57,
#           'temp_max': 62.57,
#           'temp_min': 62.57},
#  'name': 'Baruun-Urt',
#  'sys': {'country': 'MN',
#          'message': 0.0064,
#          'sunrise': 1560544363,
#          'sunset': 1560601310},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 132.649, 'speed': 15.55}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1560554974,
#  'id': 4035715,
#  'main': {'humidity': 83,
#           'pressure': 1014,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'message': 0.0061,
#          'sunrise': 1560532438,
#          'sunset': 1560571498,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1560555229,
#  'id': 3833367,
#  'main': {'humidity': 80,
#           'pressure': 1021,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0051,
#          'sunrise': 1560516957,
#          'sunset': 1560543067,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 18.34}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -38.31, 'lon': -60.23},
#  'dt': 1560555229,
#  'id': 3833859,
#  'main': {'grnd_level': 1008.06,
#           'humidity': 83,
#           'pressure': 1019.32,
#           'sea_level': 1019.32,
#           'temp': 46.01,
#           'temp_max': 46.01,
#           'temp_min': 46.01},
#  'name': 'Barrow',
#  'sys': {'country': 'AR',
#          'message': 0.0051,
#          'sunrise': 1560510944,
#          'sunset': 1560545201},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 246.404, 'speed': 6.73}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1560555230,
#  'id': 4030556,
#  'main': {'grnd_level': 1019.77,
#           'humidity': 67,
#           'pressure': 1019.78,
#           'sea_level': 1019.78,
#           'temp': 67.97,
#           'temp_max': 67.97,
#           'temp_min': 67.97},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0052,
#          'sunrise': 1560526712,
#          'sunset': 1560565313},
#  'timezone': -32400,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 143.835, 'speed': 21.9}}
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': 31.62, 'lon': 113.82},
#  'dt': 1560555230,
#  'id': 1809879,
#  'main': {'grnd_level': 994,
#           'humidity': 58,
#           'pressure': 1006.34,
#           'sea_level': 1006.34,
#           'temp': 77.15,
#           'temp_max': 77.15,
#           'temp_min': 77.15},
#  'name': 'Guangshui',
#  'sys': {'country': 'CN',
#          'message': 0.0057,
#          'sunrise': 1560547155,
#          'sunset': 1560598259},
#  'timezone': 28800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 147.816, 'speed': 6.26}}
# {'base': 'stations',
#  'clouds': {'all': 27},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1560555230,
#  'id': 6201424,
#  'main': {'humidity': 98,
#           'pressure': 1010,
#           'temp': 46.99,
#           'temp_max': 46.99,
#           'temp_min': 46.99},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0062,
#          'sunrise': 1560543941,
#          'sunset': 1560575050,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 336.414, 'speed': 3.69}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 8.48, 'lon': 76.92},
#  'dt': 1560555114,
#  'id': 1254163,
#  'main': {'humidity': 83,
#           'pressure': 1007,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Thiruvananthapuram',
#  'sys': {'country': 'IN',
#          'id': 9226,
#          'message': 0.0106,
#          'sunrise': 1560558861,
#          'sunset': 1560604267,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 3000,
#  'weather': [{'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 320, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': -33.52, 'lon': -56.9},
#  'dt': 1560555231,
#  'id': 3439749,
#  'main': {'grnd_level': 1003.42,
#           'humidity': 90,
#           'pressure': 1016.38,
#           'sea_level': 1016.38,
#           'temp': 62.21,
#           'temp_max': 62.21,
#           'temp_min': 62.21},
#  'name': 'Trinidad',
#  'sys': {'country': 'UY',
#          'message': 0.0047,
#          'sunrise': 1560509372,
#          'sunset': 1560545174},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 156.427, 'speed': 8.77}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 72.79, 'lon': -56.15},
#  'dt': 1560555232,
#  'id': 3418910,
#  'main': {'grnd_level': 1024.49,
#           'humidity': 97,
#           'pressure': 1024.08,
#           'sea_level': 1024.08,
#           'temp': 36.65,
#           'temp_max': 36.65,
#           'temp_min': 36.65},
#  'name': 'Upernavik',
#  'rain': {'3h': 2.063},
#  'sys': {'country': 'GL', 'message': 0.0044, 'sunrise': 0, 'sunset': 0},
#  'timezone': -7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 205.705, 'speed': 10.27}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.43, 'lon': 7.07},
#  'dt': 1560555232,
#  'id': 2337542,
#  'main': {'humidity': 94,
#           'pressure': 1014,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Naze',
#  'sys': {'country': 'NG',
#          'id': 1170,
#          'message': 0.0042,
#          'sunrise': 1560575949,
#          'sunset': 1560620712,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 8000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 172.274, 'speed': 1.48}}
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': -41.87, 'lon': -73.83},
#  'dt': 1560555232,
#  'id': 3899695,
#  'main': {'humidity': 93,
#           'pressure': 1025,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ancud',
#  'sys': {'country': 'CL',
#          'id': 8512,
#          'message': 0.005,
#          'sunrise': 1560514861,
#          'sunset': 1560547813,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 3300,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': -26.65, 'lon': 15.16},
#  'dt': 1560555232,
#  'id': 3355672,
#  'main': {'humidity': 19,
#           'pressure': 1020,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Luderitz',
#  'sys': {'country': 'NA',
#          'id': 2260,
#          'message': 0.0055,
#          'sunrise': 1560577535,
#          'sunset': 1560615242,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 34},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1560555233,
#  'id': 3366880,
#  'main': {'humidity': 94,
#           'pressure': 1018,
#           'temp': 47.77,
#           'temp_max': 50,
#           'temp_min': 45},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'message': 0.0044,
#          'sunrise': 1560577653,
#          'sunset': 1560613165,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60.195, 'speed': 3.18}}
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': -8.16, 'lon': -70.77},
#  'dt': 1560555233,
#  'id': 3661980,
#  'main': {'grnd_level': 983.44,
#           'humidity': 83,
#           'pressure': 1012.04,
#           'sea_level': 1012.04,
#           'temp': 74.99,
#           'temp_max': 74.99,
#           'temp_min': 74.99},
#  'name': 'Tarauaca',
#  'sys': {'country': 'BR',
#          'message': 0.0056,
#          'sunrise': 1560509631,
#          'sunset': 1560551574},
#  'timezone': -18000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30.062, 'speed': 2.86}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1560555233,
#  'id': 2163355,
#  'main': {'humidity': 70,
#           'pressure': 1017,
#           'temp': 45.91,
#           'temp_max': 46.99,
#           'temp_min': 44.6},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.0053,
#          'sunrise': 1560548393,
#          'sunset': 1560580933,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 52.51, 'lon': 99.83},
#  'dt': 1560555233,
#  'id': 1496073,
#  'main': {'grnd_level': 794.49,
#           'humidity': 88,
#           'pressure': 1002.67,
#           'sea_level': 1002.67,
#           'temp': 47.81,
#           'temp_max': 47.81,
#           'temp_min': 47.81},
#  'name': 'Orlik',
#  'rain': {'3h': 1.875},
#  'sys': {'country': 'RU',
#          'message': 0.0045,
#          'sunrise': 1560545839,
#          'sunset': 1560606291},
#  'timezone': 28800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 330.251, 'speed': 3.76}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1560555078,
#  'id': 5855927,
#  'main': {'humidity': 61,
#           'pressure': 1017,
#           'temp': 77.43,
#           'temp_max': 80.6,
#           'temp_min': 73.99},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'message': 0.0061,
#          'sunrise': 1560526879,
#          'sunset': 1560574800,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 10.29}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 16.99, 'lon': -99.26},
#  'dt': 1560555234,
#  'id': 3532499,
#  'main': {'humidity': 62,
#           'pressure': 1011,
#           'temp': 89.6,
#           'temp_max': 89.6,
#           'temp_min': 89.6},
#  'name': 'Tecoanapa',
#  'sys': {'country': 'MX',
#          'id': 7103,
#          'message': 0.0044,
#          'sunrise': 1560513801,
#          'sunset': 1560561082,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 9656,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1560555234,
#  'id': 3424607,
#  'main': {'humidity': 65,
#           'pressure': 1023,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'message': 0.0066,
#          'sunrise': 1560481757,
#          'sunset': 1560563544,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.21, 'lon': 138.6},
#  'dt': 1560555018,
#  'id': 2069194,
#  'main': {'grnd_level': 985.49,
#           'humidity': 74,
#           'pressure': 1022.81,
#           'sea_level': 1022.81,
#           'temp': 52.67,
#           'temp_max': 52.67,
#           'temp_min': 52.67},
#  'name': 'Jamestown',
#  'sys': {'country': 'AU',
#          'message': 0.0046,
#          'sunrise': 1560548815,
#          'sunset': 1560584702},
#  'timezone': 34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 3.732, 'speed': 6.15}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 34.64, 'lon': -120.46},
#  'dt': 1560555235,
#  'id': 5367788,
#  'main': {'humidity': 82,
#           'pressure': 1015,
#           'temp': 64.99,
#           'temp_max': 70,
#           'temp_min': 60.8},
#  'name': 'Lompoc',
#  'sys': {'country': 'US',
#          'id': 6155,
#          'message': 0.0068,
#          'sunrise': 1560516505,
#          'sunset': 1560568554,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1560555200,
#  'id': 3985710,
#  'main': {'humidity': 57,
#           'pressure': 1013,
#           'temp': 80.91,
#           'temp_max': 95,
#           'temp_min': 68},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 7151,
#          'message': 0.006,
#          'sunrise': 1560515648,
#          'sunset': 1560564347,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'speed': 17.22}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 62.72, 'lon': 129.66},
#  'dt': 1560555235,
#  'id': 2019488,
#  'main': {'humidity': 67,
#           'pressure': 1013,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Namtsy',
#  'sys': {'country': 'RU',
#          'id': 8854,
#          'message': 0.0052,
#          'sunrise': 1560532829,
#          'sunset': 1560604980,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 120, 'speed': 4.47}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -13.71, 'lon': -76.2},
#  'dt': 1560555235,
#  'id': 3932145,
#  'main': {'humidity': 30,
#           'pressure': 1015,
#           'temp': 67.39,
#           'temp_max': 71.6,
#           'temp_min': 64},
#  'name': 'Pisco',
#  'sys': {'country': 'PE',
#          'id': 8691,
#          'message': 0.0071,
#          'sunrise': 1560511526,
#          'sunset': 1560552286,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 220, 'speed': 16.11}}
# {'base': 'stations',
#  'clouds': {'all': 25},
#  'cod': 200,
#  'coord': {'lat': -23.78, 'lon': -45.36},
#  'dt': 1560555235,
#  'id': 3461425,
#  'main': {'grnd_level': 1020.48,
#           'humidity': 74,
#           'pressure': 1022.24,
#           'sea_level': 1022.24,
#           'temp': 74.99,
#           'temp_max': 74.99,
#           'temp_min': 74.99},
#  'name': 'Ilhabela',
#  'sys': {'country': 'BR',
#          'message': 0.0056,
#          'sunrise': 1560505282,
#          'sunset': 1560543725},
#  'timezone': -10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 25.73, 'speed': 8.66}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1560555236,
#  'id': 2175403,
#  'main': {'grnd_level': 999.04,
#           'humidity': 66,
#           'pressure': 1019.49,
#           'sea_level': 1019.49,
#           'temp': 69.77,
#           'temp_max': 69.77,
#           'temp_min': 69.77},
#  'name': 'Bluff',
#  'sys': {'country': 'AU',
#          'message': 0.0049,
#          'sunrise': 1560545003,
#          'sunset': 1560583489},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 67.865, 'speed': 1.57}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 6.8, 'lon': -58.16},
#  'dt': 1560555237,
#  'id': 3378644,
#  'main': {'humidity': 74,
#           'pressure': 1012,
#           'temp': 80.47,
#           'temp_max': 82.4,
#           'temp_min': 78.8},
#  'name': 'Georgetown',
#  'sys': {'country': 'GY',
#          'id': 8776,
#          'message': 0.0063,
#          'sunrise': 1560505052,
#          'sunset': 1560550100,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 86},
#  'cod': 200,
#  'coord': {'lat': 35.07, 'lon': 116.31},
#  'dt': 1560555237,
#  'id': 1787335,
#  'main': {'humidity': 26,
#           'pressure': 994,
#           'temp': 89.01,
#           'temp_max': 89.01,
#           'temp_min': 89.01},
#  'name': 'Jinxiang',
#  'sys': {'country': 'CN',
#          'id': 62766,
#          'message': 0.0064,
#          'sunrise': 1560546010,
#          'sunset': 1560598208,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240.245, 'speed': 12.97}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1560555237,
#  'id': 6165406,
#  'main': {'humidity': 31,
#           'pressure': 1012,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'message': 0.0046,
#          'sunrise': 1560505608,
#          'sunset': 1560568602,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1560555238,
#  'id': 3874787,
#  'main': {'humidity': 92,
#           'pressure': 1024,
#           'temp': 30.09,
#           'temp_max': 30.2,
#           'temp_min': 30},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.0052,
#          'sunrise': 1560517002,
#          'sunset': 1560544271,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 52.69, 'lon': 47.13},
#  'dt': 1560555238,
#  'id': 512152,
#  'main': {'grnd_level': 979.12,
#           'humidity': 97,
#           'pressure': 1013.67,
#           'sea_level': 1013.67,
#           'temp': 50.69,
#           'temp_max': 50.69,
#           'temp_min': 50.69},
#  'name': 'Pavlovka',
#  'rain': {'3h': 0.187},
#  'sys': {'country': 'RU',
#          'message': 0.0053,
#          'sunrise': 1560558421,
#          'sunset': 1560619008},
#  'timezone': 14400,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 122.94, 'speed': 2.37}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 22.08, 'lon': -159.32},
#  'dt': 1560555238,
#  'id': 5848280,
#  'main': {'humidity': 66,
#           'pressure': 1018,
#           'temp': 82.08,
#           'temp_max': 86,
#           'temp_min': 79},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 7873,
#          'message': 0.0056,
#          'sunrise': 1560527608,
#          'sunset': 1560576107,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 13.87}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.93, 'lon': 134.5},
#  'dt': 1560555239,
#  'id': 1865309,
#  'main': {'humidity': 88,
#           'pressure': 994,
#           'temp': 66.94,
#           'temp_max': 69.01,
#           'temp_min': 64.4},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 8027,
#          'message': 0.0062,
#          'sunrise': 1560541831,
#          'sunset': 1560593655,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 10, 'speed': 8.05}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.77, 'lon': 32.06},
#  'dt': 1560555239,
#  'id': 962367,
#  'main': {'grnd_level': 1027.92,
#           'humidity': 76,
#           'pressure': 1028.26,
#           'sea_level': 1028.26,
#           'temp': 62.57,
#           'temp_max': 62.57,
#           'temp_min': 62.57},
#  'name': 'Richards Bay',
#  'sys': {'country': 'ZA',
#          'message': 0.005,
#          'sunrise': 1560573759,
#          'sunset': 1560610904},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0.813, 'speed': 12.46}}
# {'base': 'stations',
#  'clouds': {'all': 50},
#  'cod': 200,
#  'coord': {'lat': 66.56, 'lon': 67.8},
#  'dt': 1560555239,
#  'id': 1512019,
#  'main': {'grnd_level': 993.21,
#           'humidity': 71,
#           'pressure': 999.75,
#           'sea_level': 999.75,
#           'temp': 37.19,
#           'temp_max': 37.19,
#           'temp_min': 37.19},
#  'name': 'Aksarka',
#  'sys': {'country': 'RU', 'message': 0.0052, 'sunrise': 0, 'sunset': 0},
#  'timezone': 18000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 277.139, 'speed': 12.3}}
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1560555240,
#  'id': 2022572,
#  'main': {'grnd_level': 992.99,
#           'humidity': 38,
#           'pressure': 995.53,
#           'sea_level': 995.53,
#           'temp': 45.47,
#           'temp_max': 45.47,
#           'temp_min': 45.47},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'message': 0.0048, 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 234.65, 'speed': 15.35}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -19.06, 'lon': -169.92},
#  'dt': 1560555017,
#  'id': 4036284,
#  'main': {'humidity': 78,
#           'pressure': 1014,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Alofi',
#  'sys': {'country': 'NU',
#          'id': 7306,
#          'message': 0.0052,
#          'sunrise': 1560534621,
#          'sunset': 1560574183,
#          'type': 1},
#  'timezone': -39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 51},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1560555240,
#  'id': 3372707,
#  'main': {'grnd_level': 1017.42,
#           'humidity': 79,
#           'pressure': 1017.42,
#           'sea_level': 1017.42,
#           'temp': 67.07,
#           'temp_max': 67.07,
#           'temp_min': 67.07},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'message': 0.0052,
#          'sunrise': 1560493808,
#          'sunset': 1560547201},
#  'timezone': 0,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 126.063, 'speed': 19.77}}
# {'base': 'stations',
#  'clouds': {'all': 47},
#  'cod': 200,
#  'coord': {'lat': 2.77, 'lon': 27.62},
#  'dt': 1560555240,
#  'id': 215771,
#  'main': {'grnd_level': 932.09,
#           'humidity': 99,
#           'pressure': 1014.07,
#           'sea_level': 1014.07,
#           'temp': 66.71,
#           'temp_max': 66.71,
#           'temp_min': 66.71},
#  'name': 'Isiro',
#  'rain': {'3h': 3.624},
#  'sys': {'country': 'CD',
#          'message': 0.0047,
#          'sunrise': 1560571294,
#          'sunset': 1560615501},
#  'timezone': 7200,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 276.625, 'speed': 1.25}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.63},
#  'dt': 1560555241,
#  'id': 2729907,
#  'main': {'humidity': 61,
#           'pressure': 1013,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'NO',
#          'id': 1663,
#          'message': 0.0054,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1560555241,
#  'id': 2110227,
#  'main': {'grnd_level': 1007.37,
#           'humidity': 86,
#           'pressure': 1007.44,
#           'sea_level': 1007.44,
#           'temp': 80.75,
#           'temp_max': 80.75,
#           'temp_min': 80.75},
#  'name': 'Butaritari',
#  'rain': {'3h': 8.062},
#  'sys': {'country': 'KI',
#          'message': 0.0046,
#          'sunrise': 1560536417,
#          'sunset': 1560580687},
#  'timezone': 43200,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 153.519, 'speed': 12.28}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1560555241,
#  'id': 964432,
#  'main': {'humidity': 45,
#           'pressure': 1023,
#           'temp': 55.99,
#           'temp_max': 55.99,
#           'temp_min': 55.99},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'message': 0.0055,
#          'sunrise': 1560575690,
#          'sunset': 1560611456,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 12.958, 'speed': 3.98}}
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1560555241,
#  'id': 4020109,
#  'main': {'grnd_level': 1010.49,
#           'humidity': 74,
#           'pressure': 1010.33,
#           'sea_level': 1010.33,
#           'temp': 80.21,
#           'temp_max': 80.21,
#           'temp_min': 80.21},
#  'name': 'Atuona',
#  'sys': {'country': 'PF',
#          'message': 0.0051,
#          'sunrise': 1560526189,
#          'sunset': 1560567786},
#  'timezone': -34200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102.408, 'speed': 14.23}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 50},
#  'cod': 200,
#  'coord': {'lat': 70.86, 'lon': 29.09},
#  'dt': 1560555242,
#  'id': 780687,
#  'main': {'grnd_level': 1017.61,
#           'humidity': 84,
#           'pressure': 1018.08,
#           'sea_level': 1018.08,
#           'temp': 41.15,
#           'temp_max': 41.15,
#           'temp_min': 41.15},
#  'name': 'Berlevag',
#  'sys': {'country': 'NO', 'message': 0.0053, 'sunrise': 0, 'sunset': 0},
#  'timezone': 7200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 298.693, 'speed': 18.23}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 15.11, 'lon': -16.62},
#  'dt': 1560555242,
#  'id': 2248409,
#  'main': {'humidity': 88,
#           'pressure': 1016,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Mekhe',
#  'sys': {'country': 'SN',
#          'id': 2410,
#          'message': 0.0046,
#          'sunrise': 1560494180,
#          'sunset': 1560541030,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.49, 'lon': 105.92},
#  'dt': 1560555242,
#  'id': 2031964,
#  'main': {'grnd_level': 888.69,
#           'humidity': 54,
#           'pressure': 1000.46,
#           'sea_level': 1000.46,
#           'temp': 64.01,
#           'temp_max': 64.01,
#           'temp_min': 64.01},
#  'name': 'Darhan',
#  'sys': {'country': 'MN',
#          'message': 0.0044,
#          'sunrise': 1560545355,
#          'sunset': 1560603851},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 185.991, 'speed': 8.81}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1560555242,
#  'id': 6185377,
#  'main': {'humidity': 37,
#           'pressure': 1009,
#           'temp': 71.26,
#           'temp_max': 71.6,
#           'temp_min': 71.01},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'message': 0.0069,
#          'sunrise': 1560505281,
#          'sunset': 1560576860,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'gust': 9.3, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 70, 'lon': 135.55},
#  'dt': 1560555243,
#  'id': 2013921,
#  'main': {'grnd_level': 991.5,
#           'humidity': 38,
#           'pressure': 1012.5,
#           'sea_level': 1012.5,
#           'temp': 62.03,
#           'temp_max': 62.03,
#           'temp_min': 62.03},
#  'name': 'Ust-Kuyga',
#  'sys': {'country': 'RU', 'message': 0.0057, 'sunrise': 0, 'sunset': 0},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 110.336, 'speed': 4.03}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 18.42, 'lon': -64.62},
#  'dt': 1560555243,
#  'id': 3577430,
#  'main': {'humidity': 74,
#           'pressure': 1017,
#           'temp': 80.83,
#           'temp_max': 82.4,
#           'temp_min': 79},
#  'name': 'Road Town',
#  'sys': {'country': 'VG',
#          'id': 8799,
#          'message': 0.0108,
#          'sunrise': 1560505320,
#          'sunset': 1560552933,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 6.93}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -2.54, 'lon': 115.51},
#  'dt': 1560555244,
#  'id': 1641899,
#  'main': {'grnd_level': 998.13,
#           'humidity': 92,
#           'pressure': 1011.02,
#           'sea_level': 1011.02,
#           'temp': 76.07,
#           'temp_max': 76.07,
#           'temp_min': 76.07},
#  'name': 'Labuhan',
#  'sys': {'country': 'ID',
#          'message': 0.0046,
#          'sunrise': 1560550747,
#          'sunset': 1560593856},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 36.144, 'speed': 0.56}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 61.87, 'lon': 28.88},
#  'dt': 1560555244,
#  'id': 637293,
#  'main': {'humidity': 93,
#           'pressure': 1015,
#           'temp': 53.83,
#           'temp_max': 54,
#           'temp_min': 53.6},
#  'name': 'Savonlinna',
#  'sys': {'country': 'FI',
#          'id': 1357,
#          'message': 0.005,
#          'sunrise': 1560557813,
#          'sunset': 1560628378,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 4800,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 89.339, 'speed': 4.65}}
# {'base': 'stations',
#  'clouds': {'all': 4},
#  'cod': 200,
#  'coord': {'lat': -37.88, 'lon': 147.99},
#  'dt': 1560555244,
#  'id': 2160735,
#  'main': {'grnd_level': 1019.28,
#           'humidity': 71,
#           'pressure': 1021.45,
#           'sea_level': 1021.45,
#           'temp': 53.57,
#           'temp_max': 53.57,
#           'temp_min': 53.57},
#  'name': 'Lakes Entrance',
#  'sys': {'country': 'AU',
#          'message': 0.0054,
#          'sunrise': 1560547307,
#          'sunset': 1560581703},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 309.834, 'speed': 5.21}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 70.47, 'lon': -68.59},
#  'dt': 1560555244,
#  'id': 5924351,
#  'main': {'humidity': 100,
#           'pressure': 1020,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA',
#          'id': 776,
#          'message': 0.0059,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 4023,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 60, 'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1560555061,
#  'id': 5106834,
#  'main': {'humidity': 52,
#           'pressure': 1013,
#           'temp': 61.59,
#           'temp_max': 68,
#           'temp_min': 55},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 3273,
#          'message': 0.0096,
#          'sunrise': 1560503797,
#          'sunset': 1560558839,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 300, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 71, 'lon': 24.66},
#  'dt': 1560555245,
#  'id': 779622,
#  'main': {'humidity': 86,
#           'pressure': 1020,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Havoysund',
#  'sys': {'country': 'NO',
#          'id': 1632,
#          'message': 0.0054,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 14.99}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 37.14, 'lon': -8.45},
#  'dt': 1560555236,
#  'id': 2267254,
#  'main': {'humidity': 59,
#           'pressure': 1020,
#           'temp': 60.64,
#           'temp_max': 62.6,
#           'temp_min': 59},
#  'name': 'Lagoa',
#  'sys': {'country': 'PT',
#          'id': 6892,
#          'message': 0.0076,
#          'sunrise': 1560575598,
#          'sunset': 1560628513,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1560555246,
#  'id': 2208248,
#  'main': {'humidity': 80,
#           'pressure': 1008,
#           'temp': 51.01,
#           'temp_max': 51.01,
#           'temp_min': 51.01},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'id': 2000217,
#          'message': 0.0074,
#          'sunrise': 1560543724,
#          'sunset': 1560574791,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'gust': 2.24, 'speed': 3}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -8.15, 'lon': 159.59},
#  'dt': 1560555246,
#  'id': 2109528,
#  'main': {'grnd_level': 1000.25,
#           'humidity': 77,
#           'pressure': 1009.37,
#           'sea_level': 1009.37,
#           'temp': 82.91,
#           'temp_max': 82.91,
#           'temp_min': 82.91},
#  'name': 'Buala',
#  'rain': {'3h': 1.438},
#  'sys': {'country': 'SB',
#          'message': 0.0067,
#          'sunrise': 1560540749,
#          'sunset': 1560582692},
#  'timezone': 39600,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 140.824, 'speed': 15.55}}
# {'base': 'stations',
#  'clouds': {'all': 35},
#  'cod': 200,
#  'coord': {'lat': 4.27, 'lon': -54.38},
#  'dt': 1560555246,
#  'id': 3381538,
#  'main': {'grnd_level': 998.8,
#           'humidity': 98,
#           'pressure': 1012.97,
#           'sea_level': 1012.97,
#           'temp': 74.27,
#           'temp_max': 74.27,
#           'temp_min': 74.27},
#  'name': 'Grand-Santi',
#  'rain': {'3h': 0.5},
#  'sys': {'country': 'GF',
#          'message': 0.0065,
#          'sunrise': 1560504409,
#          'sunset': 1560548927},
#  'timezone': -10800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 59.142, 'speed': 1.45}}
# {'base': 'stations',
#  'clouds': {'all': 7},
#  'cod': 200,
#  'coord': {'lat': -34.58, 'lon': 150.85},
#  'dt': 1560555246,
#  'id': 6255012,
#  'main': {'humidity': 71,
#           'pressure': 1020,
#           'temp': 55.36,
#           'temp_max': 59,
#           'temp_min': 51.8},
#  'name': 'Flinders',
#  'sys': {'country': 'AU',
#          'id': 9594,
#          'message': 0.0055,
#          'sunrise': 1560546084,
#          'sunset': 1560581553,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 12.75}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1560555247,
#  'id': 1733782,
#  'main': {'humidity': 88,
#           'pressure': 1010,
#           'temp': 79.92,
#           'temp_max': 80.6,
#           'temp_min': 78.8},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 9372,
#          'message': 0.0057,
#          'sunrise': 1560550001,
#          'sunset': 1560594731,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1.12}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 66.15, 'lon': -65.72},
#  'dt': 1560555248,
#  'id': 6096551,
#  'main': {'humidity': 70,
#           'pressure': 1022,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Pangnirtung',
#  'sys': {'country': 'CA',
#          'id': 968,
#          'message': 0.0062,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 54},
#  'cod': 200,
#  'coord': {'lat': -46.13, 'lon': 167.69},
#  'dt': 1560555249,
#  'id': 2180815,
#  'main': {'humidity': 98,
#           'pressure': 1010,
#           'temp': 46.99,
#           'temp_max': 46.99,
#           'temp_min': 46.99},
#  'name': 'Tuatapere',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'message': 0.0049,
#          'sunrise': 1560544208,
#          'sunset': 1560575344,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320.4, 'speed': 8.28}}
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -1.5, 'lon': 33.81},
#  'dt': 1560555249,
#  'id': 152451,
#  'main': {'grnd_level': 887.79,
#           'humidity': 65,
#           'pressure': 1013.03,
#           'sea_level': 1013.03,
#           'temp': 74.45,
#           'temp_max': 74.45,
#           'temp_min': 74.45},
#  'name': 'Musoma',
#  'rain': {'3h': 0.813},
#  'sys': {'country': 'TZ',
#          'message': 0.0043,
#          'sunrise': 1560570250,
# ...
#  'dt': 1560555364,
#  'id': 1786538,
#  'main': {'grnd_level': 978.45,
#           'humidity': 80,
#           'pressure': 1007.34,
#           'sea_level': 1007.34,
#           'temp': 73.19,
#           'temp_max': 73.19,
#           'temp_min': 73.19},
#  'name': 'Yining',
#  'sys': {'country': 'CN',
#          'message': 0.0056,
#          'sunrise': 1560547356,
#          'sunset': 1560597703},
#  'timezone': 28800,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 101.953, 'speed': 0.83}}
# {'base': 'stations',
#  'clouds': {'all': 16},
#  'cod': 200,
#  'coord': {'lat': 7.98, 'lon': 49.82},
#  'dt': 1560555364,
#  'id': 60019,
#  'main': {'grnd_level': 975.01,
#           'humidity': 61,
#           'pressure': 1008.66,
#           'sea_level': 1008.66,
#           'temp': 80.93,
#           'temp_max': 80.93,
#           'temp_min': 80.93},
#  'name': 'Eyl',
#  'sys': {'country': 'SO',
#          'message': 0.0062,
#          'sunrise': 1560565419,
#          'sunset': 1560610719},
#  'timezone': 10800,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 221.425, 'speed': 31.59}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 16.86, 'lon': -99.88},
#  'dt': 1560555364,
#  'id': 3533462,
#  'main': {'humidity': 62,
#           'pressure': 1011,
#           'temp': 89.6,
#           'temp_max': 89.6,
#           'temp_min': 89.6},
#  'name': 'Acapulco',
#  'sys': {'country': 'MX',
#          'id': 7103,
#          'message': 0.0047,
#          'sunrise': 1560513964,
#          'sunset': 1560561215,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 9656,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 10.29}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.81, 'lon': -74},
#  'dt': 1560555365,
#  'id': 5097801,
#  'main': {'humidity': 31,
#           'pressure': 1015,
#           'temp': 73.13,
#           'temp_max': 75.2,
#           'temp_min': 70},
#  'name': 'Fairview',
#  'sys': {'country': 'US',
#          'id': 4686,
#          'message': 0.016,
#          'sunrise': 1560504239,
#          'sunset': 1560558517,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310, 'gust': 11.3, 'speed': 13.87}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.77, 'lon': -9.06},
#  'dt': 1560555366,
#  'id': 3115824,
#  'main': {'humidity': 100,
#           'pressure': 1019,
#           'temp': 55.78,
#           'temp_max': 61,
#           'temp_min': 51.8},
#  'name': 'Muros',
#  'sys': {'country': 'ES',
#          'id': 6434,
#          'message': 0.0052,
#          'sunrise': 1560574644,
#          'sunset': 1560629760,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 3.36}}
# {'base': 'stations',
#  'clouds': {'all': 69},
#  'cod': 200,
#  'coord': {'lat': 21.98, 'lon': -103.59},
#  'dt': 1560555366,
#  'id': 3980172,
#  'main': {'grnd_level': 827.81,
#           'humidity': 32,
#           'pressure': 1009.96,
#           'sea_level': 1009.96,
#           'temp': 83.09,
#           'temp_max': 83.09,
#           'temp_min': 83.09},
#  'name': 'Villa Guerrero',
#  'sys': {'country': 'MX',
#          'message': 0.0063,
#          'sunrise': 1560514244,
#          'sunset': 1560562717},
#  'timezone': -18000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 284.553, 'speed': 7.52}}
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 3.87, 'lon': -67.92},
#  'dt': 1560555366,
#  'id': 3671450,
#  'main': {'grnd_level': 999.1,
#           'humidity': 92,
#           'pressure': 1011.42,
#           'sea_level': 1011.42,
#           'temp': 75.17,
#           'temp_max': 75.17,
#           'temp_min': 75.17},
#  'name': 'Inirida',
#  'rain': {'3h': 0.313},
#  'sys': {'country': 'CO',
#          'message': 0.0055,
#          'sunrise': 1560507701,
#          'sunset': 1560552136},
#  'timezone': -18000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 174.026, 'speed': 0.2}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 72},
#  'cod': 200,
#  'coord': {'lat': 10.74, 'lon': 14.61},
#  'dt': 1560555367,
#  'id': 2233805,
#  'main': {'grnd_level': 973.79,
#           'humidity': 56,
#           'pressure': 1011.63,
#           'sea_level': 1011.63,
#           'temp': 84.53,
#           'temp_max': 84.53,
#           'temp_min': 84.53},
#  'name': 'Bogo',
#  'sys': {'country': 'CM',
#          'message': 0.007,
#          'sunrise': 1560573575,
#          'sunset': 1560619466},
#  'timezone': 3600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 191.131, 'speed': 9.98}}
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': 22.61, 'lon': 84.51},
#  'dt': 1560555367,
#  'id': 1256246,
#  'main': {'grnd_level': 961.1,
#           'humidity': 61,
#           'pressure': 1000.83,
#           'sea_level': 1000.83,
#           'temp': 84.53,
#           'temp_max': 84.53,
#           'temp_min': 84.53},
#  'name': 'Simdega',
#  'rain': {'3h': 1},
#  'sys': {'country': 'IN',
#          'message': 0.0067,
#          'sunrise': 1560555425,
#          'sunset': 1560604060},
#  'timezone': 19800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 246.188, 'speed': 5.19}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -45.87, 'lon': 170.5},
#  'dt': 1560555205,
#  'id': 2191562,
#  'main': {'humidity': 69,
#           'pressure': 1008,
#           'temp': 55.99,
#           'temp_max': 55.99,
#           'temp_min': 55.99},
#  'name': 'Dunedin',
#  'sys': {'country': 'NZ',
#          'id': 75281,
#          'message': 0.0054,
#          'sunrise': 1560543474,
#          'sunset': 1560574730,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 216, 'gust': 3.58, 'speed': 5.01}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 35.61, 'lon': -88.82},
#  'dt': 1560555368,
#  'id': 4632595,
#  'main': {'humidity': 44,
#           'pressure': 1017,
#           'temp': 79.39,
#           'temp_max': 81,
#           'temp_min': 78.01},
#  'name': 'Jackson',
#  'sys': {'country': 'US',
#          'id': 4914,
#          'message': 0.0081,
#          'sunrise': 1560508750,
#          'sunset': 1560561120,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 51},
#  'cod': 200,
#  'coord': {'lat': 52.47, 'lon': 1.45},
#  'dt': 1560555368,
#  'id': 2656067,
#  'main': {'humidity': 82,
#           'pressure': 1013,
#           'temp': 54.03,
#           'temp_max': 57.99,
#           'temp_min': 50},
#  'name': 'Broome',
#  'sys': {'country': 'GB',
#          'id': 1467,
#          'message': 0.0062,
#          'sunrise': 1560569462,
#          'sunset': 1560629897,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 180, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 28.39, 'lon': -105.62},
#  'dt': 1560555368,
#  'id': 3996234,
#  'main': {'humidity': 17,
#           'pressure': 1017,
#           'temp': 87.03,
#           'temp_max': 91.4,
#           'temp_min': 82.99},
#  'name': 'Lazaro Cardenas',
#  'sys': {'country': 'MX',
#          'id': 7111,
#          'message': 0.0046,
#          'sunrise': 1560513889,
#          'sunset': 1560564046,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 11.41}}
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': -4.33, 'lon': 20.59},
#  'dt': 1560555368,
#  'id': 215976,
#  'main': {'grnd_level': 957.12,
#           'humidity': 57,
#           'pressure': 1012.4,
#           'sea_level': 1012.4,
#           'temp': 71.03,
#           'temp_max': 71.03,
#           'temp_min': 71.03},
#  'name': 'Ilebo',
#  'sys': {'country': 'CD',
#          'message': 0.0049,
#          'sunrise': 1560573716,
#          'sunset': 1560616454},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 113.141, 'speed': 1.45}}
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -20.65, 'lon': 166.53},
#  'dt': 1560555368,
#  'id': 2141305,
#  'main': {'grnd_level': 1017.41,
#           'humidity': 67,
#           'pressure': 1017.43,
#           'sea_level': 1017.43,
#           'temp': 71.03,
#           'temp_max': 71.03,
#           'temp_min': 71.03},
#  'name': 'Fayaoue',
#  'sys': {'country': 'NC',
#          'message': 0.0047,
#          'sunrise': 1560540459,
#          'sunset': 1560579650},
#  'timezone': 39600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 116.177, 'speed': 14.34}}
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 20.61, 'lon': 72.93},
#  'dt': 1560555369,
#  'id': 1253468,
#  'main': {'grnd_level': 1001.74,
#           'humidity': 80,
#           'pressure': 1001.79,
#           'sea_level': 1001.79,
#           'temp': 84.71,
#           'temp_max': 84.71,
#           'temp_min': 84.71},
#  'name': 'Valsad',
#  'rain': {'3h': 0.374},
#  'sys': {'country': 'IN',
#          'message': 0.0046,
#          'sunrise': 1560558451,
#          'sunset': 1560606593},
#  'timezone': 19800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 175.519, 'speed': 27.45}}
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': 47.17, 'lon': -55.16},
#  'dt': 1560555369,
#  'id': 6067472,
#  'main': {'grnd_level': 1015.2,
#           'humidity': 85,
#           'pressure': 1021.27,
#           'sea_level': 1021.27,
#           'temp': 48.71,
#           'temp_max': 48.71,
#           'temp_min': 48.71},
#  'name': 'Marystown',
#  'sys': {'country': 'CA',
#          'message': 0.0052,
#          'sunrise': 1560498264,
#          'sunset': 1560555447},
#  'timezone': -9000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 123.01, 'speed': 6.8}}
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': 48.5, 'lon': 37.59},
#  'dt': 1560555369,
#  'id': 705104,
#  'main': {'grnd_level': 999.6,
#           'humidity': 61,
#           'pressure': 1017.58,
#           'sea_level': 1017.58,
#           'temp': 58.61,
#           'temp_max': 58.61,
#           'temp_min': 58.61},
#  'name': 'Rozkishne',
#  'sys': {'country': 'UA',
#          'message': 0.0046,
#          'sunrise': 1560562039,
#          'sunset': 1560619970},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 57.099, 'speed': 1.63}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 41.28, 'lon': 20.71},
#  'dt': 1560555370,
#  'id': 787487,
#  'main': {'humidity': 77,
#           'pressure': 1019,
#           'temp': 64.4,
#           'temp_max': 64.4,
#           'temp_min': 64.4},
#  'name': 'Poum',
#  'sys': {'country': 'MK',
#          'id': 7013,
#          'message': 0.0051,
#          'sunrise': 1560567813,
#          'sunset': 1560622300,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 5.82}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 45.52, 'lon': -122.67},
#  'dt': 1560555367,
#  'id': 5746545,
#  'main': {'humidity': 46,
#           'pressure': 1018,
#           'temp': 71.46,
#           'temp_max': 75,
#           'temp_min': 68},
#  'name': 'Portland',
#  'sys': {'country': 'US',
#          'id': 5321,
#          'message': 0.0094,
#          'sunrise': 1560514882,
#          'sunset': 1560571239,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'speed': 4.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 69.13, 'lon': 18.61},
#  'dt': 1560555370,
#  'id': 3145649,
#  'main': {'humidity': 81,
#           'pressure': 1019,
#           'temp': 42.51,
#           'temp_max': 44.6,
#           'temp_min': 41},
#  'name': 'Moen',
#  'sys': {'country': 'NO',
#          'id': 1619,
#          'message': 0.0056,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 9.17}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 36.58, 'lon': 137.08},
#  'dt': 1560555371,
#  'id': 1849876,
#  'main': {'humidity': 82,
#           'pressure': 999,
#           'temp': 67.35,
#           'temp_max': 70,
#           'temp_min': 66.2},
#  'name': 'Yamada',
#  'sys': {'country': 'JP',
#          'id': 8020,
#          'message': 0.0052,
#          'sunrise': 1560540769,
#          'sunset': 1560593479,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'speed': 2.24}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 59.58, 'lon': 151.3},
#  'dt': 1560555371,
#  'id': 2122574,
#  'main': {'grnd_level': 1016.32,
#           'humidity': 91,
#           'pressure': 1019.41,
#           'sea_level': 1019.41,
#           'temp': 41.69,
#           'temp_max': 41.69,
#           'temp_min': 41.69},
#  'name': 'Ola',
#  'sys': {'country': 'RU',
#          'message': 0.0055,
#          'sunrise': 1560530157,
#          'sunset': 1560597263},
#  'timezone': 39600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 182.557, 'speed': 5.57}}
# {'base': 'stations',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': -9.54, 'lon': 16.35},
#  'dt': 1560555371,
#  'id': 2239862,
#  'main': {'grnd_level': 895.5,
#           'humidity': 41,
#           'pressure': 1017.21,
#           'sea_level': 1017.21,
#           'temp': 58.79,
#           'temp_max': 58.79,
#           'temp_min': 58.79},
#  'name': 'Malanje',
#  'sys': {'country': 'AO',
#          'message': 0.0055,
#          'sunrise': 1560575278,
#          'sunset': 1560616927},
#  'timezone': 3600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 142.362, 'speed': 5.28}}

# %%
city_df = pd.DataFrame(city_data)

# %%
city_df.loc[city_df["Humidity"] > 100]
# Out:
#                  City  Cloudiness Country        Date Description  Humidity  \
# 95             talara           0      PE  1560555258   clear sky       290
# 333             paita           0      PE  1560555322   clear sky       290
# 486  puerto maldonado          20      PE  1560555357  few clouds       334
#
#        Lat    Lng  Max Temp  Min Temp  Pressure  Temp  Wind Speed
# 95   -4.58 -81.27      62.6      62.6    1012.0  62.6       13.87
# 333  -5.09 -81.11      62.6      62.6    1012.0  62.6       13.87
# 486 -12.59 -69.19      33.8      33.8    1010.0  33.8        4.70

# %%
#scatter plot of Max temperature
plt.scatter(city_df["Lat"],city_df["Max Temp"], s= 75, c="lightcoral", edgecolor="black", linewidths=1, marker="o", 
            alpha=0.5, label="Cities")

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"),
          horizontalalignment='center', fontsize=14)

plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")


plt.grid(color='black', linewidth=.25)

# %%
#scatter plot of pressure

plt.scatter(city_df["Lat"],city_df["Pressure"],c="purple", edgecolor="black", linewidths=1, marker="o", s= 75, 
            alpha=0.5, label="Cities")

plt.title("City Latitude vs. Pressure (%s)" % time.strftime("%x"),
          horizontalalignment='center', fontsize=14)

plt.ylabel("Pressure")
plt.xlabel("Latitude")

plt.grid(color='black', linewidth=.25)

# %%
#scatter plot of humidity

plt.scatter(city_df["Lat"],city_df["Humidity"], c= "darkgrey", edgecolor="black", linewidths=1, marker="o",s=75, 
            alpha=0.5, label="Cities")

plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"),
         horizontalalignment='center', fontsize=14)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(color='black', linewidth=.25)

# %%
#scatter plot of wind speed

plt.scatter(city_df["Lat"],city_df["Wind Speed"], c="green", edgecolor="black", linewidths=1, marker="o",s=75, 
            alpha=0.5, label="Cities")

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"),
         horizontalalignment='center', fontsize=14)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(color='black', linewidth=.25)

# %%
#scatter plot of cloudiness

plt.scatter(city_df["Lat"],city_df["Cloudiness"], c="skyblue", edgecolor="black", linewidths=1, marker="o",s=75, 
            alpha=0.5, label="Cities")

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"),
         horizontalalignment='center', fontsize=14)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(color='black', linewidth=.25)

# %%
plt.scatter(city_df["Lng"],city_df["Lat"], s=25,c=np.array(city_df['Max Temp']), cmap="RdBu_r")

plt.suptitle("Cities Temperature",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Temperature in Degrees (F)",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(city_df["Lng"],city_df["Lat"], s=25,c=np.array(city_df["Pressure"]), cmap="RdBu_r")

plt.suptitle("Cities Temperature",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Temperature in Degrees (F)",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(city_df["Lng"],city_df["Lat"], s=25,c=np.array(city_df["Humidity"]), cmap="RdBu_r")

plt.suptitle("Cities Temperature",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Temperature in Degrees (F)",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()

# %%
plt.scatter(city_df["Lng"],city_df["Lat"], s=25,c=np.array(city_df["Wind Speed"]), cmap="RdBu_r")

plt.suptitle("Cities Temperature",horizontalalignment='center', verticalalignment='top', fontsize=16)
plt.title("Note: Color Represents Temperature in Degrees (F)",fontstyle ='italic', fontsize=10)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(color='black', linewidth=.10)
plt.colorbar()

#name the image file to save figure 
save_image = None 

if save_image is not None:
    plt.savefig(save_image)
    plt.close(save_image)
else:
    plt.show()
